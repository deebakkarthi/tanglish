# %% [markdown]
# # Imports

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 1.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.0.0-cp311-cp311-macosx_10_9_universal2.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24

# %%
import pandas as pd
import seaborn as sns
import re
import string
import contractions
from nltk.tokenize import word_tokenize
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE, Laplace

# %% [markdown]
# ---

# %% [markdown]
# # Preprocessing

# %%
def preproc(filename):
    df = pd.read_csv(filename, delimiter="\t")
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
    df = df[df["category"] != "not-Tamil"]
    df["text"] = df["text"].apply(conv_uchar_to_space)
    df["text"] = df["text"].apply(str.lower)
    df["text"] = df["text"].apply(lambda x: re.sub(r"\d+", "", x))
    df["text"] = df["text"].apply(contractions.fix)
    df["text"] = df["text"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))
    df["text"].to_csv(f"{filename}_cleaned.csv", index=False)
    df["text"] = df["text"].apply(lambda x: word_tokenize(x))
    corpus = df["text"].tolist()
    return corpus

# %%
df = pd.read_csv("./tamil_train.tsv", delimiter="\t")

# %%
df.head()
# Out:
#                                                 text   category
# 0           Trailer late ah parthavanga like podunga  Positive
# 1         Move pathutu vanthu trailer pakurvnga yaru  Positive
# 2           Puthupetai dhanush  ah yarellam pathinga  Positive
# 3   Dhanush oda character ,puthu sa erukay , mass ta  Positive
# 4   vera level ippa pesungada mokka nu thalaivaaaaaa  Positive

# %%
df.shape
# Out:
# (11335, 2)

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# ## Distribution

# %%
sns.histplot(data=df, x="category")
# Out:
# <Axes: xlabel='category', ylabel='Count'>

# %% [markdown]
# ## Removing non-tamil sentences

# %%
(df["category"] == "not-Tamil").value_counts()
# Out:
# False    10967
# True       368
# Name: category, dtype: int64

# %%
df = df[df["category"] != "not-Tamil"]

# %%
df.shape
# Out:
# (10967, 2)

# %%
sns.histplot(data=df, x="category")
# Out:
# <Axes: xlabel='category', ylabel='Count'>

# %% [markdown]
# ## Remove non ASCII characters

# %%
def conv_uchar_to_space(string):
    return "".join([i if ord(i) < 128 else " " for i in string])

# %%
df["text"].apply(conv_uchar_to_space)
# Out:
# 0                 trailer late ah parthavanga like podunga
# 1               move pathutu vanthu trailer pakurvnga yaru
# 2                 puthupetai dhanush  ah yarellam pathinga
# 3         dhanush oda character ,puthu sa erukay , mass ta
# 4         vera level ippa pesungada mokka nu thalaivaaaaaa
#                                ...
# 11330           yuvan shankar raja anna fan's like here...
# 11331      a masterpiece best revenge film i ve ever scene
# 11332                enna pa thala ya kamiya than katringa
# 11333                              r a a s h i k h a n n a
# 11334    trailer la nalla thaan iruku ana sound thaan k...
# Name: text, Length: 10967, dtype: object

# %%
df["text"] = df["text"].apply(conv_uchar_to_space)

# %%
df.head()
# Out:
#                                                text  category
# 0          Trailer late ah parthavanga like podunga  Positive
# 1        Move pathutu vanthu trailer pakurvnga yaru  Positive
# 2          Puthupetai dhanush  ah yarellam pathinga  Positive
# 3  Dhanush oda character ,puthu sa erukay , mass ta  Positive
# 4  vera level ippa pesungada mokka nu thalaivaaaaaa  Positive

# %% [markdown]
# ## Convert to lowercase

# %%
df["text"].apply(str.lower)
# Out:
# 0                 trailer late ah parthavanga like podunga
# 1               move pathutu vanthu trailer pakurvnga yaru
# 2                 puthupetai dhanush  ah yarellam pathinga
# 3         dhanush oda character ,puthu sa erukay , mass ta
# 4         vera level ippa pesungada mokka nu thalaivaaaaaa
#                                ...
# 11330           yuvan shankar raja anna fan's like here...
# 11331      a masterpiece best revenge film i ve ever scene
# 11332                enna pa thala ya kamiya than katringa
# 11333                              r a a s h i k h a n n a
# 11334    trailer la nalla thaan iruku ana sound thaan k...
# Name: text, Length: 10967, dtype: object

# %%
df["text"] = df["text"].apply(str.lower)

# %%
df.head()
# Out:
#                                                text  category
# 0          trailer late ah parthavanga like podunga  Positive
# 1        move pathutu vanthu trailer pakurvnga yaru  Positive
# 2          puthupetai dhanush  ah yarellam pathinga  Positive
# 3  dhanush oda character ,puthu sa erukay , mass ta  Positive
# 4  vera level ippa pesungada mokka nu thalaivaaaaaa  Positive

# %% [markdown]
# # Removing Numbers

# %%
df["text"].apply(lambda x: re.sub(r"\d+", "", x))
# Out:
# 0                 trailer late ah parthavanga like podunga
# 1               move pathutu vanthu trailer pakurvnga yaru
# 2                 puthupetai dhanush  ah yarellam pathinga
# 3         dhanush oda character ,puthu sa erukay , mass ta
# 4         vera level ippa pesungada mokka nu thalaivaaaaaa
#                                ...
# 11330           yuvan shankar raja anna fan's like here...
# 11331      a masterpiece best revenge film i ve ever scene
# 11332                enna pa thala ya kamiya than katringa
# 11333                              r a a s h i k h a n n a
# 11334    trailer la nalla thaan iruku ana sound thaan k...
# Name: text, Length: 10967, dtype: object

# %%
df["text"] = df["text"].apply(lambda x: re.sub(r"\d+", "", x))

# %% [markdown]
# ## Expand Contractions

# %%
df["text"].apply(contractions.fix)
# Out:
# 0                 trailer late ah parthavanga like podunga
# 1               move pathutu vanthu trailer pakurvnga yaru
# 2                 puthupetai dhanush  ah yarellam pathinga
# 3         dhanush oda character ,puthu sa erukay , mass ta
# 4         vera level ippa pesungada mokka nu thalaivaaaaaa
#                                ...
# 11330           yuvan shankar raja anna fan's like here...
# 11331      a masterpiece best revenge film i ve ever scene
# 11332                enna pa thala ya kamiya than katringa
# 11333                              r a a s h i k h a n n a
# 11334    trailer la nalla thaan iruku ana sound thaan k...
# Name: text, Length: 10967, dtype: object

# %%
df["text"] = df["text"].apply(contractions.fix)

# %% [markdown]
# # Remove Punctuations

# %%
df["text"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))
# Out:
# 0                 trailer late ah parthavanga like podunga
# 1               move pathutu vanthu trailer pakurvnga yaru
# 2                 puthupetai dhanush  ah yarellam pathinga
# 3           dhanush oda character puthu sa erukay  mass ta
# 4         vera level ippa pesungada mokka nu thalaivaaaaaa
#                                ...
# 11330               yuvan shankar raja anna fans like here
# 11331      a masterpiece best revenge film i ve ever scene
# 11332                enna pa thala ya kamiya than katringa
# 11333                              r a a s h i k h a n n a
# 11334    trailer la nalla thaan iruku ana sound thaan k...
# Name: text, Length: 10967, dtype: object

# %%
df["text"] = df["text"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))

# %%
df["text"].to_csv("cleaned.csv", index=False)

# %% [markdown]
# # Tokenization

# %%
df["text"].apply(lambda x: word_tokenize(x))
# Out:
# 0          [trailer, late, ah, parthavanga, like, podunga]
# 1        [move, pathutu, vanthu, trailer, pakurvnga, yaru]
# 2            [puthupetai, dhanush, ah, yarellam, pathinga]
# 3        [dhanush, oda, character, puthu, sa, erukay, m...
# 4        [vera, level, ippa, pesungada, mokka, nu, thal...
#                                ...
# 11330       [yuvan, shankar, raja, anna, fans, like, here]
# 11331    [a, masterpiece, best, revenge, film, i, ve, e...
# 11332        [enna, pa, thala, ya, kamiya, than, katringa]
# 11333                 [r, a, a, s, h, i, k, h, a, n, n, a]
# 11334    [trailer, la, nalla, thaan, iruku, ana, sound,...
# Name: text, Length: 10967, dtype: object

# %%
df["text"] = df["text"].apply(lambda x: word_tokenize(x))

# %%
df.head()
# Out:
#                                                 text  category
# 0    [trailer, late, ah, parthavanga, like, podunga]  Positive
# 1  [move, pathutu, vanthu, trailer, pakurvnga, yaru]  Positive
# 2      [puthupetai, dhanush, ah, yarellam, pathinga]  Positive
# 3  [dhanush, oda, character, puthu, sa, erukay, m...  Positive
# 4  [vera, level, ippa, pesungada, mokka, nu, thal...  Positive

# %%
corpus = df["text"].tolist()

# %%
corpus
# Out:
# [['trailer', 'late', 'ah', 'parthavanga', 'like', 'podunga'],
#  ['move', 'pathutu', 'vanthu', 'trailer', 'pakurvnga', 'yaru'],
#  ['puthupetai', 'dhanush', 'ah', 'yarellam', 'pathinga'],
#  ['dhanush', 'oda', 'character', 'puthu', 'sa', 'erukay', 'mass', 'ta'],
#  ['vera', 'level', 'ippa', 'pesungada', 'mokka', 'nu', 'thalaivaaaaaa'],
#  ['thala', 'mass', 'you', 'bgm', 'vera', 'level'],
#  ['ivara', 'pathta', 'death', 'vadi', 'madiri', 'irukku'],
#  ['s',
#   'kids',
#   'reference',
#   'maadila',
#   'irunthu',
#   'kudicha',
#   'shakthiman',
#   'kaapathvaaru'],
#  ['aiyoo', 'thala', 'mass', 'pannita', 'thala'],
#  ['enpt',
#   'ku',
#   'kaathu',
#   'kadanthathellam',
#   'oru',
#   'nimishathula',
#   'poiruchu'],
#  ['when',
#   'pandey',
#   'gets',
#   'up',
#   'vandumurugan',
#   'i',
#   'am',
#   'speaking',
#   'no',
#   'cross',
#   'speaking',
#   'sittt',
#   'downnn'],
#  ['remake', 'of', 'malayalam', 'mohanlal', 'movie', 'devadoodhan'],
#  ['tharamaana', 'sirappaana', 'sambavam', 'inimeal', 'ta', 'paaka', 'pora'],
#  ['viswasam', 'trailer', 'paathutu', 'inka', 'vanthavanga', 'like', 'panuga'],
#  ['maran', 'kattu', 'kattitamnue', 'verithanam', 'thalivaa', 'a'],
#  ['ella',
#   'trailer',
#   'la',
#   'last',
#   'la',
#   'oru',
#   'mass',
#   'dialouge',
#   'vaichikuringaaa',
#   'paaaa'],
#  ['eppa',
#   'saamy',
#   'thala',
#   'padathula',
#   'vera',
#   'director',
#   'perapakurathu',
#   'evalo',
#   'periya',
#   'santhosama',
#   'iruku'],
#  ['en',
#   'thalaivan',
#   'vijaysethubathi',
#   'kaga',
#   'matume',
#   'na',
#   'padam',
#   'papan',
#   'matha',
#   'entha',
#   'p',
#   'illa'],
#  ['kanithan', 'mugamoodi', 'neenga', 'nambalainalum', 'ithan', 'nesam'],
#  ['enakku', 'iru', 'mugan', 'trailer', 'gnabagam', 'than', 'varuthu'],
#  ['are',
#   'you',
#   'expecting',
#   'happy',
#   'deepavali',
#   'force',
#   'dialogue',
#   'in',
#   'movie'],
#  ['sakthimaan', 'fans', 'like', 'sivakarthikeyen', 'fans', 'comment'],
#  ['rajini', 'and', 'akshay', 'fans', 'hit', 'like'],
#  ['hour', 'million', 'likes'],
#  ['raww', 'vana', 'padama', 'iruku', 'all', 'the', 'best'],
#  ['thalaiva', 'full', 'support', 'from', 'kerala', 'mohanlal', 'fans'],
#  ['en',
#   'da',
#   'trailer',
#   'layae',
#   'ivlo',
#   'slow',
#   'motion',
#   'nah',
#   'padathula',
#   'paathi',
#   'duration',
#   'slow',
#   'motion',
#   'layae',
#   'mudichirpeenga',
#   'polayae'],
#  ['thalaiva',
#   'ungala',
#   'screen',
#   'pakkum',
#   'pothey',
#   'ippadiiii',
#   'erukinga',
#   'na',
#   'nerla',
#   'partha',
#   'yappidiiii',
#   'erupinga',
#   'oru',
#   'murai',
#   'tharisanam',
#   'kedaikumaaaa'],
#  ['rajini', 'ah', 'vida', 'akshay', 'mass', 'ah', 'irukane'],
#  ['thala',
#   'koda',
#   'compare',
#   'panna',
#   'yarukum',
#   'thakuthi',
#   'kidaiyathu',
#   'mind',
#   'it'],
#  ['marana',
#   'mass',
#   'marana',
#   'style',
#   'marna',
#   'gethu',
#   'mass',
#   'trailer',
#   'rajinified'],
#  ['paruthiveeran', 'karthi', 'back', 'lokesh', 'kangaraj', 'screenplay'],
#  ['diwali', 'annante', 'aniyan', 'ullaltha', 'step', 'back', 'bigil'],
#  ['dialogue',
#   'pundaiye',
#   'puriyala',
#   'otha',
#   'theatre',
#   'la',
#   'nacham',
#   'sound',
#   'seri',
#   'pannungada'],
#  ['poda',
#   'mokka',
#   'moonji',
#   'unna',
#   'pathale',
#   'siriputhan',
#   'varuthu',
#   'super',
#   'herovaam',
#   'adutha',
#   'mugamoodiii'],
#  ['dei', 'kelthu', 'kuthi', 'ajith', 'ivanya', 'yaru', 'nadika', 'sona'],
#  ['yaaru',
#   'ivanaa',
#   'indha',
#   'kosu',
#   'asoorana',
#   'dei',
#   'ennada',
#   'unga',
#   'rasana'],
#  ['namma',
#   'kitte',
#   'kaadu',
#   'irunthaeduthukuvanga',
#   'namma',
#   'kitte',
#   'roopa',
#   'iruntha',
#   'pudukiku',
#   'vaanga',
#   'padippu',
#   'mattum',
#   'namma',
#   'kitte',
#   'irundhu',
#   'eduthukave',
#   'mudiyathu',
#   'superb',
#   'lines'],
#  ['ethukkuda',
#   'ivlo',
#   'actors',
#   'hypothalaivar',
#   'padamna',
#   'avar',
#   'matumtha',
#   'irukanum'],
#  ['thlaiavaa', 'thalaivaa', 'thaliava', 'thalaivaa', 'thalaivaa'],
#  ['epdi', 'like', 'pottavan', 'eallarum', 'seathupogada'],
#  ['true',
#   'in',
#   'the',
#   'age',
#   'information',
#   'abundance',
#   'and',
#   'mass',
#   'distractions'],
#  ['supper', 'dhanush', 'anna', 'mass', 'waiting', 'asuran'],
#  ['vera', 'lvl', 'thalaiva', 'you', 'r', 'great'],
#  ['mobile',
#   'main',
#   'mera',
#   'phek',
#   'dunga',
#   'iphone',
#   'x',
#   'barna',
#   'aisa',
#   'problem',
#   'hoga'],
#  ['ellam', 'avan', 'sayal', 'movie', 'mathiriya', 'irukku'],
#  ['boss', 'you', 'looking', 'so', 'handsome', 'nd', 'young', 'kekaa'],
#  ['pattaya', 'kelapitey', 'siva', 'awesome'],
#  ['dahaaaaaaa',
#   'chitii',
#   'come',
#   'back',
#   'i',
#   'am',
#   'waiting',
#   'get',
#   'ready',
#   'to'],
#  ['boni',
#   'kapoor',
#   'sir',
#   'ini',
#   'entha',
#   'update',
#   'illama',
#   'ethum',
#   'release',
#   'panathinga',
#   'sir',
#   'intha',
#   'chinna',
#   'pasanga',
#   'tholla',
#   'thanga',
#   'mudiyala'],
#  ['looks',
#   'thrilling',
#   'thala',
#   'get',
#   'up',
#   'super',
#   'as',
#   'lawyer',
#   'dai',
#   'pandey',
#   'neeya',
#   'da'],
#  ['neenga',
#   'enna',
#   'vena',
#   'kathukonga',
#   'aana',
#   'hollywood',
#   'padathukku',
#   'dubbing',
#   'mattum',
#   'kathukathinga'],
#  ['ena',
#   'da',
#   'nadakuthu',
#   'inga',
#   'epaaa',
#   'sathiyamaa',
#   'edir',
#   'pakatha',
#   'trailer',
#   'totally',
#   'unimaginable',
#   'trailer',
#   'thalivar'],
#  ['thala', 'da', 'by', 'thalapathy', 'fan'],
#  ['sun',
#   'picture',
#   'best',
#   'or',
#   'vijay',
#   'tv',
#   'best',
#   'sp',
#   'best',
#   'na',
#   'dislike',
#   'pannuga',
#   'vijay',
#   'tv',
#   'best',
#   'na',
#   'like',
#   'pannuga'],
#  ['hey',
#   'makkalay',
#   'yaaru',
#   'darbar',
#   'motion',
#   'poster',
#   'announcementku',
#   'apram',
#   'vantheenga'],
#  ['last',
#   'dialoge',
#   'thala',
#   'fans',
#   'ungalukkuta',
#   'iam',
#   'vijay',
#   'fan',
#   'trailer',
#   'super'],
#  ['hollywood',
#   'range',
#   'la',
#   'iruku',
#   'padam',
#   'kandipa',
#   'blockbuster',
#   'hit',
#   'semma',
#   'story'],
#  ['but',
#   'ore',
#   'oru',
#   'varutham',
#   'ennana',
#   'sunday',
#   'release',
#   'pannirukkalam',
#   'yesterday',
#   'aavathu',
#   'announcement',
#   'pannirukkalam'],
#  ['semmma', 'style', 'rajini', 'sir', 'is', 'back'],
#  ['my', 'dear', 'thala', 'ahhhhhhhhhhhhhh', 'semma', 'gethu'],
#  ['idduke', 'va', 'tarlam', 'kolla', 'mass'],
#  ['movie', 'savadi', 'vera', 'level', 'poothalaivar', 'thalaivar', 'thaamass'],
#  ['super',
#   'thalaiva',
#   'semma',
#   'mass',
#   'intha',
#   'movie',
#   'blockbuster',
#   'thaan',
#   'fdfs',
#   'poravanga',
#   'like',
#   'pannunga'],
#  ['k', 'views', 'k', 'likes', 'fraud'],
#  ['minute',
#   'trailor',
#   'vida',
#   'thil',
#   'irukkaabollywood',
#   'la',
#   'panrangatamila',
#   'mudiyuma'],
#  ['dai', 'ranjit', 'nee', 'idha', 'parthu', 'film', 'eduka', 'kathuko'],
#  ['trailer',
#   'fast',
#   'ah',
#   'podu',
#   'ana',
#   'background',
#   'la',
#   'main',
#   'bgm',
#   'illaye',
#   'fyt',
#   'ku',
#   'varadhinga',
#   'da',
#   'unmaiya',
#   'tha',
#   'slura'],
#  ['superb',
#   'vivek',
#   'mervin',
#   'pinnitinga',
#   'ponga',
#   'ungalukagave',
#   'padam',
#   'pakanum'],
#  ['viswasam',
#   'likes',
#   'aa',
#   'pathu',
#   'payainthu',
#   'vainthavainga',
#   'yar',
#   'yar',
#   'like',
#   'pothathu'],
#  ['thaa', 'enna', 'lookyou', 'daa', 'saami', 'that', 'bgm', 'lit'],
#  ['guyzz', 'm', 'likes', 'vara', 'varaikum', 'vitraadheenga'],
#  ['padaiyatchi',
#   'nu',
#   'sonna',
#   'mattum',
#   'ungalukku',
#   'jaathi',
#   'veri',
#   'nagi',
#   'reddi',
#   'settiyar',
#   'mudaliar',
#   'nu',
#   'sonna',
#   'adhu',
#   'jaathi',
#   'veri',
#   'illaya'],
#  ['velraj',
#   'sir',
#   'thalaivana',
#   'masss',
#   'a',
#   'kamchirukaru',
#   'vera',
#   'level',
#   'you'],
#  ['you',
#   'kaga',
#   'paakuradha',
#   'illa',
#   'sk',
#   'kaaga',
#   'verukuradhane',
#   'therila',
#   'but',
#   'mithran',
#   'you',
#   'kaaga',
#   'kandipa',
#   'paakanum'],
#  ['iam',
#   'vijay',
#   'fan',
#   'kerala',
#   'and',
#   'iam',
#   'waiting',
#   'super',
#   'stars',
#   'petta'],
#  ['oh', 'my', 'god', 'it', 'is', 'rajini', 'for', 'you'],
#  ['thala',
#   'looka',
#   'apdiyae',
#   'vechurkaru',
#   'pa',
#   'without',
#   'audio',
#   'la',
#   'paata',
#   'thalaikum',
#   'ivrukkum',
#   'vityasam',
#   'teriyathu'],
#  ['dai',
#   'yaaru',
#   'da',
#   'antha',
#   'k',
#   'apadi',
#   'enna',
#   'da',
#   'enga',
#   'thala',
#   'mela',
#   'ungaluku',
#   'gaandu'],
#  ['love',
#   'you',
#   'thalaivaaaaaaa',
#   'avangala',
#   'aarani',
#   'anastasias',
#   'alabama',
#   'and',
#   'anastasias'],
#  ['iam', 'sk', 'fan', 'aanaa', 'trailer', 'semma'],
#  ['wow',
#   'padam',
#   'tharu',
#   'mara',
#   'iruka',
#   'poguthu',
#   'this',
#   'pongal',
#   'petta',
#   'diwali'],
#  ['sema', 'mass', 'marana', 'mass', 'tha', 'i', 'love', 'rajini'],
#  ['k',
#   'likes',
#   'varavareku',
#   'nanu',
#   'thungamatte',
#   'nenaikiravage',
#   'like',
#   'podunge'],
#  ['damni', 'am', 'a', 'proud', 'chiyaan', 'vikram', 'fan'],
#  ['enna', 'panna', 'porom', 'sweet', 'sapda', 'porom'],
#  ['entha',
#   'kannada',
#   'naiyai',
#   'ennum',
#   'tamilnattil',
#   'erunthu',
#   'anupalaiya'],
#  ['vaa',
#   'thalaiva',
#   'via',
#   'diwali',
#   'mass',
#   'you',
#   'are',
#   'movie',
#   'bikil',
#   'out'],
#  ['veralevel', 'performer', 'dhanush', 'sir'],
#  ['no',
#   'means',
#   'no',
#   'entha',
#   'dialogue',
#   'thalaya',
#   'thavara',
#   'yaru',
#   'sonna',
#   'nallairukumnu',
#   'tharayala'],
#  ['super', 'akshay', 'sir', 'i', 'love', 'you', 'sir'],
#  ['looks', 'like', 'he', 'will', 'set', 'screen', 'on', 'fire'],
#  ['ninga',
#   'vena',
#   'yenkuda',
#   'classah',
#   'passah',
#   'suthla',
#   'aana',
#   'yen',
#   'massu',
#   'yennanu',
#   'teriyathulla'],
#  ['it', 'is', 'pink', 'with', 'ajith', 'kumar', 'ka', 'chutiyapa'],
#  ['rmba',
#   'sandhosama',
#   'irukku',
#   'thala',
#   'ipdi',
#   'suspense',
#   'movie',
#   'la',
#   'nadichadhuand',
#   'rlz',
#   'kaga',
#   'waiting'],
#  ['villaina',
#   'mass',
#   'aa',
#   'kattallayea',
#   'so',
#   'sad',
#   'villain',
#   'mass',
#   'aa',
#   'iruntha',
#   'thaa',
#   'movie',
#   'mass',
#   'aa',
#   'irukkum'],
#  ['trailer', 'vera', 'level', 'athana', 'daaamai', 'kunjugala'],
#  ['yenda',
#   'padathoda',
#   'ottumoththa',
#   'kadhaiyayum',
#   'idhudhan',
#   'nu',
#   'potu',
#   'kaatra',
#   'mariya',
#   'da',
#   'trailer',
#   'pannuveenga'],
#  ['nambakita',
#   'kadu',
#   'iruntha',
#   'vangikuvanunga',
#   'kasu',
#   'iruntha',
#   'puduingikuvanunga',
#   'padipa',
#   'mattum',
#   'pudungavey',
#   'mudiyathu',
#   'chidambaram'],
#  ['to', 'marana', 'massssss'],
#  ['thalapathy', 'villan', 'ku', 'oru', 'like', 'podu'],
#  ['no', 'trendingyellarum', 'idha', 'thana', 'ketutu', 'irundhinga'],
#  ['dhanush', 'fans', 'hit', 'like', 'here'],
#  ['eadicha', 'copy', 'daithu', 'ellam', 'avan', 'seyal', 'movie'],
#  ['like', 'so', 'much', 'thala', 'from', 'ap', 'pawankalyan', 'anna', 'fans'],
#  ['yellaam', 'super', 'but', 'nawazudin', 'voice', 'mattum', 'nalla', 'illa'],
#  ['wow', 'i', 'love', 'you', 'thalaivaaaaaa'],
#  ['thala', 'kola', 'waiting', 'eppo', 'yaa', 'release', 'panna', 'poringa'],
#  ['vaalum',
#   'theivam',
#   'ajith',
#   'kumar',
#   'manitha',
#   'kadavul',
#   'ajith',
#   'kumar',
#   'sokka',
#   'thangam',
#   'ajith',
#   'kumar',
#   'en',
#   'uyirai',
#   'kaakum',
#   'ajith',
#   'kumar',
#   'ulaga',
#   'uthaman',
#   'ajith',
#   'kumar'],
#  ['ethukku',
#   'ethellam',
#   'vvsrajini',
#   'murugan',
#   'mari',
#   'comedy',
#   'movie',
#   'pathuttu',
#   'entha',
#   'movie',
#   'pakka',
#   'mudiuma'],
#  ['comment', 'box', 'pakka', 'vantha', 'like', 'podunga'],
#  ['thalaivar', 'varuvaru', 'sure', 'aa', 'adippaaru'],
#  ['who', 'else', 'are', 'here', 'after', 'sarkar', 'movie'],
#  ['dialogues', 'ah', 'illama', 'mass', 'scenes', 'la', 'pesirukalaam'],
#  ['pongal', 'namalukku', 'super', 'collection', 'ma'],
#  ['ennada', 'pittalatama', 'irruku', 'views', 'k', 'but', 'likes', 'k', 'va'],
#  ['thalaivaaaa', 'ippa', 'enna', 'panna', 'porom', 'sweet', 'sapda', 'porom'],
#  ['i',
#   'am',
#   'thalapathi',
#   'fanbut',
#   'thalapathi',
#   'ku',
#   'apram',
#   'karthi',
#   'anna',
#   'va',
#   'than',
#   'pidikumintha',
#   'diwali',
#   'enaku',
#   'double',
#   'treat'],
#  ['yuvan',
#   'bgm',
#   'kola',
#   'mass',
#   'thalaiva',
#   'marana',
#   'waiting',
#   'for',
#   'valimai'],
#  ['thalaivar', 'ku', 'ennum', 'vaisae', 'agala', 'sema'],
#  ['kaithi',
#   'blockbuster',
#   'movie',
#   'bigil',
#   'abhi',
#   'tak',
#   'hit',
#   'bhi',
#   'nhi',
#   'huvi'],
#  ['ippa',
#   'enna',
#   'panna',
#   'poram',
#   'sweet',
#   'sapada',
#   'porom',
#   'super',
#   'awesome'],
#  ['thala', 'you', 'yuvan', 'shankar', 'raja', 'mass'],
#  ['shakthiman', 'fans', 'kill', 'the', 'like', 'button'],
#  ['antman', 'ah', 'pottu', 'hope', 'pottu', 'polakra', 'adhe', 'smack'],
#  ['screen',
#   'presence',
#   'la',
#   'ungala',
#   'adichukka',
#   'vera',
#   'evanum',
#   'illa',
#   'thala'],
#  ['vera', 'level', 'movie', 'vasool', 'nkp'],
#  ['vera',
#   'level',
#   'acting',
#   'thalaivar',
#   'masss',
#   'pakka',
#   'mass',
#   'sry',
#   'petta',
#   'masssss',
#   'sss'],
#  ['sahoo', 'million', 'nkp', 'innu', 'million', 'tha'],
#  ['senseless', 'movie', 'just', 'video', 'game'],
#  ['thala', 'fans', 'saarbaaga', 'motion', 'poster', 'vendum', 'adhe'],
#  ['rajinikanth', 'sir', 'is', 'my', 'favorite', 'hero', 'says', 'arr'],
#  ['kadaram', 'kondan', 'vs', 'saaho', 'i', 'am', 'waiting'],
#  ['sec', 'wowwwww'],
#  ['last', 'dialogue', 'suit', 'for', 'all', 'fans'],
#  ['thala', 'fans', 'hit', 'like', 'me'],
#  ['edho', 'sadhi', 'nadakudhu', 'pa', 'inum', 'trending', 'la', 'varala'],
#  ['kalaila',
#   'enthirucha',
#   'udane',
#   'thala',
#   'ah',
#   'paaka',
#   'vathavanga',
#   'oru',
#   'like',
#   'ah',
#   'podunga'],
#  ['shankar',
#   'sir',
#   'next',
#   'film',
#   'vijay',
#   'and',
#   'katrina',
#   'kaif',
#   'and',
#   'perya',
#   'herova',
#   'villain',
#   'ah',
#   'pana',
#   'veinga'],
#  ['dai', 'bahubali', 'kelambu', 'kelambu'],
#  ['pink', 'bollywood', 'but', 'like', 'ajit', 'kumar'],
#  ['comedy', 'ya', 'erukku', 'ithukku', 'billa', 'pandi', 'ok'],
#  ['vs', 'anna', 'semma', 'epavum', 'pola', 'neega', 'vera', 'level'],
#  ['okay', 'chiyan', 'vikram', 'in', 'kadaram', 'kondan', 'best', 'wishes'],
#  ['enna', 'paarva', 'da', 'idhu', 'goosebumps', 'guaranteed'],
#  ['marana', 'marana', 'marana', 'sirapana', 'tharamaana', 'padam'],
#  ['thala',
#   'look',
#   'sema',
#   'mass',
#   'nu',
#   'soldravanga',
#   'mattum',
#   'oru',
#   'like',
#   'podunga'],
#  ['vanthathu',
#   'vanthuteenga',
#   'thala',
#   'fans',
#   'ellarum',
#   'like',
#   'potutu',
#   'ponga'],
#  ['enada', 'pandey', 'news', 'ah', 'vittutu', 'cinema', 'la', 'nadikuran'],
#  ['ena', 'da', 'bgm', 'ithu', 'yuvannnnnnnnnn', 'rocksssssss'],
#  ['st', 'like', 'vijay', 'fanss', 'hit', 'likes'],
#  ['ex', 'police', 'cop', 'become', 'a', 'prisoner'],
#  ['trailer',
#   'late',
#   'ah',
#   'parthu',
#   'miss',
#   'pannavanga',
#   'ippo',
#   'happy',
#   'ah'],
#  ['nazawuddin', 'siddiqui', 'in', 'pettai', 'tharamana', 'mudivu'],
#  ['oru', 'pakkam', 'bigil', 'bigil', 'anil', 'kunjugalin', 'alaparaikal'],
#  ['super',
#   'yaru',
#   'nu',
#   'keta',
#   'chinna',
#   'kulandhai',
#   'um',
#   'solum',
#   'maestro',
#   'of',
#   'style'],
#  ['dhanush',
#   'indha',
#   'padathula',
#   'ethana',
#   'pera',
#   'vetunarunu',
#   'yarachum',
#   'therinja',
#   'solunga'],
#  ['vijay', 'sethupathi', 'fans', 'hit', 'like', 'here'],
#  ['aiyo', 'enaku', 'ipave', 'thalaya', 'padathula', 'pakanumnu', 'eruku'],
#  ['thalaaaa', 'you', 'again', 'rock'],
#  ['petta', 'telugu', 'la', 'illea', 'missing', 'in', 'tollywood'],
#  ['story',
#   'match',
#   'kaakapoinaa',
#   'konni',
#   'konni',
#   'shots',
#   'sukumar',
#   'rangasthalam',
#   'laaga',
#   'ne',
#   'undhi',
#   'choodataniki'],
#  ['telugu', 'thala', 'fans', 'hit', 'likes'],
#  ['ennada',
#   'm',
#   'views',
#   'ku',
#   'th',
#   'day',
#   'laye',
#   'ivlo',
#   'mukkudhu',
#   'nu',
#   'solra',
#   'bot',
#   'anil',
#   'p',
#   'pasangala',
#   'no',
#   'bots',
#   'no',
#   'visay'],
#  ['akshay', 'kumar', 'as', 'shiva', 'kumar'],
#  ['siripu', 'vantha', 'oru', 'like', 'podunga'],
#  ['teaser',
#   'la',
#   'iruntha',
#   'yedho',
#   'onnu',
#   'trailer',
#   'la',
#   'missing',
#   'aana',
#   'ithuvum',
#   'nalla',
#   'than',
#   'irukku'],
#  ['maran', 'waiting', 'la', 'panavendam', 'poi', 'saavunga', 'ajith', 'fans'],
#  ['dhanush', 'fans', 'sarbaga', 'padam', 'vetri', 'adiya', 'valthukal'],
#  ['sweet',
#   'sappuda',
#   'porom',
#   'sweet',
#   'saputtu',
#   'apdiye',
#   'ethavthu',
#   'karama',
#   'viswasam',
#   'sappuduvom'],
#  ['pazhaya', 'rajinikanth', 'ah', 'paatha', 'feeling', 'pa'],
#  ['maranam',
#   'mass',
#   'uh',
#   'maranam',
#   'petta',
#   'athukku',
#   'avar',
#   'thaa',
#   'poranthu',
#   'varanum',
#   'thalaivar'],
#  ['neraya',
#   'neraya',
#   'neraya',
#   'neraya',
#   'neraya',
#   'what',
#   'a',
#   'performance',
#   'voice',
#   'vera',
#   'level'],
#  ['ithan',
#   'diwali',
#   'fightsemme',
#   'kartikstory',
#   'value',
#   'va',
#   'hero',
#   'value',
#   'r',
#   'nu'],
#  ['dhanush', 'fans', 'oru', 'like', 'potutu', 'ponga'],
#  ['pink', 'but', 'like', 'for', 'ajith'],
#  ['beginning', 'of', 'satyayuga', 'end', 'of', 'kaliyuga'],
#  ['dhanush', 'sir', 'ku', 'ella', 'get', 'up', 'um', 'set', 'aagudhu'],
#  ['inimal',
#   'sun',
#   'networkla',
#   'petta',
#   'promo',
#   'poda',
#   'start',
#   'panniduvaanga'],
#  ['neraya',
#   'neraya',
#   'neraya',
#   'neraya',
#   'neraya',
#   'what',
#   'a',
#   'powerful',
#   'voice'],
#  ['thala',
#   'dye',
#   'adikkam',
#   'irukanaalathan',
#   'naama',
#   'nimathiya',
#   'irukkamudiythuthala',
#   'takkarudoi'],
#  ['krish', 'movie', 'mask', 'mathiri', 'erukku', 'pa'],
#  ['chiyaan', 'vikram', 'sir', 'vera'],
#  ['ethe', 'maari', 'ennamo', 'padam', 'pathaa', 'maatiye', 'eruke'],
#  ['thala', 'thanta', 'thalaiya', 'minja', 'evanta'],
#  ['late', 'a', 'vanthalu', 'latest', 'a', 'vanthurukku'],
#  ['thatha', 'ku', 'jodiya', 'paatis', 'padam', 'nalla', 'irrukum', 'pola'],
#  ['padappavali', 'now', 'petta', 'viswasam'],
#  ['bigil', 'satham', 'ketta', 'ella', 'kaithiyum', 'amaithithan'],
#  ['confirm',
#   'm',
#   'likes',
#   'varumnu',
#   'soldravange',
#   'like',
#   'podunge',
#   'machanzz'],
#  ['happy', 'new', 'year', 'thalaivar', 'padam', 'mass', 'kata', 'pothu'],
#  ['thala', 'vera', 'level', 'maas', 'you', 'bgm', 'ultimate'],
#  ['yenda',
#   'thala',
#   'enga',
#   'thala',
#   'ya',
#   'vada',
#   'dislike',
#   'panni',
#   'irukkenga'],
#  ['dai', 'youtube', 'trending', 'la', 'podu', 'da'],
#  ['sam', 'cs', 'vera', 'level', 'ya', 'un', 'bgm'],
#  ['thala', 'vera', 'level', 'n', 'yuvan', 'bgm', 'semmeee'],
#  ['thala',
#   'endru',
#   'sollada',
#   'thalai',
#   'nimirndhu',
#   'nillada',
#   'vanthudaruda',
#   'en',
#   'thala',
#   'ippa',
#   'vangada',
#   'kena'],
#  ['are', 'you', 'a', 'virgin', 'girls', 'kani', 'kazhiyama', 'irukingala'],
#  ['thalaivaa',
#   'thalaivaa',
#   'thalaivaa',
#   'thalaivaa',
#   'thalaivaa',
#   'thalaivaa',
#   'thalaivaa',
#   'thalaivaa',
#   'thalaivaa',
#   'thalaivaa'],
#  ['all', 'the', 'best', 'karthi', 'and', 'lokesh', 'kanakaraaj'],
#  ['romba',
#   'naaluku',
#   'aparam',
#   'thalaivar',
#   'sema',
#   'massa',
#   'pakurom',
#   'get',
#   'rajinified'],
#  ['indha',
#   'aala',
#   'ennadhan',
#   'veruthaalum',
#   'on',
#   'screenla',
#   'paakka',
#   'solla',
#   'indha',
#   'aalu',
#   'style',
#   'la',
#   'vilundarom'],
#  ['enna',
#   'mari',
#   'veetuku',
#   'theriyama',
#   'ippa',
#   'trailer',
#   'parkuravanga',
#   'yaravadhu',
#   'irukeengala'],
#  ['mavena',
#   'edhavadhu',
#   'haters',
#   'irundha',
#   'odi',
#   'poiru',
#   'kola',
#   'kandula',
#   'irukkaen',
#   'padam',
#   'paakama',
#   'vidamataen'],
#  ['elam',
#   'girls',
#   'um',
#   'trailer',
#   'ah',
#   'patha',
#   'maari',
#   'movie',
#   'ya',
#   'kandipaa',
#   'parungaa'],
#  ['ena', 'da', 'spartan', 's', 'bgm', 'la', 'varuthu'],
#  ['i',
#   'am',
#   'kamal',
#   'sir',
#   'fanzz',
#   'but',
#   'i',
#   'like',
#   'trailer',
#   'waiting',
#   'fr',
#   'movie'],
#  ['vetrimaran',
#   'ithai',
#   'thavira',
#   'vera',
#   'ethuvum',
#   'theriyatha',
#   'ora',
#   'mathiri',
#   'padam'],
#  ['viswasam',
#   'teaser',
#   'vartum',
#   'nama',
#   'side',
#   'la',
#   'irnthu',
#   'oru',
#   'sambavam',
#   'panuvom'],
#  ['intha', 'padatha', 'pathe', 'aakanum', 'thalaivaa', 'aaaaaa'],
#  ['kris',
#   's',
#   'movie',
#   'pola',
#   'irukkunu',
#   'yaarukkavadu',
#   'feel',
#   'aahircha'],
#  ['viswasam',
#   'trailer',
#   'k',
#   'like',
#   'm',
#   'like',
#   'thala',
#   'fans',
#   'like',
#   'tha',
#   'trailer'],
#  ['ada', 'dei', 'nama', 'sambatha', 'da', 'dei'],
#  ['nvp', 'voda', 'recorda', 'break', 'pannanum', 'solravangalike', 'pannunga'],
#  ['movie',
#   'pathutan',
#   'semma',
#   'mass',
#   'a',
#   'irukku',
#   'music',
#   'la',
#   'vera',
#   'leval'],
#  ['marana', 'mass', 'thala', 'i', 'am', 'waiting'],
#  ['intha',
#   'padathula',
#   'gethu',
#   'mass',
#   'kaatra',
#   'thalaya',
#   'nadikala',
#   'intha',
#   'padathula',
#   'intha',
#   'naatoda',
#   'indraiya',
#   'unmaiya',
#   'solra',
#   'ajith',
#   'kumar',
#   'ah',
#   'nadichirkaaru',
#   'stopwomenabuse'],
#  ['vayase', 'aagala', 'pa', 'ena', 'effort', 'chanceless'],
#  ['thala',
#   'yada',
#   'dialogue',
#   'delivery',
#   'sema',
#   'mass',
#   'vera',
#   'level',
#   'goosebumps',
#   'overloaded'],
#  ['gommala',
#   'vararuda',
#   'ye',
#   'thalaivar',
#   'ippavea',
#   'alluthuparu',
#   'palapearuku',
#   'parupuuu'],
#  ['vaera',
#   'level',
#   'thala',
#   'summa',
#   'na',
#   'podathiga',
#   'mokka',
#   'seenu',
#   'eppa',
#   'naerkonda',
#   'parvai',
#   'is',
#   'coming',
#   'soon'],
#  ['vayasanalum',
#   'unga',
#   'style',
#   'azhagum',
#   'innum',
#   'marala',
#   'thalaiva',
#   'roxkzzzzzz'],
#  ['matha',
#   'actor',
#   'la',
#   'vera',
#   'level',
#   'na',
#   'niii',
#   'top',
#   'level',
#   'thalaivaaa'],
#  ['enna', 'panna', 'porom', 'sweet', 'sapda', 'porom', 'petta', 'paraak'],
#  ['dislike', 'pota', 'ealarum', 'lusu', 'p'],
#  ['vena', 'padama', 'release', 'pannathinga', 'pakka', 'mudiyala'],
#  ['thala', 'bloods', 'ellaarum', 'oru', 'like', 'podunga'],
#  ['real', 'rajnikant', 'or', 'dupe', 'amazingly', 'young'],
#  ['deepavali',
#   'ku',
#   'vera',
#   'level',
#   'padam',
#   'irukku',
#   'pakka',
#   'kaithi',
#   'deepavali'],
#  ['aiyo',
#   'thala',
#   'marana',
#   'mass',
#   'thala',
#   'love',
#   'you',
#   'so',
#   'much',
#   'thala'],
#  ['thla', 'da', 'you', 'bgm'],
#  ['intha', 'padampothu', 'thalaya', 'asaikka', 'kooda', 'mudiyathu'],
#  ['nkp',
#   'million',
#   'views',
#   'varum',
#   'solravaga',
#   'thala',
#   'fans',
#   'hit',
#   'like',
#   'button',
#   'million',
#   'like'],
#  ['inga',
#   'neraya',
#   'arivalikalukku',
#   'teaserkum',
#   'trailer',
#   'kum',
#   'different',
#   'theriyama',
#   'vaitherichala',
#   'koovitu',
#   'irukkanga'],
#  ['super', 'super', 'super', 'super', 'star', 'rajini', 'sri', 'good'],
#  ['mind', 'blowing', 'ipo', 'paarunga', 'therikka', 'vitudalam'],
#  ['idhupola',
#   'vetradhu',
#   'kuthradhulam',
#   'pls',
#   'kaamikadhinga',
#   'screen',
#   'la',
#   'padatha',
#   'paathuthaan',
#   'paadhi',
#   'samudhayam',
#   'kedudhu',
#   'all',
#   'the',
#   'best',
#   'for',
#   'the',
#   'team'],
#  ['semma',
#   'thala',
#   'nee',
#   'vera',
#   'level',
#   'nee',
#   'onnaya',
#   'paratta',
#   'vaarthaiye',
#   'illa',
#   'fantastic',
#   'thala'],
#  ['king',
#   'of',
#   'kollywood',
#   'one',
#   'only',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala'],
#  ['marana',
#   'masss',
#   'thalaiva',
#   'hollywood',
#   'deractor',
#   'la',
#   'vaya',
#   'polaka',
#   'poranugga'],
#  ['thala', 'mass', 'but', 'court', 'room', 'perusa', 'irundhurkalam'],
#  ['idhu',
#   'padam',
#   'da',
#   'ommla',
#   'enna',
#   'padam',
#   'da',
#   'i',
#   'saw',
#   'shows',
#   'back',
#   'to',
#   'back',
#   'vera',
#   'level'],
#  ['pakkaaa', 'message', 'polathalaivaaa', 'we', 'are', 'waiting'],
#  ['thalapathy',
#   'kku',
#   'evlo',
#   'massss',
#   'irukka',
#   'pootho',
#   'thalapathy',
#   'lokeshkanagaraj'],
#  ['tamil',
#   'nadimarke',
#   'oru',
#   'puthiya',
#   'velluvilliakkumooo',
#   'manju',
#   'chechiudea',
#   'puthiya',
#   'entry'],
#  ['nammaku',
#   'tevaiyanada',
#   'namma',
#   'taan',
#   'adichi',
#   'vaanganum',
#   'padipa',
#   'mattum',
#   'nammakitta',
#   'irundu',
#   'edutuka',
#   'mudiyathu'],
#  ['ennayyanamma',
#   'makkal',
#   'selvan',
#   'padam',
#   'trailerkke',
#   'oru',
#   'full',
#   'thalapathy',
#   'movie',
#   'paatha',
#   'alavukk',
#   'appadiye',
#   'silirpp',
#   'kottuth'],
#  ['last', 'dailog', 'inga', 'like', 'podunga'],
#  ['super',
#   'star',
#   'is',
#   'super',
#   'star',
#   'vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv',
#   'vv',
#   'nice',
#   'trailer',
#   'i',
#   'really',
#   'love',
#   'it'],
#  ['st',
#   'unga',
#   'thalaivara',
#   'age',
#   'ku',
#   'thaguntha',
#   'mathiri',
#   'natikka',
#   'sollunga',
#   'appuram',
#   'vijay',
#   'ajith',
#   'pathi',
#   'peasalam'],
#  ['naanum',
#   'thalavar',
#   'rasigan',
#   'than',
#   'enakku',
#   'akshaya',
#   'kumar',
#   'performance',
#   'than',
#   'pudichi',
#   'irukku',
#   'thalavara',
#   'dummy',
#   'ah',
#   'aakitanagaama',
#   'vai',
#   'illa',
#   'ya'],
#  ['vera', 'level', 'sk', 'bro', 'keep', 'going', 'huge'],
#  ['oruthar',
#   'mela',
#   'viswasatha',
#   'katrathuku',
#   'innorthara',
#   'yen',
#   'asinga',
#   'paduthuringa'],
#  ['last',
#   'dialague',
#   'semma',
#   'rasikanuku',
#   'advice',
#   'pannitaru',
#   'thala',
#   'super',
#   'thala'],
#  ['super', 'pa', 'thalapadhy', 'rasigar', 'saarba', 'vaalthukal'],
#  ['thala', 'ena', 'thala', 'ketta', 'mass', 'ah', 'irukiyae'],
#  ['thambi', 'naanga', 'hourslaya', 'm', 'neenga', 'yaaru', 'da', 'komali'],
#  ['appo',
#   'kabalieee',
#   'na',
#   'nerupuda',
#   'eppo',
#   'robot',
#   'na',
#   'chitti',
#   'o',
#   'version'],
#  ['waiting', 'm', 'likes', 'and', 'm', 'views'],
#  ['vayasu',
#   'analum',
#   'unga',
#   'style',
#   'um',
#   'alagum',
#   'innum',
#   'ungala',
#   'vitu',
#   'pogalaold',
#   'time',
#   'rajni',
#   'ah',
#   'pakaramariye',
#   'iruku'],
#  ['kaithi', 'thane', 'daw', 'intha', 'diwali', 'ku'],
#  ['ada', 'aamaigala', 'm', 'like', 'kooda', 'varlaya', 'aamai', 'ajith'],
#  ['realy', 'trailer', 'marana', 'massa', 'iruku', 'iam', 'waiting', 'petta'],
#  ['you',
#   'are',
#   'line',
#   'line',
#   'line',
#   'ithu',
#   'mari',
#   'neriya',
#   'neriya',
#   'neriya',
#   'neriya',
#   'padatthula',
#   'irukum',
#   'pola',
#   'iam',
#   'waiting'],
#  ['simion', 'sir', 'enga', 'irrukinga', 'sekiram', 'vanga'],
#  ['wow', 'mill', 'ns', 'views'],
#  ['back',
#   'to',
#   'back',
#   'super',
#   'blockbuster',
#   'movies',
#   'first',
#   'then',
#   'petta',
#   'rajnikanth',
#   'is',
#   'just',
#   'amaaaaaaazing'],
#  ['hatters',
#   'dislike',
#   'pannunalum',
#   'asuran',
#   'movie',
#   'kku',
#   'award',
#   'confirm',
#   'bypure',
#   'dhanush',
#   'anna',
#   'fan'],
#  ['dislike', 'pannravan', 'ratham', 'kakkai', 'saavan'],
#  ['i', 'am', 'waiting', 'for', 'nerkoonda', 'paarvai'],
#  ['vijay',
#   'vera',
#   'vera',
#   'vera',
#   'vetakaran',
#   'taan',
#   'da',
#   'venumm',
#   'ajith',
#   'nerya',
#   'nerya',
#   'nerya',
#   'nerya',
#   'nerya'],
#  ['thala',
#   'pathi',
#   'thappaa',
#   'cmnt',
#   'panura',
#   'kuchikari',
#   'movanlaam',
#   'odirunga'],
#  ['dislike', 'panavan', 'oruthanuku', 'poruthuruka', 'maatan', 'poogada'],
#  ['dei',
#   'kadisiya',
#   'style',
#   'dance',
#   'ah',
#   'parunga',
#   'da',
#   'ayyo',
#   'sema',
#   'thalaiva',
#   'cuteness',
#   'charisma',
#   'fight',
#   'sequel',
#   'banged',
#   'comeback'],
#  ['darbat',
#   'k',
#   'comment',
#   'varanum',
#   'k',
#   'like',
#   'varanum',
#   'view',
#   'million',
#   'varanum'],
#  ['shaktiman',
#   'madri',
#   'next',
#   'comedy',
#   'punda',
#   'aga',
#   'poren',
#   'sakadai',
#   'kelavan'],
#  ['thalaya',
#   'screen',
#   'la',
#   'parka',
#   'yarellam',
#   'marana',
#   'waiting',
#   'comment',
#   'pannunga',
#   'thala',
#   'rathangale'],
#  ['vada',
#   'chennai',
#   'jaygiromo',
#   'illayo',
#   'motha',
#   'sanda',
#   'seiyanum',
#   'asuran',
#   'namaku',
#   'theva',
#   'yanatha',
#   'nambha',
#   'tha',
#   'adichi',
#   'vanganum'],
#  ['wow', 'trailer', 'marana', 'waiting', 'diwali', 'ku'],
#  ['entha',
#   'trailer',
#   'best',
#   'nu',
#   'pakalam',
#   'like',
#   'asuran',
#   'cmnt',
#   'kaapan'],
#  ['comments',
#   'parka',
#   'vandha',
#   'padika',
#   'vandha',
#   'nanba',
#   'nanbigal',
#   'like',
#   'pannitu',
#   'pooga'],
#  ['thala', 'thaan', 'eppavume', 'ennudaya', 'role', 'maadal'],
#  ['it', 'is', 'superstar', 'rajini', 'not', 'rajni', 'spelling', 'mistake'],
#  ['remake',
#   'of',
#   'pink',
#   'movie',
#   'ah',
#   'apdiye',
#   'eduthurukeenga',
#   'oru',
#   'dialogue',
#   'kooda',
#   'maarama',
#   'but',
#   'fight',
#   'scene',
#   'extra',
#   'va'],
#  ['neraya',
#   'neraya',
#   'neraya',
#   'atha',
#   'yarkanave',
#   'nerachi',
#   'poitha',
#   'iruku',
#   'inum',
#   'yathuku',
#   'kaekura',
#   'iva',
#   'mutta',
#   'punda'],
#  ['eduthu', 'vainga', 'da', 'adutha', 'oscar', 'ah', 'asuran', 'ku'],
#  ['i', 'miss', 'you', 'ishwarya', 'rai', 'madam'],
#  ['mass', 'dhanush', 'manju', 'vetri'],
#  ['thalaivaaaaaaa',
#   'ungaluku',
#   'vayase',
#   'aaakathu',
#   'nee',
#   'mattum',
#   'thaa',
#   'thlaiva',
#   'mass',
#   'massuke',
#   'boss'],
#  ['thala', 'o', 'ku', 'aavathu', 'atleast', 'pre', 'announcement', 'pannunga'],
#  ['aptilam',
#   'nadakkathu',
#   'nadakka',
#   'kudathu',
#   'fire',
#   'on',
#   'eyes',
#   'thala'],
#  ['amam',
#   'eppa',
#   'puthu',
#   'trailer',
#   'poduvingo',
#   'mgr',
#   'kala',
#   'thu',
#   'padama',
#   're',
#   'release',
#   'panna',
#   'poran',
#   'gala'],
#  ['oruthar',
#   'mela',
#   'viswasam',
#   'kaatradhukaga',
#   'aduthavangala',
#   'edhuku',
#   'asinga',
#   'paduthuringasema',
#   'thalalove',
#   'from',
#   'thalapathy',
#   'fanzzzzz'],
#  ['entha',
#   'padathalaum',
#   'vivazya',
#   'pirachana',
#   'solraga',
#   'pola',
#   'oh',
#   'my',
#   'god'],
#  ['kaithi', 'ye', 'evlo', 'mass', 'ah', 'iruku', 'na', 'thalapathy'],
#  ['adra',
#   'sakka',
#   'thalaivaa',
#   'marana',
#   'mass',
#   'adi',
#   'thool',
#   'petta',
#   'pongal',
#   'petta',
#   'parrakk'],
#  ['maranam',
#   'mass',
#   'uh',
#   'maranam',
#   'tough',
#   'tharanum',
#   'athukku',
#   'avan',
#   'thaaan',
#   'poranthu',
#   'varanum'],
#  ['for', 'some', 'thala', 'thalapathy', 'fans'],
#  ['please', 'make', 'thalapathy', 'like', 'kaithi', 'visuals'],
#  ['nothing', 'to', 'say', 'just', 'goosebumps', 'thalarasigai'],
#  ['mass',
#   'mass',
#   'nu',
#   'soli',
#   'pavam',
#   'fight',
#   'ill',
#   'lathe',
#   'padathu',
#   'la',
#   'kuda',
#   'fight',
#   'varawaychitaga'],
#  ['to',
#   'yenna',
#   'swag',
#   'pa',
#   'thala',
#   'thala',
#   'pola',
#   'varuma',
#   'fdfs',
#   'from',
#   'karnataka'],
#  ['enada',
#   'tamil',
#   'cinema',
#   'eduka',
#   'sonna',
#   'hollywood',
#   'cinema',
#   'eduthu',
#   'vachirkinga'],
#  ['saavaratha',
#   'irunthalum',
#   'sanda',
#   'pottu',
#   'saaganum',
#   'bayanthu',
#   'kaalla',
#   'vizhunthu',
#   'saaga',
#   'kudathu',
#   'tharam'],
#  ['sethu',
#   'anna',
#   'voice',
#   'thalaivar',
#   'entry',
#   'kolla',
#   'gaandu',
#   'la',
#   'irukan',
#   'epo',
#   'varum',
#   'oh',
#   'nu'],
#  ['marana', 'mass', 'thalaiva', 'ungalukku', 'innu', 'vayasu', 'agale'],
#  ['intha',
#   'padam',
#   'kantippa',
#   'win',
#   'pannum',
#   'but',
#   'rajinikaga',
#   'illa',
#   'shankar',
#   'kaga',
#   'avaroda',
#   'talent',
#   'kaga'],
#  ['oru',
#   'oru',
#   'scenum',
#   'goosebumps',
#   'ahh',
#   'iruku',
#   'petta',
#   'parak',
#   'like',
#   'podunga',
#   'trailer',
#   'pathu',
#   'goosebumps',
#   'anuvanga'],
#  ['vijaya', 'vallu', 'movies', 'teesthunnaraa', 'inkaa', 'wow'],
#  ['nerkondapaarvai',
#   'superb',
#   'thala',
#   'pesura',
#   'yella',
#   'dialogues',
#   'kum',
#   'avar',
#   'kan',
#   'simtave',
#   'ella',
#   'vera',
#   'level',
#   'acting'],
#  ['petta', 'movie', 'atta', 'flop', 'old', 'man', 'sotta', 'boy'],
#  ['ena', 'da', 'bomma', 'padam', 'eduthu', 'vachirukeenga'],
#  ['semma', 'vera', 'level', 'like', 'hits'],
#  ['pink', 'movie', 'in', 'hindi', 'final', 'dialouge', 'superrrr'],
#  ['chinna', 'pulla', 'thanamaala', 'irukku', 'graphics', 'xd', 'xd'],
#  ['rajini', 'sir', 'telugu', 'fans', 'hit', 'a', 'like', 'here', 'rajinified'],
#  ['o',
#   'my',
#   'god',
#   'superstar',
#   'rajinikanth',
#   'navajuddin',
#   'siddiki',
#   'vijay',
#   'setupati',
#   'what',
#   'else',
#   'needed'],
#  ['marvel',
#   'paruppu',
#   'thannidc',
#   'upputamil',
#   'masala',
#   'kick',
#   'kadugu',
#   'krissh',
#   'vengayam',
#   'thakkali',
#   'hero',
#   'sambar'],
#  ['bayama', 'irukku', 'i', 'except', 'more', 'but', 'i', 'feel', 'sad'],
#  ['sethupathi', 'kaga', 'wait', 'panravangalam', 'kai', 'thoongunga'],
#  ['tamil',
#   'movie',
#   'o',
#   'king',
#   'in',
#   'india',
#   'wonder',
#   'super',
#   'star',
#   'an',
#   'sankars',
#   'mass',
#   'movie'],
#  ['st', 'day', 'st', 'show', 'poravanga', 'like', 'potuttu', 'ponga'],
#  ['sprb', 'shradha', 'srinath', 'done', 'a', 'good', 'job'],
#  ['ennoda',
#   'phone',
#   'ah',
#   'yaaralum',
#   'control',
#   'panna',
#   'mudiyadhu',
#   'akshay',
#   'kumar',
#   'ah',
#   'tension',
#   'aayiduvan',
#   'idhu',
#   'hang',
#   'aguradha',
#   'paathu'],
#  ['rajini', 'kanth', 'fans', 'hit', 'like', 'here'],
#  ['kola',
#   'gaadula',
#   'iruka',
#   'thalaivaaaaaaaa',
#   'waiting',
#   'layea',
#   'veri',
#   'aaguthey'],
#  ['get', 'readysk', 'force', 'part', 'part', 'varavaipomaaaaaa'],
#  ['omg', 'use', 'head', 'phones', 'enna', 'bgm', 'da', 'saami'],
#  ['petta', 'uthikum', 'visvasam', 'hit', 'agum'],
#  ['enpt',
#   'release',
#   'agalanu',
#   'kavala',
#   'illa',
#   'aurathanamana',
#   'asuran',
#   'varuthu',
#   'adhu',
#   'pothum'],
#  ['those',
#   'vfx',
#   'nalla',
#   'illa',
#   'daaaw',
#   'guys',
#   'idhu',
#   'trailer',
#   'dhaan',
#   'maa',
#   'main',
#   'picture',
#   'is',
#   'coming',
#   'maranamass'],
#  ['vera', 'level', 'thala', 'you', 'r', 'rock'],
#  ['lokesh', 'kanagaraj', 'movie', 'naalae', 'english', 'rapsong', 'vandurum'],
#  ['what',
#   'a',
#   'trailer',
#   'ya',
#   'vera',
#   'level',
#   'la',
#   'irukuyow',
#   'karthi',
#   'subburaj',
#   'pinnida',
#   'ya',
#   'awesome',
#   'awesome'],
#  ['thalada', 'all', 'india', 'thala', 'kottai'],
#  ['indha', 'kalatholo', 'siva', 'karthikeyan', 'nadike', 'mudiyadhu'],
#  ['evano',
#   'indha',
#   'video',
#   'ku',
#   'dislike',
#   'button',
#   'amuka',
#   'vandhurundha',
#   'odiru',
#   'kolaa',
#   'kaandu',
#   'la',
#   'irukan',
#   'kollama',
#   'vida',
#   'matan'],
#  ['mujhe',
#   'kuch',
#   'samajh',
#   'sirf',
#   'vfx',
#   'tu',
#   'achh',
#   'hai',
#   'hai',
#   'lekin',
#   'utna',
#   'dam',
#   'nahi',
#   'jitna',
#   'zero',
#   'ka',
#   'trailer',
#   'me',
#   'hai'],
#  ['title', 'card', 'bgm', 'vara', 'level', 'nu', 'soluravuga', 'like', 'pl'],
#  ['rijini',
#   'sir',
#   'nadichirukaru',
#   'rompa',
#   'nalaiku',
#   'piragu',
#   'sema',
#   'treatuuuuu'],
#  ['thala', 'nkp', 'kaga', 'wait', 'panravan', 'like', 'panunga'],
#  ['climax', 'la', 'judge', 'kathiyeh', 'heart', 'attack', 'shethuduvaaraah'],
#  ['mokka', 'palaya', 'film', 'sayal', 'niraya', 'irukku'],
#  ['mokka', 'ah', 'irukkum', 'nu', 'confirn', 'pannittenga'],
#  ['hours', 'm', 'view', 's', 'k', 'like', 's', 'nkp'],
#  ['thala', 'you', 'bgm'],
#  ['surya',
#   'thambi',
#   'karthi',
#   'poii',
#   'karthi',
#   'oda',
#   'anna',
#   'tha',
#   'surya',
#   'airuchuu'],
#  ['now', 'you', 'are', 'lying', 'lying', 'lying', 'thala', 'mass'],
#  ['namaku', 'thevayanathu', 'nammatha', 'adichi', 'vaanganum', 'masssssssss'],
#  ['deepawali',
#   'kala',
#   'katta',
#   'pothu',
#   'bigil',
#   'kaithi',
#   'sanga',
#   'thamizhan'],
#  ['common', 'thala', 'fans', 'm', 'likes', 'varanum'],
#  ['yeppo',
#   'million',
#   'like',
#   'aagum',
#   'nu',
#   'pakka',
#   'wait',
#   'pannittu',
#   'irruka'],
#  ['that', 'bike', 'is', 'a', 'modified', 'duke'],
#  ['last', 'dialogue', 'semma', 'thala', 'tucker', 'doi'],
#  ['abhay', 'deol'],
#  ['thala', 'veriyans', 'maddum', 'oru', 'like', 'poddu', 'vidunga', 'bro'],
#  ['starting', 'looks', 'like', 'king', 'liar', 'malayalam', 'movie'],
#  ['good',
#   'morning',
#   'guys',
#   'kaalaila',
#   'ezhunthathum',
#   'trailer',
#   'paakka',
#   'vanthavangala',
#   'like',
#   'podunga'],
#  ['enna', 'da', 'views', 'ivlo', 'kammiya', 'iruku', 'romba', 'nerama'],
#  ['dai',
#   'mokka',
#   'vetri',
#   'mara',
#   'unaku',
#   'yethrathamanna',
#   'kathaiyee',
#   'eduka',
#   'theriyatha'],
#  ['ethir', 'paartha', 'alavu', 'ila', 'sadness'],
#  ['sema',
#   'thala',
#   'merattal',
#   'movie',
#   'eppo',
#   'paaka',
#   'poromnu',
#   'romba',
#   'aarvama',
#   'irukku',
#   'thala'],
#  ['ena', 'ipa', 'trending', 'la', 'varuthu', 'thalaivar', 'eh'],
#  ['karthi', 'annaaaa', 'vera', 'level', 'acting'],
#  ['national', 'award', 'ah', 'askar', 'ah', 'dhanush', 'fanz', 'like'],
#  ['padam',
#   'peru',
#   'sangathamizhan',
#   'producer',
#   'yaru',
#   'na',
#   'bharathireddy',
#   'what',
#   'an',
#   'irony'],
#  ['anirudh', 'bgmmmmmm', 'bang', 'bang', 'bang', 'petttaaaa', 'paaaraaaaaak'],
#  ['inga',
#   'rajini',
#   'ya',
#   'pathi',
#   'mattum',
#   'comment',
#   'pannunga',
#   'nan',
#   'vijay',
#   'sethupathika',
#   'papen',
#   'aniruthuka',
#   'papen',
#   'apdina',
#   'adichu',
#   'underwearoda',
#   'oda',
#   'vituventhalaivar',
#   'forever'],
#  ['viswasam', 'jan', 'thaane', 'clash', 'aavathu', 'ninaikkiren'],
#  ['trailer', 'la', 'vidya', 'balan', 'missing', 'why'],
#  ['sangar', 'sangar', 'ra', 'etha', 'movie', 'direct', 'pannala'],
#  ['i',
#   'think',
#   'sivakarthickku',
#   'hero',
#   'getup',
#   'set',
#   'aagala',
#   'trailer',
#   'is',
#   'goodbut',
#   'movie',
#   'average',
#   'pogumnu',
#   'ninaikiravanga',
#   'like',
#   'pannuga'],
#  ['ajith', 'sir', 't', 'h', 'a', 'l', 'a'],
#  ['arjun', 'sir', 'looking', 'very', 'smart', 'and', 'handsome'],
#  ['attention',
#   'thala',
#   'fans',
#   'indha',
#   'padam',
#   'block',
#   'buster',
#   'aaguradhukkuu',
#   'neega',
#   'dhaan',
#   'theater',
#   'ku',
#   'poooi',
#   'thalai',
#   'ku',
#   'periya',
#   'flexkatout',
#   'vaikanummm'],
#  ['times', 'ku', 'mela', 'pathavanga', 'like', 'podunga'],
#  ['i', 'am', 'big', 'for', 'illaya', 'super', 'star', 'dhanush'],
#  ['simran', 'rajinikanth', 'vijay', 'sethupathi'],
#  ['i', 'phone', 'vs', 'android', 'nu', 'ninaikiren'],
#  ['trailer',
#   'la',
#   'nallathan',
#   'da',
#   'irukku',
#   'padam',
#   'mokkaiya',
#   'illama',
#   'iruntha',
#   'sari'],
#  ['innoru', 'vakkil', 'rangaraj', 'pandey', 'dhana', 'avaru'],
#  ['ini',
#   'jenmathhuku',
#   'meethane',
#   'hydrocarbon',
#   'pathhi',
#   'nenachi',
#   'kooda',
#   'paaka',
#   'mudiyaadhu',
#   'corporates',
#   'ela',
#   'padamum',
#   'ini',
#   'adhapathi',
#   'daan'],
#  ['thala',
#   'seekirom',
#   'theatre',
#   'ku',
#   'va',
#   'thala',
#   'ennala',
#   'wait',
#   'panna',
#   'mudiyala'],
#  ['marana',
#   'mass',
#   'ungaluku',
#   'vayasu',
#   'aanalum',
#   'andha',
#   'style',
#   'apadiye',
#   'iruku',
#   'thalaivaaaaaaa'],
#  ['kamala', 'kalasa', 'en', 'thlaivan', 'dance', 'mass', 'ah'],
#  ['sakthimaan',
#   'sollidu',
#   'thovaikira',
#   'kallulanthu',
#   'kila',
#   'vilunthu',
#   'adipattavanka',
#   'like',
#   'pannuga',
#   'thaiyal',
#   'enaku'],
#  ['thala', 'da', 'i', 'love', 'you', 'thala'],
#  ['super', 'super', 'super', 'super', 'star'],
#  ['mmmm', 'times', 'this', 'video', 'see'],
#  ['thalaivarea',
#   'kaalioda',
#   'aatatha',
#   'neenga',
#   'kaatitinga',
#   'ini',
#   'thooku',
#   'thurai',
#   'oda',
#   'alaparaiya',
#   'naalaiku',
#   'ku',
#   'paapinga'],
#  ['nanga', 'late', 'ahh', 'vandhalum', 'latest', 'ah', 'varuvom'],
#  ['sema', 'anna', 'lv', 'you', 'karthi', 'anna'],
#  ['how', 'many', 'of', 'you', 'life', 'rajini'],
#  ['waiting',
#   'for',
#   'judgement',
#   'day',
#   'nerkonda',
#   'paarvai',
#   'trailer',
#   'marana',
#   'mass',
#   'thalaaaaaaaa'],
#  ['ippo',
#   'yana',
#   'pana',
#   'poram',
#   'sweet',
#   'sapada',
#   'poram',
#   'love',
#   'you',
#   'thalavaaaaaaaaaa'],
#  ['sethupathi',
#   'padam',
#   'pakkum',
#   'pothu',
#   'irutha',
#   'mass',
#   'scenes',
#   'niyabagam',
#   'varudhu'],
#  ['paaaaaaa',
#   'more',
#   'thaaan',
#   'hollywood',
#   'range',
#   'excited',
#   'to',
#   'have',
#   'watch',
#   'over',
#   'it'],
#  ['like', 'icon', 'ah', 'terika', 'vidalama', 'thala', 'bloods'],
#  ['yow',
#   'songs',
#   'epo',
#   'ya',
#   'viduvinga',
#   'bgm',
#   'verra',
#   'level',
#   'thalaforever'],
#  ['thaka', 'fans', 'ah', 'iru', 'dha', 'like', 'poduga'],
#  ['thala', 'un', 'rasiganu', 'solla', 'santhsama', 'karvama', 'irukku'],
#  ['pandey', 'and', 'thala', 'argument', 'super', 'thala', 'nadakakuduthu'],
#  ['m', 'views', 'in', 'min'],
#  ['fulla', 'un', 'thiruvizha', 'tha', 'dhaunsh', 'anna'],
#  ['yan',
#   'daa',
#   'like',
#   'podrathu',
#   'easy',
#   'nu',
#   'unga',
#   'ishtathukku',
#   'ethuku',
#   'like',
#   'athuku',
#   'comment',
#   'nu',
#   'podringlaa',
#   'ethellaam',
#   'oru',
#   'polappu'],
#  ['mana', 'thalvair', 'epaime', 'gethuda', 'sema', 'inda', 'pongal'],
#  ['indias', 'pride', 'shankar', 'sir', 'team'],
#  ['gud',
#   'morning',
#   'thala',
#   'bloodsenna',
#   'nanba',
#   'readyaviswasam',
#   'trailerku',
#   'senja',
#   'sambavatha',
#   'vida',
#   'sirapaa',
#   'siyanum'],
#  ['unga',
#   'nalla',
#   'manasuku',
#   'epayum',
#   'vettri',
#   'than',
#   'thala',
#   'ungaluku',
#   'phinix',
#   'bird',
#   'thala',
#   'nenga',
#   'vizhamattinga'],
#  ['million', 'likes', 'kondu', 'varanum', 'keep', 'share', 'thala', 'bloods'],
#  ['oru', 'channel', 'la', 'sona', 'marie', 'pana', 'matingala', 'daaa', 'dei'],
#  ['fight', 'scene', 'kola', 'mass', 'vera', 'level'],
#  ['yuvan', 'bgm'],
#  ['m', 'like', 'varathu', 'pola', 'nalaki', 'kuda', 'sethu'],
#  ['nee',
#   'nadigan',
#   'enpadhukaga',
#   'un',
#   'rasigar',
#   'illa',
#   'nalla',
#   'manithan'],
#  ['oruthar',
#   'mela',
#   'viswasam',
#   'katradhukaga',
#   'inoruthara',
#   'aen',
#   'asingapaduthringa',
#   'sema',
#   'thala'],
#  ['intha',
#   'maari',
#   'movie',
#   'tamil',
#   'cinema',
#   'la',
#   'vanthathu',
#   'ila',
#   'movie',
#   'vanthurukum',
#   'da'],
#  ['dei', 'yennada', 'marvel', 'maari', 'kondu', 'varinga'],
#  ['not', 'bad', 'any', 'way', 'karthik', 'flop', 'agama', 'iruka'],
#  ['waiting', 'thalapathy', 'lokesh', 'kanagaraj'],
#  ['trending', 'no', 'thala', 'youtube', 'king', 'thala'],
#  ['vera', 'levelu', 'thalaivar', 'always', 'i', 'love', 'thalaivar'],
#  ['ajith',
#   'acting',
#   'matha',
#   'movie',
#   'la',
#   'ellam',
#   'nalla',
#   'irunthathubut',
#   'nerkonda',
#   'parvai',
#   'trailer',
#   'romba',
#   'mokkaya',
#   'tha',
#   'iruku'],
#  ['romba', 'naalaiku', 'apuram', 'oru', 'rajini', 'padam'],
#  ['sexy',
#   'shradhaa',
#   'ava',
#   'unmeyave',
#   'virgin',
#   'ille',
#   'avala',
#   'poyi',
#   'kekera',
#   'kelveeya',
#   'adhe'],
#  ['semma', 'mass', 'chiyan', 'vikram', 'sir', 'i', 'am', 'waiting'],
#  ['enga',
#   'thalastzit',
#   'parvaila',
#   'avar',
#   'gethana',
#   'kuralila',
#   'summa',
#   'kalakuraru',
#   'pa',
#   'thala',
#   'da'],
#  ['surya',
#   'vathu',
#   'mairavathu',
#   'nethan',
#   'than',
#   'thalaiva',
#   'nadipin',
#   'arakkan'],
#  ['naa',
#   'trailer',
#   'ah',
#   'thalaivar',
#   'kaga',
#   'pakka',
#   'varalavj',
#   'sethu',
#   'anna',
#   'kaga',
#   'than',
#   'pakka',
#   'vandhurukken'],
#  ['lokesh', 'kanagaraj', 'fans', 'leave', 'a', 'like'],
#  ['trending', 'la', 'naanga', 'thanada', 'no'],
#  ['thala', 'ku', 'aaga', 'dhaan', 'padamae', 'pola'],
#  ['pariyerum',
#   'perumal',
#   'ku',
#   'award',
#   'varala',
#   'but',
#   'next',
#   'time',
#   'indha',
#   'movie',
#   'ku',
#   'kedaikanum'],
#  ['amaa',
#   'eppa',
#   'yenna',
#   'pannaporomm',
#   'ahaaaa',
#   'sweet',
#   'sapdaa',
#   'poroomm'],
#  ['kaidhi',
#   'vera',
#   'lvl',
#   'trailer',
#   'idhaa',
#   'dewali',
#   'kaidhii',
#   'dhaa',
#   'king'],
#  ['thalaivaaa', 'verithanam', 'apdye', 'chumma', 'therikkavidra'],
#  ['the',
#   'end',
#   'by',
#   'chiyan',
#   'you',
#   'kena',
#   'tunggu',
#   'lebih',
#   'lama',
#   'lagi',
#   'untuk',
#   'thosai',
#   'rocking',
#   'bh'],
#  ['love', 'you', 'thala', 'dulquer', 'salmaan', 'fans', 'kerala'],
#  ['nan',
#   'thalaivre',
#   'tralare',
#   'ra',
#   'tamies',
#   'ku',
#   'mela',
#   'pathuten',
#   'i',
#   'am',
#   'whating',
#   'asuran'],
#  ['k', 'views', 'k', 'likes'],
#  ['haters', 'in', 'world', 'chiyaan', 'vikram'],
#  ['marana', 'maass', 'thalaivaaa', 'i', 'love', 'you', 'sir'],
#  ['yenga', 'anna', 'yeppov', 'super', 'hero', 'dhan'],
#  ['bro',
#   'thalapathy',
#   'fans',
#   'kuda',
#   'nalla',
#   'irukku',
#   'nu',
#   'solranga',
#   'romba',
#   'happy',
#   'ya',
#   'irukku'],
#  ['thala',
#   'and',
#   'yuvan',
#   'like',
#   'ha',
#   'therika',
#   'vidungada',
#   'pasangalabgm',
#   'vera',
#   'level'],
#  ['trailer', 'pala', 'thadava', 'parthavanga', 'mattum', 'our', 'like'],
#  ['video',
#   'pakrathuku',
#   'munnadiye',
#   'like',
#   'pannavanga',
#   'mattum',
#   'kai',
#   'ah',
#   'thookunga'],
#  ['k', 'naraya', 'naraya', 'naraya', 'naraya', 'naraya', 'naraya'],
#  ['i', 'am', 'waiting', 'vera', 'level', 'trailer', 'i', 'ever', 'seen'],
#  ['maranam',
#   'maranam',
#   'maranam',
#   'last',
#   'bgm',
#   'therikkudhu',
#   'gv',
#   'bro',
#   'vera',
#   'level'],
#  ['yevanavathu', 'yuvan', 'bgm', 'pathi', 'pesurangala', 'nu', 'paaru'],
#  ['viswasam', 'teaser', 'ku', 'wait', 'panravan', 'like', 'podu'],
#  ['super', 'star', 'petta', 'pongal', 'petta', 'paraak'],
#  ['thalaivar', 'thalaivarr'],
#  ['oruthara',
#   'mela',
#   'nenga',
#   'viswasam',
#   'katrathukagainoruthara',
#   'yen',
#   'asinga',
#   'paduthuringa',
#   'sema'],
#  ['mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass'],
#  ['bgm', 'vera', 'level', 'gvpvetri', 'maaran', 'no', 'words'],
#  ['antha', 'padatha', 'vida', 'intha', 'padam', 'nalla', 'irukum', 'poliye'],
#  ['wow', 'nice', 'trailer', 'rajini', 'kant', 'super', 'star'],
#  ['thalaivaaaaaaaa', 'days', 'to', 'go', 'thalaivaru', 'tharisanam'],
#  ['comment',
#   'pakka',
#   'vandha',
#   'nanba',
#   'nanbigal',
#   'like',
#   'pannitu',
#   'pooga'],
#  ['today',
#   'trailer',
#   'paaththu',
#   'padam',
#   'paakka',
#   'wait',
#   'panravangka',
#   'like',
#   'podungka'],
#  ['adichu', 'under', 'wear', 'oda', 'oda', 'vitralama'],
#  ['ratchasan',
#   'music',
#   'mari',
#   'eruku',
#   'startngla',
#   'enaku',
#   'matum',
#   'tha',
#   'apdi',
#   'thonutho'],
#  ['ithu', 'peru', 'thaan', 'pakka', 'masswoww', 'goosebumbs'],
#  ['viswasam',
#   'trailor',
#   'hrs',
#   'la',
#   'vandha',
#   'like',
#   'kooda',
#   'indha',
#   'trailor',
#   'ku',
#   'ithana',
#   'naal',
#   'la',
#   'varala'],
#  ['fully',
#   'rajinism',
#   'thalaivaaaaaa',
#   'mass',
#   'fdfs',
#   'kalakata',
#   'poguthu',
#   'thalaivaaaaaa'],
#  ['paeru',
#   'dhanushyou',
#   'national',
#   'award',
#   'winner',
#   'dhanushyou',
#   'kaelvi',
#   'patrukeengala',
#   'verithanamaa',
#   'waiting',
#   'for',
#   'asuran'],
#  ['thalaiver', 'mass', 'super', 'star', 'rajini'],
#  ['vetrimaran', 'erukara', 'varaikum', 'dhanush', 'ku', 'no', 'tension'],
#  ['nanba', 'sekaram', 'like', 'm', 'kontu', 'vaaga'],
#  ['karthi', 'padathula', 'ithu', 'oru', 'nalla', 'padam'],
#  ['krish', 'movie', 'fans', 'like', 'here'],
#  ['t',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a',
#   't',
#   'a',
#   'a'],
#  ['chiyaan',
#   'vikram',
#   'sir',
#   'i',
#   'like',
#   'you',
#   'r',
#   'costume',
#   'i',
#   'like',
#   'you',
#   'r',
#   'moment'],
#  ['inum', 'm', 'likes', 'kuda', 'varala'],
#  ['semmaya',
#   'erukku',
#   'trailer',
#   'enga',
#   'anna',
#   'eppovum',
#   'grate',
#   'hero',
#   'dha',
#   'love',
#   'you',
#   'sk',
#   'anna'],
#  ['ne', 'ala', 'vijay', 'muturatha', 'kudikerked', 'tha', 'laki'],
#  ['petta', 'movie', 'pakka', 'yarellam', 'wait', 'panringa'],
#  ['srk', 'fan', 'plz', 'dislike', 'tha', 'video'],
#  ['last',
#   'vara',
#   'dialog',
#   'thavaravera',
#   'onnum',
#   'edupadala',
#   'movie',
#   'ya',
#   'paathutu',
#   'comment',
#   'pandren'],
#  ['will', 'blockbuster', 'yes', 'like', 'no', 'comment'],
#  ['yaarlam', 'teejay', 'ah', 'patheenga'],
#  ['hindi',
#   'la',
#   'youa',
#   'certificate',
#   'tamil',
#   'la',
#   'you',
#   'certificate',
#   'yepdi',
#   'da',
#   'dei',
#   'yellarum',
#   'india',
#   'la',
#   'thaane',
#   'irukkom'],
#  ['valimai', 'kku', 'wait', 'panravanga', 'thatra', 'likes', 'ah'],
#  ['aiyooo',
#   'ithu',
#   'petta',
#   'illa',
#   'thalaivar',
#   'settaaaayena',
#   'style',
#   'yena',
#   'alaga',
#   'katirukanunga',
#   'semmaaaa'],
#  ['marana',
#   'mass',
#   'thala',
#   'end',
#   'fight',
#   'vera',
#   'level',
#   'look',
#   'semma',
#   'mass',
#   'ah',
#   'eruku'],
#  ['movie', 'la', 'night', 'shots', 'neraya', 'iruku'],
#  ['chindhamani', 'kolakkes', 'like', 'podra'],
#  ['yaar',
#   'ellaam',
#   'thala',
#   'ah',
#   'theater',
#   'la',
#   'paarka',
#   'marana',
#   'waiting',
#   'la',
#   'irukinga',
#   'oru',
#   'like',
#   'podunga'],
#  ['jan', 'ke', 'pongal', 'start', 'aakuthu'],
#  ['wow',
#   'wow',
#   'wow',
#   'thalaivaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa',
#   'proud',
#   'to',
#   'be',
#   'every',
#   'indian',
#   'thanks',
#   'to',
#   'shankar',
#   'sir',
#   'and',
#   'holl',
#   'team'],
#  ['kichadi',
#   'padhiri',
#   'ella',
#   'english',
#   'padathaiyum',
#   'mix',
#   'panni',
#   'irrukkan',
#   'shankar',
#   'vera',
#   'level',
#   'pavam'],
#  ['super', 'like', 'is', 'equivalent', 'to', 'likes'],
#  ['oruthar',
#   'mela',
#   'neenga',
#   'viswasam',
#   'kaatrathukaga',
#   'innoruthar',
#   'enn',
#   'asinga',
#   'paduthu',
#   'ringa'],
#  ['rajini', 'sir', 'telugu', 'fans', 'like'],
#  ['last',
#   'dialogue',
#   'is',
#   'a',
#   'hint',
#   'to',
#   'his',
#   'fans',
#   'thala',
#   'mela',
#   'visvasam',
#   'kaatrathuku',
#   'thalapathy',
#   'ya',
#   'asinga',
#   'padutha',
#   'koodathu'],
#  ['trending', 'in', 'sri', 'lanka', 'i', 'am', 'very', 'happy', 'hit', 'like'],
#  ['no', 'means', 'no', 'thala', 'dialouge', 'delivery', 'super'],
#  ['oruthar',
#   'mela',
#   'neenga',
#   'viswasam',
#   'kaattradhukkaga',
#   'innoruthara',
#   'yen',
#   'asinga',
#   'paduthuringa'],
#  ['yarellam',
#   'morning',
#   'wake',
#   'up',
#   'aanathum',
#   'trailer',
#   'paakka',
#   'vanthinga'],
#  ['our', 'sirappaana', 'taramaana', 'movie', 'book', 'panna', 'poram'],
#  ['semmmmmmmaaaaaaaaaaaa', 'performance', 'thala', 'mrajith', 'sir', 'good'],
#  ['pongal', 'ke', 'confirm', 'sweet', 'sapada', 'porum'],
#  ['indha',
#   'pongaluku',
#   'release',
#   'ana',
#   'adutha',
#   'pongal',
#   'vara',
#   'odanumndravanga',
#   'like',
#   'podunga'],
#  ['thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala'],
#  ['ajith',
#   'solra',
#   'last',
#   'line',
#   'idha',
#   'yavadhu',
#   'pathu',
#   'thirundunga',
#   'da',
#   'dai'],
#  ['t', 'h', 'a', 'l', 'a'],
#  ['super', 'star', 'na', 'marana', 'mass', 'thaan'],
#  ['thala', 'awwsm', 'n', 'you', 'bgm', 'rocks'],
#  ['indha',
#   'padam',
# ...
#   'padathuku',
#   'competition',
#   'ah',
#   'irukkum'],
#  ['trailer', 'aa', 'vida', 'bgm', 'vera', 'level'],
#  ['last', 'dialogue', 'kettuttu', 'poi', 'thooku', 'matti', 'thongungada'],
#  ['lol',
#   'bigil',
#   'trailer',
#   'inum',
#   'release',
#   'agulaathukula',
#   'kaithi',
#   'n',
#   'bigil',
#   'compare',
#   'panitu',
#   'irukanga'],
#  ['namba',
#   'thala',
#   'ajith',
#   'smoke',
#   'panni',
#   'paathirikkuringla',
#   'thala',
#   'maari',
#   'nalla',
#   'manasu',
#   'endha',
#   'actor',
#   'ku',
#   'varum',
#   'never',
#   'evergiveup'],
#  ['toh', 'zero', 'who', 'will', 'win'],
#  ['bgm',
#   'gv',
#   'dhanush',
#   'sir',
#   'amazing',
#   'perfomance',
#   'vetri',
#   'sir',
#   'movie',
#   'nnaaa',
#   'summaavaaa'],
#  ['padam', 'vetripera', 'thalapathy', 'rasigargal', 'saarbil', 'valthukal'],
#  ['bgm',
#   'summa',
#   'therikuthuthala',
#   'dialog',
#   'delivery',
#   'vera',
#   'levelmass',
#   'you',
#   'fans',
#   'oru',
#   'like',
#   'pottutu',
#   'paarungam'],
#  ['hit',
#   'like',
#   'if',
#   'you',
#   'see',
#   'our',
#   'old',
#   'kanmadam',
#   'movie',
#   'manju',
#   'is',
#   'back'],
#  ['thala', 'is', 'rocking', 'by', 'surya', 'anna', 'fan'],
#  ['all',
#   'you',
#   'dislikes',
#   'persons',
#   'last',
#   'dialog',
#   'for',
#   'you',
#   'mad',
#   'peoples'],
#  ['rajni', 'sir', 'akki', 'storm', 'blockbuster', 'movie'],
#  ['mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'mass',
#   'masss',
#   'marana',
#   'mass',
#   'thalaiver',
#   'mass'],
#  ['i', 'am', 'waiting', 'waiting', 'waiting'],
#  ['h',
#   'vinoth',
#   'mass',
#   'sathuranga',
#   'vettai',
#   'theeran',
#   'narkonda',
#   'paarvai'],
#  ['maranam',
#   'ma',
#   'iruku',
#   'sekrama',
#   'movie',
#   'release',
#   'date',
#   'sllu',
#   'ga',
#   'marana',
#   'waiting',
#   'ah',
#   'iruku'],
#  ['wowwwwww', 'what', 'a', 'style', 'ya'],
#  ['more',
#   'than',
#   'times',
#   'pathuten',
#   'thala',
#   'pakka',
#   'pakka',
#   'veri',
#   'erudhu',
#   'love',
#   'you',
#   'thala'],
#  ['vijay', 'sethupathi', 'a', 'adhigama', 'kaatave', 'illa'],
#  ['vadachennai', 'left', 'la', 'poirum', 'polaye', 'vetri', 'nailed', 'it'],
#  ['vijay', 'sethupathya', 'pidichavan', 'like', 'ah', 'thatuu'],
#  ['ne', 'vaa', 'thalaivaa', 'nanga', 'irukom', 'la'],
#  ['m', 'super', 'millon', 'varathukku', 'help', 'pannunga', 'pleas'],
#  ['kaithi', 'deepavali', 'realise', 'i', 'am', 'waiting'],
#  ['vera', 'vera', 'level', 'da', 'version'],
#  ['k', 'likes', 'reached', 'aairuku', 'pangalingala', 'adichi', 'thookalamaa'],
#  ['in',
#   'hindi',
#   'pink',
#   'movie',
#   'amita',
#   'banchan',
#   'n',
#   'tapseee',
#   'in',
#   'tamil',
#   'nerkonda',
#   'paarvai',
#   'ajit',
#   'kumarshradda',
#   'srinath',
#   'semma'],
#  ['petta', 'pongalukku', 'sey', 'um', 'vasul', 'vetta'],
#  ['asuran',
#   'movie',
#   'ku',
#   'oscar',
#   'award',
#   'varum',
#   'nu',
#   'solluravanga',
#   'like',
#   'pannunga',
#   'friends'],
#  ['mo', 'oooooo', 'kkkkk', 'aaaaaa', 'daaaaa'],
#  ['kabalikaalaa',
#   'madhri',
#   'parapaiyan',
#   'padama',
#   'irundhapadam',
#   'odadhube',
#   'careful'],
#  ['trailer',
#   'vera',
#   'level',
#   'bgm',
#   'adukum',
#   'mela',
#   'karthi',
#   'acting',
#   'ultimate'],
#  ['mankatha', 'billa', 'type', 'la', 'thala', 'oru', 'movie', 'pannanum'],
#  ['comment',
#   'section',
#   'ool',
#   'mari',
#   'erukunu',
#   'soldravanga',
#   'like',
#   'this',
#   'watha',
#   'like',
#   'vechinu',
#   'ena',
#   'daw',
#   'sathika',
#   'poringa'],
#  ['dissapointedsaamy', 'trailer', 'is', 'bettervikram', 'mass'],
#  ['pahhh',
#   'vere',
#   'level',
#   'repeat',
#   'panni',
#   'paathaven',
#   'ellam',
#   'like',
#   'pode',
#   'thaledaa',
#   'thale'],
#  ['that',
#   'guyippa',
#   'namma',
#   'enna',
#   'panna',
#   'porom',
#   'thalaivarsweet',
#   'saapida',
#   'porom',
#   'vera',
#   'level'],
#  ['la',
#   'super',
#   'social',
#   'message',
#   'thala',
#   'vera',
#   'level',
#   'sir',
#   'nenga',
#   'i',
#   'love',
#   'you',
#   'thala',
#   'sir'],
#  ['sorry',
#   'to',
#   'say',
#   'action',
#   'king',
#   'arjun',
#   'sir',
#   'kaagaa',
#   'movie',
#   'pakka',
#   'poren'],
#  ['superb', 'thala', 'mass', 'i', 'am', 'waiting'],
#  ['thalaya',
#   'jeika',
#   'innoruthan',
#   'poranthu',
#   'varanum',
#   'da',
#   'verithanathin',
#   'utchakattam',
#   'da'],
#  ['intha',
#   'padam',
#   'flop',
#   'aaganum',
#   'ironman',
#   'fans',
#   'hit',
#   'like',
#   'here'],
#  ['thala', 'veriyan', 'mass', 'fans', 'like', 'here'],
#  ['naanum',
#   'thala',
#   'rasikan',
#   'thaan',
#   'aana',
#   'intha',
#   'padam',
#   'sema',
#   'mokkaiyathaan',
#   'irukkum',
#   'naan',
#   'intha',
#   'padaa',
#   'thha',
#   'paaka',
#   'theatrekke',
#   'pogamatten',
#   'mokkaiya',
#   'irukkum'],
#  ['edhu', 'speed', 'la', 'pathalum', 'semma', 'aa', 'thaa', 'iruku', 'dd'],
#  ['indha',
#   'trailerkagave',
#   'kudukalaamya',
#   'vaatiku',
#   'mela',
#   'paathuten',
#   'thalaiva',
#   'karthik',
#   'subburaju',
#   'enga',
#   'super',
#   'stara',
#   'getha',
#   'kaatirukaya'],
#  ['awards',
#   'ellam',
#   'eduthu',
#   'veinkada',
#   'thukitu',
#   'poga',
#   'asuran',
#   'team',
#   'varuthu'],
#  ['thalaaaaa', 'sema', 'i', 'love', 'you', 'thalaaaaaa'],
#  ['thala', 'vera', 'joner', 'la', 'irukar', 'super'],
#  ['ok', 'type', 'not', 'a', 'rajani', 'mark', 'trailer'],
#  ['dia',
#   'kena',
#   'tunggu',
#   'lama',
#   'lagi',
#   'untuk',
#   'tahu',
#   'sayahahaha',
#   'malay',
#   'dialogue',
#   'by',
#   'chiyaan'],
#  ['million', 'likes', 'varum', 'nu', 'solravanga', 'like', 'panunga'],
#  ['breaked', 'sarkar', 'views', 'in', 'hrs'],
#  ['kajal', 'fans', 'subscribe'],
#  ['sarkar',
#   'kitta',
#   'kooda',
#   'nerunga',
#   'mudiyala',
#   'just',
#   'million',
#   'views'],
#  ['yaruda',
#   'avanunga',
#   'vanthu',
#   'cinna',
#   'pulla',
#   'thanama',
#   'dislike',
#   'pannittu',
#   'irukkaranunga'],
#  ['trailer',
#   'vanthu',
#   'evaluvu',
#   'neram',
#   'aguthu',
#   'enga',
#   'trendingla',
#   'canom'],
#  ['ithu',
#   'yaroda',
#   'story',
#   'nu',
#   'first',
#   'eh',
#   'clarify',
#   'panidunga',
#   'padam',
#   'release',
#   'agum',
#   'podhu',
#   'yaru',
#   'story',
#   'nu',
#   'adichikadhinga'],
#  ['your', 'voice', 'kambiramma', 'irukku', 'sema', 'super', 'thala'],
#  ['thala', 'super', 'na', 'like', 'panuga'],
#  ['thalaaaaaaaaa', 'love', 'you', 'sirr', 'frm', 'andhra', 'pradesh'],
#  ['asuran',
#   'verithanamkaadu',
#   'eruntha',
#   'eduthukuvanga',
#   'kasu',
#   'eruntha',
#   'pudikiruvanga',
#   'ana',
#   'padipa',
#   'maittum',
#   'namba',
#   'kitta',
#   'eduthukavae',
#   'mudiyathu'],
#  ['bigil', 'vs', 'nerkonda', 'parvainane', 'answer', 'sollidranansbigil'],
#  ['enaku',
#   'kalakalappu',
#   'film',
#   'dialogue',
#   'nyabagam',
#   'thaan',
#   'varudhu',
#   'idhala',
#   'nambra',
#   'madhiri',
#   'anga',
#   'iruku'],
#  ['ammma', 'deee', 'yyyo', 'bgm', 'vara', 'laval'],
#  ['trailer',
#   'mairu',
#   'maari',
#   'iruku',
#   'but',
#   'padam',
#   'semmaya',
#   'irukum',
#   'nu',
#   'namburan'],
#  ['st', 'day', 'show', 'booked'],
#  ['ithu', 'tamil', 'nadu', 'ella', 'ithu', 'enga', 'thala', 'nadu'],
#  ['going',
#   'to',
#   'be',
#   's',
#   'kid',
#   'movie',
#   'thalaivaaaaaaa',
#   'vera',
#   'level',
#   'thalaivaaaa'],
#  ['mass', 'katradhuna', 'epdi', 'venalum', 'katalam', 'da'],
#  ['last', 'siva', 'karthikeyen', 'nnu', 'nenache'],
#  ['nkp',
#   'visvasam',
#   'asuran',
#   'music',
#   'sariyaana',
#   'mokka',
#   'avlo',
#   'worth',
#   'illa',
#   'trailer'],
#  ['goosebumps', 'vandha', 'like', 'podu'],
#  ['bat', 'man'],
#  ['kosu',
#   'adikara',
#   'machine',
#   'padam',
#   'pathavangaluku',
#   'mattun',
#   'than',
#   'puriyum'],
#  ['sathyama', 'ivlo', 'nalla', 'irukum', 'nu', 'ninaikala'],
#  ['ivan', 'munjikyu', 'heroins', 'kevalo', 'panipaye'],
#  ['never', 'ever', 'seen', 'vfx', 'like', 'this'],
#  ['s', 'kid', 'sakthiman', 'fans', 'hit', 'like'],
#  ['dai',
#   'evan',
#   'dislike',
#   'potalum',
#   'ellarukum',
#   'pudicha',
#   'trailor',
#   'adu',
#   'marathu',
#   'da',
#   'manga',
#   'madainungala',
#   'nkp',
#   'awesome'],
#  ['enga', 'ajith', 'munnadi', 'evan', 'oru', 'mairum', 'pudunga', 'mudiatha'],
#  ['watching',
#   'again',
#   'and',
#   'again',
#   'kolakandula',
#   'erukan',
#   'kolama',
#   'vidamatan'],
#  ['yarukkelam',
#   'dhanush',
#   'anna',
#   'movie',
#   'pudichirukko',
#   'avunga',
#   'like',
#   'pannunga'],
#  ['make', 'm', 'likes', 'as', 'soon', 'as', 'possible'],
#  ['vithule',
#   'soru',
#   'ilena',
#   'paravalepilenge',
#   'school',
#   'padikathiyum',
#   'paravaleanaactor',
#   'pi',
#   'manggu',
#   'vangi',
#   'tinnulenah',
#   'pundengeleke',
#   'thukomo',
#   'savo',
#   'varathu',
#   'phuikkk'],
#  ['dai',
#   'indha',
#   'rajini',
#   'ah',
#   'dhaan',
#   'da',
#   'pala',
#   'varshama',
#   'naanga',
#   'kekrom'],
#  ['diwali', 'ku', 'vidu', 'nga', 'bigil', 'ku', 'sangu'],
#  ['you', 'bgm', 'theri', 'mass', 'bgmukahavay', 'movie', 'paakkanum'],
#  ['court', 'scene', 'theater', 'summa', 'adhira', 'pogudhu', 'thalaaaaaaaa'],
#  ['vikram', 'sir', 'you', 'are', 'rockstar'],
#  ['kaithi',
#   'jeyil',
#   'layae',
#   'irrukirathu',
#   'nallathu',
#   'bigil',
#   'on',
#   'the',
#   'way'],
#  ['pink', 'remake', 'but', 'ajit', 'is', 'good'],
#  ['not', 'realistic', 'but', 'entertain', 'side', 'nokumpol', 'kollaam'],
#  ['ean', 'ya', 'unaku', 'intha', 'vendatha', 'velai'],
#  ['warning',
#   'to',
#   'another',
#   'movie',
#   'sentiment',
#   'irundhaa',
#   'oodi',
#   'poiru',
#   'kola',
#   'gandu',
#   'la',
#   'irukken',
#   'kollaama',
#   'vidamaaten'],
#  ['oruthar',
#   'mela',
#   'viswasam',
#   'kaatradhukagayn',
#   'inoruthara',
#   'kevala',
#   'paduthuringa'],
#  ['pakka',
#   'mass',
#   'daa',
#   'die',
#   'hard',
#   'fans',
#   'from',
#   'telugu',
#   'superb',
#   'abba'],
#  ['looks', 'like', 'remake', 'of', 'pink', 'movie'],
#  ['you', 'kola', 'mass', 'bgm', 'verithanam', 'pannitinga', 'ponga'],
#  ['pakkka', 'masss', 'vera', 'level'],
#  ['by', 'wo', 'ct', 'v', 'very', 'vy'],
#  ['like', 'super', 'trailer', 'blockbuster', 'movie'],
#  ['thala', 'fansna', 'sumava', 'sema', 'union', 'pa', 'pullarikuthu'],
#  ['i', 'from', 'karnataka', 'm', 'vikrams', 'fan'],
#  ['vera', 'level', 'rajini', 'is', 'the', 'mass'],
#  ['panday',
#   'nee',
#   'la',
#   'enga',
#   'thala',
#   'ku',
#   'opposite',
#   'ah',
#   'otha',
#   'poturuvom'],
#  ['ule',
#   'poyi',
#   'pani',
#   'noku',
#   'thalapaty',
#   'teaser',
#   'varattu',
#   'marana',
#   'milin',
#   'viwers',
#   'irukku',
#   'from',
#   'kerala'],
#  ['enga',
#   'thalaivanna',
#   'summava',
#   'ippo',
#   'paruda',
#   'indha',
#   'kaali',
#   'oda',
#   'aatatha',
#   'kaala',
#   'mudinchu',
#   'kaali',
#   'ya',
#   'vandhirukaruda'],
#  ['virtual',
#   'reality',
#   'la',
#   'uta',
#   'naangalum',
#   'veetlayey',
#   'd',
#   'la',
#   'papom',
#   'la'],
#  ['appada',
#   'kitta',
#   'thatta',
#   'varusama',
#   'oruthan',
#   'kitta',
#   'maatikittu',
#   'saavadichaaru',
#   'ipothan',
#   'konjam',
#   'vithiyasama',
#   'rasikira',
#   'mathiri',
#   'iruku',
#   'keep',
#   'it',
#   'up',
#   'thala'],
#  ['ajith',
#   'kumar',
#   'pera',
#   'theatre',
#   'pakkka',
#   'marana',
#   'waiting',
#   'thala',
#   'bloods'],
#  ['thala', 'ne', 'va', 'thala', 'vera', 'levala', 'thala'],
#  ['endha', 'timele', 'yar', 'yar', 'trailer', 'pathuttu', 'erukinge'],
#  ['aboorva', 'ragangal', 'love', 'you', 'thalaiva', 'thalapathy', 'fan'],
#  ['m', 'like', 'varum', 'nu', 'solluravangaa', 'mattum', 'like', 'poduga'],
#  ['sivakarthikyen', 'fans', 'like', 'here', 'from', 'andhra'],
#  ['ippo',
#   'yarlam',
#   'vanthu',
#   'teaser',
#   'pathinga',
#   'avangalam',
#   'oru',
#   'like',
#   'podunga'],
#  ['awsome', 'guru', 'i', 'love', 'you', 'thalava'],
#  ['marana', 'waiting', 'for', 'nkp', 'lub', 'you', 'thalaaaaaaaaaaaa'],
#  ['padan',
#   'ellam',
#   'nalla',
#   'than',
#   'irikkr',
#   'but',
#   'bigiloda',
#   'poatti',
#   'podradhudhan',
#   'neenga',
#   'aeira',
#   'periiiiiya',
#   'thappu'],
#  ['super',
#   'amazing',
#   'karthi',
#   'ji',
#   'we',
#   'are',
#   'waiting',
#   'for',
#   'karthi',
#   'by',
#   'thala',
#   'ajith',
#   'fans',
#   'club',
#   'karaikudi'],
#  ['next',
#   'kaappaan',
#   'pola',
#   'dei',
#   'eppa',
#   'swamy',
#   'poothum',
#   'da',
#   'unga',
#   'vivasayam',
#   'advise',
#   'athu',
#   'thaan',
#   'daily',
#   'seeman',
#   'solldrare'],
#  ['antha',
#   'abhirami',
#   'trailer',
#   'kooda',
#   'mental',
#   'maathiri',
#   'thaan',
#   'behave',
#   'panathu'],
#  ['neraya', 'neraya', 'neraya', 'neraya', 'goosebumps', 'moment', 'wow'],
#  ['dheena', 'fans', 'hit', 'like'],
#  ['trailer',
#   'mokka',
#   'ya',
#   'iruku',
#   'krish',
#   'trailer',
#   'pakkura',
#   'mari',
#   'iruku'],
#  ['soori', 'irukar', 'padam', 'confirm', 'flop', 'dhan'],
#  ['classana',
#   'movie',
#   'than',
#   'ithu',
#   'aana',
#   'ajith',
#   'kumar',
#   'apdingra',
#   'name',
#   'nala',
#   'mass',
#   'aaga',
#   'poguthu'],
#  ['vera', 'level', 'theater', 'le', 'terika', 'podhu'],
#  ['trailer', 'paakamaye', 'like', 'potavanga', 'hit', 'like'],
#  ['last',
#   'shot',
#   'la',
#   'semma',
#   'mass',
#   'erukapla',
#   'thalalow',
#   'angle',
#   'la',
#   'semma',
#   'gethu'],
#  ['love', 'you', 'thala', 'evalavu', 'alagu', 'da', 'thala'],
#  ['pandey', 'mass', 'ajith', 'sir', 'pakka', 'mass'],
#  ['sirapana', 'tharamana', 'sambhavam', 'by', 'karthik', 'subburaj'],
#  ['indha',
#   'karumatha',
#   'dha',
#   'raathiri',
#   'poora',
#   'ottitu',
#   'irundhiya',
#   'moment'],
#  ['cell',
#   'phone',
#   'ah',
#   'kaanoomaaaa',
#   'appoooo',
#   'siva',
#   'kumar',
#   'ah',
#   'thaan',
#   'keatkanum',
#   'oorela',
#   'iruka',
#   'yellaa',
#   'phoneayum',
#   'veri',
#   'thanama',
#   'veattayaadraan',
#   'yaaa'],
#  ['k', 'dislikes', 'maaha', 'maanadu', 'grps', 'pola'],
#  ['marana', 'mass', 'i', 'am', 'wach', 'for', 'marana', 'waitting'],
#  ['cell',
#   'phone',
#   'towernala',
#   'seththu',
#   'pora',
#   'sittu',
#   'kuruvi',
#   'manitharkalai',
#   'pali',
#   'vankum',
#   'kathai'],
#  ['speed', 'up', 'guys', 'likes', 'ah', 'therikka', 'vidunga'],
#  ['super', 'ajit', 'kumar', 'sir', 'from', 'andhra', 'pradesh', 'fans'],
#  ['yaaru', 'athu', 'music', 'director', 'bgm', 'vera', 'level', 'ya', 'yov'],
#  ['m', 'views', 'innum', 'etattum', 'thalaivaaaa'],
#  ['manusanuku',
#   'thala',
#   'mukkium',
#   'athupola',
#   'filmindustryku',
#   'ak',
#   'very',
#   'very',
#   'important'],
#  ['rajinii',
#   'sirrr',
#   'we',
#   'loveeee',
#   'you',
#   'alottt',
#   'hyderabadtelanganatamil',
#   'ajith',
#   'fan'],
#  ['atleast',
#   'million',
#   'views',
#   'likes',
#   'varavikaa',
#   'thala',
#   'fans',
#   'support',
#   'pannukaa'],
#  ['vera',
#   'level',
#   'sir',
#   'thalaaaa',
#   'ans',
#   'best',
#   'wishes',
#   'from',
#   'thalapathy',
#   'fans'],
#  ['karthik', 'fans', 'from', 'keralalike', 'adikk', 'makkale'],
#  ['thalaivar',
#   'asuran',
#   'ah',
#   'vanthurukarulast',
#   'la',
#   'bgm',
#   'vera',
#   'levell'],
#  ['thala', 'siva', 'combo', 'la', 'innoru', 'mass', 'padam', 'pannunga'],
#  ['music', 'verithanam', 'nu', 'solravanga', 'oru', 'like', 'ah', 'podunga'],
#  ['oruthavanga',
#   'mela',
#   'visvasam',
#   'katurathukaka',
#   'innoruthara',
#   'yen',
#   'asinga',
#   'paduthuringa',
#   'bhuhahhaha',
#   'mass',
#   'finishing',
#   'thala',
#   'dappu',
#   'takkaru',
#   'doiiii'],
#  ['at', 'you', 'king', 'of', 'bgm'],
#  ['neraya', 'neraya', 'neraya', 'neraya', 'neraya', 'neraya'],
#  ['manasa', 'badhicha', 'padamdhanushvetri', 'marangv', 'vera', 'level'],
#  ['nallave',
#   'illa',
#   'itha',
#   'poi',
#   'thala',
#   'mass',
#   'kola',
#   'mass',
#   'nu',
#   'soltringa'],
#  ['kola',
#   'kaandula',
#   'iruken',
#   'mavane',
#   'kollama',
#   'vidamaten',
#   'sema',
#   'dialogue'],
#  ['k', 'views', 'k', 'likes', 'super'],
#  ['ithu',
#   'ajith',
#   'padama',
#   'irukathu',
#   'but',
#   'ajith',
#   'sema',
#   'super',
#   'padama',
#   'irukum',
#   'nenaikuren'],
#  ['ayya', 'director', 'siva', 'konjam', 'pathu', 'panunga'],
#  ['dai', 'eppa', 'enna', 'da', 'ithu', 'semma', 'da', 'dai'],
#  ['rajini', 'sir', 'waiting', 'from', 'kerala'],
#  ['yean',
#   'p',
#   'la',
#   'patha',
#   'kuda',
#   'clarity',
#   'eh',
#   'ilama',
#   'iruku',
#   'phone',
#   'la',
#   'prblm',
#   'ah',
#   'ila',
#   'pixel',
#   'eh',
#   'ipadi',
#   'thanaa'],
#  ['pakka', 'rajini', 'film', 'like', 'if', 'you', 'agree'],
#  ['a', 's', 'you', 'r', 'a', 'n'],
#  ['padipai',
#   'mattrumdan',
#   'evanaliyum',
#   'eduthukola',
#   'mudiyad',
#   'nalla',
#   'vasanam',
#   'asuran',
#   'aalapogiran',
#   'all',
#   'the',
#   'best',
#   'for',
#   'the',
#   'teem'],
#  ['rajini', 'mass', 'and', 'shankar', 'veral', 'level'],
#  ['to', 'bgm', 'looks', 'like', 'padayappa', 'bgm'],
#  ['waiting', 'for', 'kalyani', 'priyadharsans', 'kollywood', 'entry'],
#  ['paaa', 'mass', 'makkalselvanepudi', 'ungala', 'pakkaa', 'thn', 'asapadrom'],
#  ['semmmaaa', 'mass', 'thalaaaa', 'lveee', 'uuu', 'always'],
#  ['thaaateaser', 'na', 'itha', 'da', 'teaseru', 'vera', 'leveluu'],
#  ['mount', 'hermon', 'darjeeling', 'superstar', 'rajni'],
#  ['k', 'likes', 'reached', 'aairuku'],
#  ['pppaaaaa', 'thala', 'back', 'to', 'citizen', 'vibez'],
#  ...]

# %% [markdown]
# ---
# # N-Gram

# %%
train, vocab = padded_everygram_pipeline(2, corpus)

# %%
for _ in range(10):
    print(list(next(train)))
# Out:
# [('<s>',), ('<s>', 'when'), ('when',), ('when', 'pandey'), ('pandey',), ('pandey', 'gets'), ('gets',), ('gets', 'up'), ('up',), ('up', 'vandumurugan'), ('vandumurugan',), ('vandumurugan', 'i'), ('i',), ('i', 'am'), ('am',), ('am', 'speaking'), ('speaking',), ('speaking', 'no'), ('no',), ('no', 'cross'), ('cross',), ('cross', 'speaking'), ('speaking',), ('speaking', 'sittt'), ('sittt',), ('sittt', 'downnn'), ('downnn',), ('downnn', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'remake'), ('remake',), ('remake', 'of'), ('of',), ('of', 'malayalam'), ('malayalam',), ('malayalam', 'mohanlal'), ('mohanlal',), ('mohanlal', 'movie'), ('movie',), ('movie', 'devadoodhan'), ('devadoodhan',), ('devadoodhan', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'tharamaana'), ('tharamaana',), ('tharamaana', 'sirappaana'), ('sirappaana',), ('sirappaana', 'sambavam'), ('sambavam',), ('sambavam', 'inimeal'), ('inimeal',), ('inimeal', 'ta'), ('ta',), ('ta', 'paaka'), ('paaka',), ('paaka', 'pora'), ('pora',), ('pora', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'viswasam'), ('viswasam',), ('viswasam', 'trailer'), ('trailer',), ('trailer', 'paathutu'), ('paathutu',), ('paathutu', 'inka'), ('inka',), ('inka', 'vanthavanga'), ('vanthavanga',), ('vanthavanga', 'like'), ('like',), ('like', 'panuga'), ('panuga',), ('panuga', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'maran'), ('maran',), ('maran', 'kattu'), ('kattu',), ('kattu', 'kattitamnue'), ('kattitamnue',), ('kattitamnue', 'verithanam'), ('verithanam',), ('verithanam', 'thalivaa'), ('thalivaa',), ('thalivaa', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'ella'), ('ella',), ('ella', 'trailer'), ('trailer',), ('trailer', 'la'), ('la',), ('la', 'last'), ('last',), ('last', 'la'), ('la',), ('la', 'oru'), ('oru',), ('oru', 'mass'), ('mass',), ('mass', 'dialouge'), ('dialouge',), ('dialouge', 'vaichikuringaaa'), ('vaichikuringaaa',), ('vaichikuringaaa', 'paaaa'), ('paaaa',), ('paaaa', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'eppa'), ('eppa',), ('eppa', 'saamy'), ('saamy',), ('saamy', 'thala'), ('thala',), ('thala', 'padathula'), ('padathula',), ('padathula', 'vera'), ('vera',), ('vera', 'director'), ('director',), ('director', 'perapakurathu'), ('perapakurathu',), ('perapakurathu', 'evalo'), ('evalo',), ('evalo', 'periya'), ('periya',), ('periya', 'santhosama'), ('santhosama',), ('santhosama', 'iruku'), ('iruku',), ('iruku', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'en'), ('en',), ('en', 'thalaivan'), ('thalaivan',), ('thalaivan', 'vijaysethubathi'), ('vijaysethubathi',), ('vijaysethubathi', 'kaga'), ('kaga',), ('kaga', 'matume'), ('matume',), ('matume', 'na'), ('na',), ('na', 'padam'), ('padam',), ('padam', 'papan'), ('papan',), ('papan', 'matha'), ('matha',), ('matha', 'entha'), ('entha',), ('entha', 'p'), ('p',), ('p', 'illa'), ('illa',), ('illa', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'kanithan'), ('kanithan',), ('kanithan', 'mugamoodi'), ('mugamoodi',), ('mugamoodi', 'neenga'), ('neenga',), ('neenga', 'nambalainalum'), ('nambalainalum',), ('nambalainalum', 'ithan'), ('ithan',), ('ithan', 'nesam'), ('nesam',), ('nesam', '</s>'), ('</s>',)]
# [('<s>',), ('<s>', 'enakku'), ('enakku',), ('enakku', 'iru'), ('iru',), ('iru', 'mugan'), ('mugan',), ('mugan', 'trailer'), ('trailer',), ('trailer', 'gnabagam'), ('gnabagam',), ('gnabagam', 'than'), ('than',), ('than', 'varuthu'), ('varuthu',), ('varuthu', '</s>'), ('</s>',)]

# %%
lm = MLE(2)

# %%
len(lm.vocab)
# Out:
# 0

# %%
lm.fit(train, vocab)

# %%
print(lm.vocab)
# Out:
# <Vocabulary with cutoff=1 unk_label='<UNK>' and 18404 items>

# %%
len(lm.vocab)
# Out:
# 18404

# %%
lm.vocab.lookup(corpus[0])
# Out:
# ('trailer', 'late', 'ah', 'parthavanga', 'like', 'podunga')

# %%
lm.vocab.lookup(["aliens", "from", "Mars"])
# Out:
# ('aliens', 'from', '<UNK>')

# %%
print(lm.counts)
# Out:
# <NgramCounter with 2 ngram orders and 215279 ngrams>

# %%
lm.counts['thala']
# Out:
# 1890

# %%
lm.generate(5)
# Out:
# ['shooting', 'etuthaanga', '</s>', 'padathula', 'sivakarthikeyan']

# %%
test = preproc("./tamil_dev.tsv")

# %%
test
# Out:
# [['daily', 'likes', 'views', 'pakka', 'vanthavaga', 'ellarukum', 'vanakkam'],
#  ['k',
#   'dislikes',
#   'ethuku',
#   'da',
#   'intha',
#   'trailerku',
#   'poi',
#   'apdi',
#   'ungalukku',
#   'entha',
#   'trailer',
#   'tha',
#   'pidikum'],
#  ['lyca', 'unna', 'nenacha', 'pavama', 'iruku', 'ya'],
#  ['it', 'looks', 'like', 'hindi', 'movie', 'amitab', 'bachan'],
#  ['thalaivarukku',
#   'nejamavey',
#   'vayasaagiduchu',
#   'sivaji',
#   'than',
#   'thalaivaroda',
#   'peak'],
#  ['thala', 'nu', 'sollu', 'thala', 'nemirinthu', 'nillu'],
#  ['pink',
#   'original',
#   'version',
#   'pathavikaluku',
#   'this',
#   'trailer',
#   'old',
#   'maritha',
#   'irukum',
#   'pakathvigalukutha',
#   'all',
#   'scenes',
#   'um',
#   'new',
#   'ah',
#   'irukum'],
#  ['vera',
#   'levellllllllllllll',
#   'all',
#   'the',
#   'best',
#   'shankar',
#   'sir',
#   'you',
#   'are',
#   'a',
#   'legend'],
#  ['h', 'raja', 'reference', 'kandupudichavangalam', 'like', 'pannunga'],
#  ['massssss', 'thalivaa', 'vera', 'level', 'energy', 'petta', 'parak'],
#  ['nadakkadhu',
#   'nadakkakoodathu',
#   'nadakka',
#   'vidamattaen',
#   'who',
#   'expected',
#   'that',
#   'line'],
#  ['nerkonda',
#   'parvai',
#   'continue',
#   'days',
#   'in',
#   'all',
#   'teater',
#   'it',
#   'will',
#   'be',
#   'block',
#   'buster',
#   'movie',
#   'yeslike',
#   'nocomment'],
#  ['r',
#   'sijlee',
#   'energy',
#   'solutions',
#   'pvt',
#   'ltdr',
#   'sijleecomare',
#   'r',
#   'emi',
#   'availabler',
#   'chennai'],
#  ['hello',
#   'youtube',
#   'trent',
#   'on',
#   'button',
#   'your',
#   'software',
#   'death',
#   'ah'],
#  ['ultimate', 'star', 'ajith', 'kumar', 'thala', 'thala', 'thala'],
#  ['unmaiya', 'thala', 'fana', 'irrutha', 'like', 'poduga'],
#  ['thalaiva', 'superstar', 'rajinikanth', 'number', 'one', 'mass', 'hero'],
#  ['makkal', 'selvan', 'fans', 'hit', 'like', 'here'],
#  ['super', 'star', 'marana', 'mass'],
#  ['am', 'sasikumar', 'big', 'fan', 'so', 'i', 'like', 'the', 'move'],
#  ['superstar',
#   'rajnikant',
#   'fans',
#   'hit',
#   'like',
#   'k',
#   'likes',
#   'petta',
#   'this',
#   'pongal',
#   'pakka',
#   'blockbuster'],
#  ['siruthai',
#   'siva',
#   'apdiye',
#   'director',
#   'odadha',
#   'vaangi',
#   'madakku',
#   'madakku',
#   'nu',
#   'kudi',
#   'unnaku',
#   'direction',
#   'varudhaanu',
#   'paapom'],
#  ['thala',
#   'thala',
#   'pesunaa',
#   'anilu',
#   'ammaiyan',
#   'vjmaaa',
#   'ku',
#   'tharama',
#   'sembavam',
#   'irrukku',
#   'daaaa',
#   'anilu',
#   'vick',
#   'sorry',
#   'kotte',
#   'pathy'],
#  ['yenapa',
#   'hollywood',
#   'movie',
#   'madiri',
#   'trailer',
#   'iruku',
#   'chiyan',
#   'rocks',
#   'kalakitaru',
#   'getup',
#   'vera',
#   'level'],
#  ['bgm', 'vera', 'level', 'going', 'hike', 'ghibran'],
#  ['eppadina',
#   'bigil',
#   'trailera',
#   'namma',
#   'views',
#   'reach',
#   'aga',
#   'koodadhu',
#   'adhe'],
#  ['vaa',
#   'thaliva',
#   'vaa',
#   'thalaiva',
#   'marana',
#   'mass',
#   'thailaiva',
#   'fire',
#   'waiting',
#   'thailva'],
#  ['that',
#   'final',
#   'dialoge',
#   'oruthar',
#   'meala',
#   'visvasam',
#   'katurathukaga',
#   'ennorthara',
#   'yen',
#   'asinga',
#   'paduthuringa'],
#  ['bro',
#   'ellaarum',
#   'm',
#   'likes',
#   'ethukunga',
#   'vidaathingai',
#   'would',
#   'create',
#   'pannungafast'],
#  ['thala',
#   'madhiri',
#   'thuiya',
#   'tamil',
#   'pessi',
#   'nadikka',
#   'mudiuma',
#   'thala',
#   'tamilan',
#   'da'],
#  ['yaarellam', 'oct', 'ku', 'verithanama', 'wait', 'panreega', 'hit', 'like'],
#  ['thalapathy',
#   'fan',
#   'like',
#   'thala',
#   'ni',
#   'vaa',
#   'thala',
#   'nanga',
#   'erukkom'],
#  ['enna', 'da', 'trailer', 'kannapundai', 'madiri', 'iruku'],
#  ['enathaku',
#   'da',
#   'dislike',
#   'pannringa',
#   'edhoda',
#   'oru',
#   'gethu',
#   'trailer',
#   'irukka',
#   'vaipae',
#   'illa'],
#  ['anil',
#   'kunjunga',
#   'romba',
#   'kadharranga',
#   'idharku',
#   'ore',
#   'theervu',
#   'arali',
#   'vedhaya',
#   'sappuradhu',
#   'dhan'],
#  ['agalathey',
#   'paatu',
#   'kku',
#   'aprum',
#   'vanthavanga',
#   'like',
#   'aa',
#   'pottu',
#   'viduunga',
#   'nu',
#   'comment',
#   'panna',
#   'vanthavanga',
#   'oru',
#   'like',
#   'a',
#   'podunga'],
#  ['trailers', 'semaaaaaaaa', 'i', 'am', 'waiting', 'release', 'big', 'screen'],
#  ['love', 'you', 'karthik', 'real', 'fan', 'made', 'film'],
#  ['thala', 'vera', 'level', 'in', 'ner', 'konda', 'paarvai'],
#  ['manitha',
#   'kadavul',
#   'ajith',
#   'kumar',
#   'kadhal',
#   'mannan',
#   'ajithkumar',
#   'ultimate',
#   'star',
#   'ajithkumar'],
#  ['daily', 'intha', 'trailer', 'ah', 'pakuravanga'],
#  ['super', 'raa', 'ya', 'eriku', 'trailer', 'movie', 'uk', 'whiting'],
#  ['eanga', 'chiyan', 'vikaram', 'yappo', 'maa', 'mass', 'da'],
#  ['trailer',
#   'nalla',
#   'erukku',
#   'pengal',
#   'ku',
#   'nadakkura',
#   'kodumaiya',
#   'eduthu',
#   'solra',
#   'kadhai',
#   'sema',
#   'thalapathy',
#   'fan'],
#  ['vijay', 'sethupathi', 'anna', 'bayangara', 'mass', 'said', 'irukaru'],
#  ['final', 'dialogue', 'and', 'previous', 'dialogue', 'mass'],
#  ['happy',
#   'diwali',
#   'guysss',
#   'if',
#   'vijay',
#   'fans',
#   'here',
#   'means',
#   'enjoy',
#   'you',
#   'are',
#   'sarkar',
#   'day'],
#  ['like', 'vennum', 'ennum', 'narayaaa', 'narayaaa', 'narayaaa'],
#  ['valimai',
#   'aana',
#   'aamai',
#   'inathin',
#   'thailvan',
#   'ajith',
#   'kuthi',
#   'punda',
#   'mavan',
#   'valga'],
#  ['sk',
#   'anna',
#   'nenga',
#   'vera',
#   'level',
#   'aduthu',
#   'aduthu',
#   'munari',
#   'poitairukinge',
#   'anna',
#   'always',
#   'love',
#   'you',
#   'anna'],
#  ['hit', 'like', 'ithu', 'onnu', 'than', 'inga', 'comments', 'aa', 'irukku'],
#  ['hours',
#   'million',
#   'views',
#   'woww',
#   'thalaivaaaaipa',
#   'vaanga',
#   'da',
#   'china',
#   'pasangala'],
#  ['am', 'waiting', 'for', 'thala', 'in', 'nerkonda', 'parvai'],
#  ['rajini', 'kanth', 'sir', 'fans', 'like', 'here'],
#  ['guyzz',
#   'night',
#   'kulla',
#   'm',
#   'views',
#   'k',
#   'likes',
#   'podanumspeed',
#   'upp',
#   'dudes'],
#  ['hero', 'already', 'looks', 'like', 'a', 'zero'],
#  ['rmba',
#   'nerama',
#   'k',
#   'la',
#   'mattume',
#   'iruku',
#   'thala',
#   'mass',
#   'views',
#   'pakalanu',
#   'patha',
#   'ithu',
#   'vera',
#   'sathi',
#   'pannuthu'],
#  ['mathavanga',
#   'mari',
#   'bandha',
#   'katti',
#   'nadikama',
#   'karthulla',
#   'padam',
#   'choose',
#   'panni',
#   'nadikirau',
#   'love',
#   'you',
#   'thala',
#   'hats',
#   'off'],
#  ['trending', 'no', 'in', 'singapore', 'steady', 'la'],
#  ['fathers', 'day', 'special', 'paarungu', 'awareness', 'share', 'pannungu'],
#  ['indheee',
#   'oru',
#   'padam',
#   'poodhum',
#   'thalaivaaaa',
#   'naaan',
#   'ungaleee',
#   'marupadiyum',
#   'parthutheeee'],
#  ['why',
#   'k',
#   'dislikewhat',
#   'they',
#   'understandplese',
#   'tell',
#   'me',
#   'dislike',
#   'persons'],
#  ['waiting', 'for', 'kaappaan', 'suriya', 'fans', 'like', 'here'],
#  ['thalaivar', 'than', 'super', 'star', 'vera', 'evarum', 'kidaiyathu'],
#  ['asuren', 'vettai', 'arambam', 'am', 'dhanush', 'anna', 'veriyan'],
#  ['no', 'one', 'two', 'la', 'papanga', 'vilayattu', 'super', 'star'],
#  ['trailer',
#   'pathi',
#   'edhana',
#   'sollunga',
#   'ya',
#   'na',
#   'poll',
#   'vachi',
#   'nadathuranunga',
#   'indha',
#   'fan',
#   'boys',
#   'like',
#   'hu',
#   'comment',
#   'haam'],
#  ['will', 'it', 'get', 'million', 'likes'],
#  ['ithu', 'tamil', 'nadu', 'ella', 'ithu', 'enga', 'thala', 'nadu', 'daa'],
#  ['epd',
#   'unga',
#   'combovetridhanush',
#   'nala',
#   'matum',
#   'ipd',
#   'realistica',
#   'kondu',
#   'vara',
#   'mudyuthu',
#   'semmmma',
#   'pa'],
#  ['wowww',
#   'amaizing',
#   'bgm',
#   'nammakita',
#   'kaaadu',
#   'iruntha',
#   'eduthupanga',
#   'kasu',
#   'iruntha',
#   'pudingikuruvanga',
#   'padipa',
#   'mattum',
#   'eduthukave',
#   'mudiyathu',
#   'chithambaram',
#   'superb'],
#  ['adichu', 'underwear', 'oda', 'voda', 'vitturuven'],
#  ['pakathana', 'pora', 'pongalugu', 'inntha', 'kalliyoda', 'attatha'],
#  ['indha', 'diwali', 'kaidhi', 'ku', 'bigil', 'visil', 'podu'],
#  ['adutha',
#   'vaaram',
#   'thaan',
#   'indha',
#   'maanam',
#   'ketta',
#   'padathuku',
#   'm',
#   'views',
#   'varumnu',
#   'nenaikiravanga',
#   'like',
#   'podunga'],
#  ['ithu', 'vae', 'ippadi', 'naapa', 'thalapathy'],
#  ['koja', 'different', 'aana', 'movie', 'interesting'],
#  ['oruthar',
#   'meala',
#   'viswasam',
#   'katura',
#   'naala',
#   'inu',
#   'oruthara',
#   'yen',
#   'asinga',
#   'paduthuringa',
#   'thala',
#   'vera',
#   'level'],
#  ['kola', 'verithanam', 'trailer', 'award', 'kandipa', 'kedaikkun'],
#  ['rajini',
#   'sankar',
#   'ar',
#   'rahman',
#   'vera',
#   'level',
#   'intha',
#   'combo',
#   'kkaaga',
#   'tharalaama',
#   'paakalam'],
#  ['kola',
#   'gaandula',
#   'iruken',
#   'mavane',
#   'kollama',
#   'vidamaten',
#   'antha',
#   'k',
#   'dislike',
#   'panninavangala'],
#  ['wtf', 'manu', 'is', 'doing', 'in', 'between', 'gandhi', 'and', 'ambedkar'],
#  ['kaasu',
#   'kodhuthu',
#   'vikku',
#   'mudiya',
#   'vangalam',
#   'ana',
#   'kaasu',
#   'kodhuthu',
#   'tholapathy',
#   'enra',
#   'title',
#   'vangalaama'],
#  ['viswasathuku',
#   'sirappana',
#   'tharamana',
#   'sambavangalai',
#   'ini',
#   'thaan',
#   'paarka',
#   'poreenga'],
#  ['indha',
#   'padam',
#   'kandippa',
#   'mokkaya',
#   'irukum',
#   'nu',
#   'nenaikaravanga',
#   'like',
#   'podunga'],
#  ['this',
#   'time',
#   'thalaivar',
#   'trailer',
#   'ah',
#   'ku',
#   'mela',
#   'parthavanga',
#   'like',
#   'pannunga'],
#  ['min', 'a', 'k', 'views', 'omg'],
#  ['thalaivaaaa',
#   'you',
#   'are',
#   'one',
#   'and',
#   'only',
#   'super',
#   'star',
#   'pettaaaaa',
#   'marana',
#   'maaaaasss',
#   'i',
#   'will',
#   'be',
#   'in',
#   'fdfs',
#   'at',
#   'trichy'],
#  ['vikram',
#   'look',
#   'vera',
#   'level',
#   'making',
#   'la',
#   'pakumbotheya',
#   'veriya',
#   'irruku',
#   'kasa',
#   'thaniya',
#   'vari',
#   'erachi',
#   'irrukanga',
#   'polatrailer',
#   'semma',
#   'mass',
#   'dha'],
#  ['therikka', 'vda', 'vantaanga', 'thalaivar', 'and', 'team'],
#  ['thala', 'ajith', 'kumar', 'yuvan', 'shankar', 'raja', 'h', 'vinond', 'uff'],
#  ['chiyan',
#   'fans',
#   'lam',
#   'like',
#   'button',
#   'ah',
#   'adichi',
#   'thookunga',
#   'paaklaamm'],
#  ['bgm', 'nice', 'but', 'onum', 'solra', 'maari', 'illa'],
#  ['dr', 'br', 'ambedkar', 'dialogue', 'jai', 'bheem'],
#  ['kgf', 'chapter', 'like', 'kaithi', 'like'],
#  ['on', 'trending', 'omg', 'woww', 'love', 'rajinikanth'],
#  ['nangalum',
#   'kola',
#   'kanda',
#   'la',
#   'than',
#   'irukom',
#   'oda',
#   'vidroma',
#   'illayanu',
#   'parru'],
#  ['g', 'v', 'p', 'kumar', 'music', 'vera', 'leval', 'bgm'],
#  ['chiyan', 'ninga', 'fast', 'furiors', 'laye', 'nadikalam'],
#  ['million',
#   'innum',
#   'days',
#   'kulla',
#   'varanum',
#   'friends',
#   'keep',
#   'watching'],
#  ['mirattal', 'ah', 'irukku', 'boss', 'siva', 'anne', 'sema'],
#  ['dai',
#   'kodi',
#   'thevaiya',
#   'intha',
#   'movieku',
#   'varumaiyil',
#   'vazum',
#   'eazakku',
#   'seru',
#   'pottala',
#   'natu',
#   'munnerum'],
#  ['dai',
#   'pandey',
#   'thala',
#   'ya',
#   'vey',
#   'yethirthu',
#   'pesuriya',
#   'goyala',
#   'theater',
#   'pakkam',
#   'varuvala',
#   'va'],
#  ['vjs',
#   'anna',
#   'voice',
#   'ke',
#   'naanelam',
#   'adimainu',
#   'solravanga',
#   'oru',
#   'like',
#   'podunga'],
#  ['ethana',
#   'padam',
#   'vanthanu',
#   'salt',
#   'and',
#   'pepper',
#   'mattum',
#   'thanth',
#   'l'],
#  ['namakku',
#   'thevayandhu',
#   'namaa',
#   'dha',
#   'adichu',
#   'vanganum',
#   'semma',
#   'punch',
#   'd',
#   'killing',
#   'trailor',
#   'dudes'],
#  ['diehard', 'fan', 'of', 'chiyaan', 'vikram'],
#  ['trailera',
#   'fulla',
#   'paakave',
#   'porumai',
#   'illaye',
#   'padam',
#   'epdi',
#   'irkumo'],
#  ['nerkonda', 'parvai', 'blue', 'sattai', 'maran', 'review'],
#  ['next', 'bigil', 'movie', 'ku', 'waiting', 'pantravanga'],
#  ['trailer', 'bangam', 'talented', 'film', 'maker', 'lokesh', 'ganagaraj'],
#  ['theatre',
#   'padam',
#   'pakkanum',
#   'solli',
#   'veriyilla',
#   'erikkenevanavadu',
#   'piracy',
#   'solli',
#   'net',
#   'la',
#   'padaththa',
#   'vittathalavaroda',
#   'kolaveriyan',
#   'mavane',
#   'koluththama',
#   'vidamatten'],
#  ['malayalam', 'movie', 'chindhamani', 'kolakes', 'copy', 'ajit', 'vest'],
#  ['thala',
#   'padama',
#   'ithu',
#   'koothi',
#   'maari',
#   'iruku',
#   'trailer',
#   'padam',
#   'punda',
#   'mathiri',
#   'irukum',
#   'pola'],
#  ['back', 'to', 'youth', 'rajini', 'thalaiva', 'marana', 'mass'],
#  ['i', 'can', 'not', 'believe', 'he', 'is'],
#  ['appu',
#   'ithu',
#   'enna',
#   'telegu',
#   'padam',
#   'matri',
#   'iruku',
#   'tamil',
#   'padam',
#   'yedugeda'],
#  ['thala', 'thala', 'thala', 'thala', 'thalathala', 'thala', 'thala'],
#  ['vijay',
#   'fans',
#   'dislike',
#   'pottu',
#   'oomba',
#   'vandhutanga',
#   'thayoli',
#   'poitu',
#   'unga',
#   'amma',
#   'shidhiya',
#   'oombungada'],
#  ['blockbuster', 'but', 'not', 'as', 'like', 'bahubali'],
#  ['ithula',
#   'dislike',
#   'panna',
#   'ennada',
#   'irukku',
#   'enda',
#   'ithana',
#   'dislikes'],
#  ['thalaivar',
#   'masss',
#   'ah',
#   'irukarupa',
#   'nu',
#   'sonnavangala',
#   'hit',
#   'likes'],
#  ['times', 'pathavanga', 'like', 'podunga'],
#  ['thala', 'tharisanam', 'marana', 'waiting', 'in', 'big', 'screen'],
#  ['pakarathuku',
#   'chinna',
#   'paiyan',
#   'maathiriya',
#   'poi',
#   'sonnalum',
#   'oru',
#   'nayam',
#   'venamada'],
#  ['die', 'hard', 'fans', 'of', 'ajithkumar', 'hit', 'like'],
#  ['sethupathi',
#   'anna',
#   'va',
#   'innum',
#   'konjam',
#   'mass',
#   'ah',
#   'kaatirukalam',
#   'padathoda',
#   'edhiriparpu',
#   'innum',
#   'adhigama',
#   'irundhirukum'],
#  ['thalaivar', 'kolla', 'kondula', 'erukeo', 'kollama', 'vittamatto'],
#  ['siva',
#   'mela',
#   'viswasam',
#   'kaaati',
#   'yen',
#   'yengala',
#   'asinga',
#   'paduthureenge',
#   'thala',
#   'climax',
#   'vera',
#   'level'],
#  ['dei',
#   'ennada',
#   'conair',
#   'padatha',
#   'kavuthi',
#   'pota',
#   'madiri',
#   'iruku',
#   'unga',
#   'kaithi',
#   'thiruttu',
#   'payale',
#   'lokesuh'],
#  ['remake', 'of', 'pink', 'a', 'class', 'movie'],
#  ['zero', 'is', 'better', 'hit', 'like', 'if', 'agree'],
#  ['samaaaaaa',
#   'damnnnnnnnnn',
#   'vfx',
#   'ah',
#   'kora',
#   'sonavanugaparugada',
#   'ipa',
#   'indha',
#   'trailerah',
#   'thalaiver',
#   'dialog',
#   'pahvera',
#   'level'],
#  ['vera', 'vera', 'vera', 'level', 'thala', 'top', 'takker'],
#  ['ennada', 'naduvula', 'viswasam', 'bgm', 'pottu', 'vachirukkinga'],
#  ['ithu',
#   'padama',
#   'illapandaylaanirukarunews',
#   'sa',
#   'thalaki',
#   'yaytha',
#   'look',
#   'illaya'],
#  ['tamil',
#   'acters',
#   'kerala',
#   'star',
#   'value',
#   'vijay',
#   'surya',
#   'rajani',
#   'vikram',
#   'dhanush',
#   'vijay',
#   'sethupathi',
#   'then',
#   'only',
#   'ajith'],
#  ['manju', 'warrier', 'uh', 'adhu', 'na', 'kuda', 'anushka', 'nu', 'nenachen'],
#  ['ek',
#   'building',
#   'aur',
#   'ek',
#   'fieldpe',
#   'hi',
#   'puri',
#   'film',
#   'dikha',
#   'diyalol'],
#  ['dhanushs',
#   'swag',
#   'just',
#   'awseome',
#   'nammaku',
#   'thevaiyanathu',
#   'naamatha',
#   'aaduchu',
#   'vaanganum'],
#  ['hollywood',
#   'kaaranalatha',
#   'mudiyumnu',
#   'illa',
#   'tamilanaalayum',
#   'mudiyum',
#   'da',
#   'example',
#   'shankar',
#   'sir'],
#  ['thalapathy', 'fans', 'here', 'for', 'lokesh', 'kanakaraj', 'thalapathy'],
#  ['appudila', 'nadakathu', 'nadaka', 'kudathu', 'thala'],
#  ['i', 'am', 'jayam', 'ravi', 'anna', 'fan'],
#  ['thala', 'look', 'vera', 'levelnice', 'bgmyou', 'suparmovie', 'supar'],
#  ['petta',
#   'semma',
#   'super',
#   'muni',
#   'kanchana',
#   'motion',
#   'poster',
#   'release'],
#  ['superstar',
#   'yaarunu',
#   'karthik',
#   'subburaj',
#   'ta',
#   'kaetu',
#   'therinjukonga',
#   'baunga',
#   'jaathi',
#   'veriku',
#   'en',
#   'thalaivara',
#   'bali',
#   'aakathinga'],
#  ['thalaivaaaaa', 'you', 'are', 'great', 'by', 'vijay', 'fan'],
#  ['padam', 'kandipa', 'thokuradhukana', 'thagudhiyum', 'pakkava', 'iruku'],
#  ['ultimate',
#   'acting',
#   'thala',
#   'ennna',
#   'dialogue',
#   'delivery',
#   'chance',
#   'eh',
#   'ilaaa',
#   'love',
#   'you',
#   'thalaaaaaaaverrraaaa',
#   'level'],
#  ['st', 'trailer', 'looked', 'stupid', 'this', 'looks', 'dumb'],
#  ['ennda',
#   'ithu',
#   'appdiyea',
#   'vada',
#   'chennai',
#   'mathiri',
#   'trailer',
#   'iruku'],
#  ['pandey', 'va', 'cinema', 'kulla', 'kondu', 'vandhuteengala', 'mass', 'dha'],
#  ['who', 'was', 'waiting', 'war', 'movie', 'hit', 'like'],
#  ['massssssssssss', 'looooookkkk', 'thalaaaaaa', 'vera', 'level'],
#  ['thala', 'vera', 'level', 'kerala', 'vijay', 'fan'],
#  ['after', 'see', 'movie', 'and', 'see', 'trailer', 'hit', 'like'],
#  ['first', 'view', 'and', 'first', 'like', 'by', 'selvam'],
#  ['kala', 'pathamadhiri', 'irukku', 'solra', 'alavukku', 'illa'],
#  ['i', 'sense', 'amy', 'jackson', 'as', 'a', 'villain'],
#  ['hats',
#   'off',
#   'to',
#   'dhanush',
#   'sirsirantha',
#   'nadipupadipu',
#   'mattumae',
#   'oru',
#   'nabarai',
#   'uyaruthum'],
#  ['marana',
#   'mass',
#   'muchcha',
#   'anilu',
#   'ammaiyan',
#   'vjmaaa',
#   'ummah',
#   'sollu',
#   'hahaha'],
#  ['petta',
#   'la',
#   'thalaivar',
#   'totally',
#   'different',
#   'ta',
#   'irukukaaru',
#   'acting',
#   'um',
#   'thaaan',
#   'sirapu',
#   'sambhavam',
#   'thirkaaka',
#   'waiting'],
#  ['hit', 'likes', 'nu', 'picha', 'edukathavanga', 'like', 'pannunga'],
#  ['maaasss',
#   'thalaiva',
#   'unna',
#   'vitta',
#   'vera',
#   'yaaralum',
#   'intha',
#   'acting',
#   'varathu',
#   'unga',
#   'style',
#   'paakave',
#   'time',
#   'movie',
#   'paaka',
#   'varlam'],
#  ['vada', 'chennai', 'mari', 'irukkum', 'jolly'],
#  ['ippadi',
#   'neraya',
#   'neraya',
#   'nerayamanda',
#   'fulla',
#   'narachu',
#   'pochuidula',
#   'punchuvera',
#   'lvl',
#   'trailer'],
#  ['asuran',
#   'climax',
#   'la',
#   'dhanush',
#   'soldra',
#   'dialogue',
#   'ah',
#   'arjun',
#   'modify',
#   'panni',
#   'sonna',
#   'maadri',
#   'yennaku',
#   'mattum',
#   'dha',
#   'thonnuda'],
#  ['vera', 'level', 'vfx', 'just', 'killing', 'it'],
#  ['thalavia',
#   'neenga',
#   'veera',
#   'level',
#   'boss',
#   'and',
#   'neega',
#   'thaan',
#   'marana',
#   'mass'],
#  ['cool', 'old', 'rajni', 'return', 's'],
#  ['super', 'star', 'fan', 'from', 'kerala', 'like', 'here'],
#  ['neraya', 'neraya', 'neraya', 'vaaila', 'tha', 'kudukanum'],
#  ['boom', 'boom', 'robo', 'da', 'robo', 'da'],
#  ['lots', 'of', 'love', 'from', 'karnataka', 'hit', 'like', 'karthi', 'fans'],
#  ['m', 'likes', 'varuma', 'hit', 'here'],
#  ['vayasuku',
#   'thagundha',
#   'savagasame',
#   'illa',
#   'ivarukujust',
#   'funthalaivar',
#   'massssss'],
#  ['mokka', 'mokka', 'mokka', 'trailer', 'fans'],
#  ['dai',
#   'ajith',
#   'kelatu',
#   'naaye',
#   'intha',
#   'madri',
#   'films',
#   'nee',
#   'panite',
#   'vantha',
#   'ommala',
#   'kamal',
#   'hassan',
#   'madri',
#   'neeyum',
#   'kaanama',
#   'poiduva',
#   'da'],
#  ['verum',
#   'buildup',
#   'um',
#   'bgm',
#   'um',
#   'vachi',
#   'hitu',
#   'kodukuravanga',
#   'mathiyila',
#   'indhamaaari',
#   'oru',
#   'movie',
#   'kodutha',
#   'vetrimaran',
#   'sir',
#   'kuhattsoffdhanush',
#   'siractworth',
#   'to',
#   'watch'],
#  ['paakradhuku',
#   'chinna',
#   'paiyan',
#   'maari',
#   'style',
#   'ah',
#   'irukeenga',
#   'how',
#   'true'],
#  ['any', 'yuvan', 'shankar', 'raja', 'fans', 'here'],
#  ['thala', 'thalaa', 'masss', 'fan', 'from', 'karnataka'],
#  ['thalaivaaaaaaa',
#   'yen',
#   'kadavulaaaeess',
#   'proud',
#   'to',
#   'be',
#   'you',
#   'are',
#   'fan'],
#  ['next',
#   'time',
#   'teacer',
#   'edhir',
#   'parkura',
#   'angali',
#   'pangalinga',
#   'comment',
#   'pannunga',
#   'because',
#   'nama',
#   'trailerke',
#   'gethu',
#   'katrom',
#   'tecera',
#   'irundha'],
#  ['nanga',
#   'oruthan',
#   'kittah',
#   'matikittu',
#   'irukom',
#   'avan',
#   'yeanatha',
#   'pannah',
#   'porano'],
#  ['ennada',
#   'kaila',
#   'laddua',
#   'kuduthutu',
#   'trailerla',
#   'jilebia',
#   'pichi',
#   'potrukingaa',
#   'oruvelai',
#   'pink',
#   'movie',
#   'kooda',
#   'ippadi',
#   'dhaa',
#   'irukumoo'],
#  ['petta', 'viswasamsame', 'old', 'story', 'like', 'veeram'],
#  ['seeing', 'prakash', 'raj', 'after', 'long', 'time'],
#  ['ajitj', 'as', 'a', 'lawyer', 'first', 'time'],
#  ['neraya', 'neraya', 'neraya', 'neraya', 'neraya', 'neraya'],
#  ['vera',
#   'level',
#   'la',
#   'erukku',
#   'trailer',
#   'stunt',
#   'pathi',
#   'solla',
#   'varthaiye',
#   'ila',
#   'ba'],
#  ['thalaivaaa', 'last', 'la', 'andha', 'dance', 'semma'],
#  ['trailer', 'la', 'nala', 'iruku', 'ana', 'sivaku', 'match', 'agala'],
#  ['enna',
#   'thalaivar',
#   'trailer',
#   'ivlo',
#   'nal',
#   'kaluchu',
#   'trending',
#   'varuthu'],
#  ['yuvan',
#   'bgm',
#   'semaya',
#   'irukuromba',
#   'naal',
#   'kalichu',
#   'thala',
#   'kuda',
#   'join',
#   'panadhu',
#   'romba',
#   'happy',
#   'iruku'],
#  ['i',
#   'am',
#   'chiyaan',
#   'vikram',
#   'sir',
#   'fan',
#   'but',
#   'i',
#   'love',
#   'ajith',
#   'kumar',
#   'sir'],
#  ['look', 'like', 'a', 'bigil', 'football', 'stadium'],
#  ['i', 'm', 'from', 'telangana', 'jai', 'rajini', 'jai', 'thalaiva'],
#  ['apdiye',
#   'aaluma',
#   'doluma',
#   'song',
#   'paathutu',
#   'adhuku',
#   'oru',
#   'like',
#   'podunga'],
#  ['dhanushvetrimaaran',
#   'innum',
#   'ethana',
#   'padam',
#   'sernthu',
#   'pannaalum',
#   'elaamae',
#   'sorgam',
#   'thaan',
#   'cinema',
#   'lovers',
#   'ku'],
#  ['ajith', 'last', 'aha', 'sonna', 'varthai', 'mattum', 'supprrr'],
#  ['dhanush', 'anna', 'fans', 'mattum', 'like', 'panega'],
#  ['pink', 'movie', 'se', 'jyada', 'maza', 'aayegareason', 'thala'],
#  ['sk', 'anna', 'mass', 'i', 'like', 'you', 'anna', 'marana', 'waiting'],
#  ['trailer', 'kidu', 'appo', 'padam', 'kandechu', 'varaam', 'thala'],
#  ['who', 'is', 'badly', 'waiting', 'for', 'this', 'movie'],
#  ['ajith', 'fans', 'like', 'here', 'kaithi'],
#  ['thalaivar', 'oda', 'dialogue', 'vera', 'lvl'],
#  ['chindamani',
#   'kolacase',
#   'movie',
#   'orma',
#   'vannavark',
#   'ivide',
#   'like',
#   'adikkam'],
#  ['atleast',
#   'indha',
#   'super',
#   'hero',
#   'padamachu',
#   'makkal',
#   'support',
#   'panuvaanganu',
#   'nenaikurensk',
#   'at',
#   'his',
#   'atmost',
#   'bestalwayss',
#   'masss'],
#  ['ciyaan', 'vikram', 'i', 'love', 'you'],
#  ['apadila',
#   'nadakathu',
#   'nadakoodathu',
#   'lines',
#   'for',
#   'woman',
#   's',
#   'super',
#   'thala'],
#  ['gibran', 'vera', 'level'],
#  ['kola', 'gaandla', 'irukan', 'mavana', 'kollama', 'vida', 'maattan'],
#  ['just',
#   'k',
#   'likes',
#   'away',
#   'from',
#   'passing',
#   'vivegam',
#   'trailer',
#   'likes'],
#  ['thala', 'thala', 'tamil', 'naatuku', 'ore', 'thala'],
#  ['waiting', 'to', 'see', 'vekkai', 'novel', 'real', 'version'],
#  ['super', 'maass', 'movie', 'love', 'you', 'thalaivar'],
#  ['million', 'like', 'varala', 'all', 'thala', 'fans', 'like', 'podunga'],
#  ['orutharu',
#   'mela',
#   'katura',
#   'viswasthuku',
#   'enoruthara',
#   'en',
#   'asinga',
#   'paduthuringa',
#   'thala',
#   'powerful',
#   'dialogue'],
#  ['mokka',
#   'padama',
#   'irukalam',
#   'may',
#   'be',
#   'ajith',
#   'kaga',
#   'hit',
#   'agalam'],
#  ['allam', 'ok', 'super', 'than', 'but', 'trailer', 'mokkaye'],
#  ['you',
#   'kena',
#   'tunggu',
#   'lebih',
#   'lama',
#   'lagi',
#   'untuk',
#   'tahu',
#   'saya',
#   'meaning',
#   'you',
#   'need',
#   'to',
#   'wait',
#   'more',
#   'to',
#   'understand',
#   'me'],
#  ['singa', 'thoda', 'mudi', 'narajita', 'ade', 'singa', 'illane', 'aidada'],
#  ['vera', 'level', 'anna', 'i', 'am', 'marana', 'waiting'],
#  ['idhu', 'dhan', 'ya', 'unmaiya', 'na', 'verithanam'],
#  ['superstar', 'and', 'sankar', 'combination', 'always', 'pakka'],
#  ['varudam',
#   'ivar',
#   'naarkalii',
#   'ku',
#   'aaasaipaadatha',
#   'aatkal',
#   'ilaai',
#   'indru',
#   'varikum'],
#  ['come', 'on', 'dude', 'come', 'in', 'dude'],
#  ['pink',
#   'remake',
#   'tamil',
#   'la',
#   'nalla',
#   'illa',
#   'thala',
#   'thairiyama',
#   'diwalikku',
#   'vaa'],
#  ['enga',
#   'thala',
#   'thaanda',
#   'eppavume',
#   'gethu',
#   'meethi',
#   'ellaarum',
#   'vethu'],
#  ['never', 'put', 'you', 'are', 'phone', 'in', 'airplane', 'mode'],
#  ['mass',
#   'thalaivar',
#   'ah',
#   'nijama',
#   'chinna',
#   'paiyana',
#   'pakra',
#   'maari',
#   'eruku',
#   'athe',
#   'style',
#   'athe',
#   'rajini'],
#  ['thatta',
#   'da',
#   'aamai',
#   'porumaiya',
#   'poittu',
#   'irukku',
#   'innum',
#   'oru',
#   'naal',
#   'aagum',
#   'm',
#   'views',
#   'ku'],
#  ['last', 'la', 'vara', 'black', 'dress', 'pa', 'chancey', 'illa'],
#  ['did', 'you', 'get', 'it', 'it', 'is', 'pink', 'movie'],
#  ['apdiye',
#   'poiru',
#   'kola',
#   'kandula',
#   'irukan',
#   'mass',
#   'thalaivasweet',
#   'sapda',
#   'poro'],
#  ['ithu', 'rajini', 'padam', 'ithu', 'thaan', 'rajini', 'padam'],
#  ['neraya',
#   'neraya',
#   'neraya',
#   'veri',
#   'yethuraruba',
#   'namba',
#   'thala',
#   'phaa',
#   'suma',
#   'odambu',
#   'pullarichiruchi'],
#  ['summa', 'marana', 'mass', 'trailer', 'mirattala', 'irukku', 'excellent'],
#  ['dhanush', 'anna', 'fans', 'hit', 'like'],
#  ['sweet', 'sapda', 'porom', 'apram', 'sugar', 'mathira', 'sapda', 'porom'],
#  ['sweet',
#   'sapda',
#   'poromnu',
#   'unga',
#   'kelavan',
#   'sonnan',
#   'paarthu',
#   'sugar',
#   'vanthu',
#   'sethuraama'],
#  ['yarellam', 'teejay', 'ah', 'vaa', 'pathu', 'excite', 'aanginga'],
#  ['apdilam', 'nadakkathuthu', 'nadakka', 'koodathu'],
#  ['oruthar', 'mela', 'viswasam', 'katta', 'mass', 'thala'],
#  ['yanda',
#   'pasangala',
#   'chi',
#   'pongada',
#   'nengalum',
#   'cinemavum',
#   'unga',
#   'ennam',
#   'ci'],
#  ['yo', 'ghibran', 'ennaya', 'epdi', 'bgm', 'podura'],
#  ['marana', 'waiting', 'for', 'you', 'thalaivaaa'],
#  ['simran', 'enabha', 'trishava', 'katlum', 'younga', 'iruku', 'wow'],
#  ['thalapathy', 'rasigana', 'dhanush', 'ku', 'oru', 'like'],
#  ['enna', 'da', 'inum', 'm', 'kuda', 'varla'],
#  ['thalaiva', 'idhe', 'podhu', 'thalaiva', 'pongal', 'varaikum', 'thaangum'],
#  ['make', 'it', 'milion', 'views'],
#  ['dei',
#   'ennada',
#   'conair',
#   'padatha',
#   'kavuthi',
#   'pota',
#   'madiri',
#   'iruku',
#   'unga',
#   'kaithir',
#   'thiruttu',
#   'payale',
#   'lokesuh'],
#  ['hit', 'like', 'if', 'you', 'see', 'mahath', 'in'],
#  ['ajith',
#   'sir',
#   'carrierlaye',
#   'idhu',
#   'vidhyasamaana',
#   'padamnu',
#   'solravanga',
#   'cmt',
#   'pannunga'],
#  ['vara', 'level', 'thala', 'love', 'you', 'so', 'much', 'thala'],
#  ['i', 'am', 'waiting', 'is', 'movie'],
#  ['cmnts', 'are', 'hit', 'like', 'cmnts', 'romba', 'mosam', 'da', 'dei'],
#  ['thangam', 'nee', 'sonna', 'sari', 'solluti', 'sellam'],
#  ['vayasuanalum',
#   'style',
#   'um',
#   'alagum',
#   'maraveillahh',
#   'thalaivaaahats',
#   'off'],
#  ['dai', 'ithu', 'velayutham', 'padam', 'da', 'yaara', 'yeamaathringa'],
#  ['thalaivar',
#   'padam',
#   'day',
#   's',
#   'show',
#   'pakkuravanga',
#   'like',
#   'pannunga'],
#  ['ealam', 'ok', 'bgm', 'than', 'engayo', 'ketamariye', 'iruku'],
#  ['neraya',
#   'neraya',
#   'neraya',
#   'after',
#   'hearing',
#   'it',
#   'is',
#   'sapadu',
#   'nyabagam',
#   'vandhuruchi'],
#  ['yaaro',
#   'oru',
#   'group',
#   'padam',
#   'flop',
#   'dhan',
#   'konja',
#   'naalu',
#   'ku',
#   'munadi',
#   'koovitu',
#   'irundhanga',
#   'avanga',
#   'laam',
#   'konjam',
#   'line',
#   'la',
#   'vanga'],
#  ['over',
#   'seenu',
#   'odabuku',
#   'agathu',
#   'thambi',
#   'mukkunalum',
#   'thalapathy',
#   'pola',
#   'varathu'],
#  ['semma',
#   'mokka',
#   'idellam',
#   'oru',
#   'padam',
#   'edukurawanauku',
#   'adikanam',
#   'seruppala'],
#  ['first', 'like', 'button', 'vijay', 'setupati', 'fans'],
#  ['adichu',
#   'pudichumutti',
#   'modhi',
#   'munnukku',
#   'varathuna',
#   'ethuthan',
#   'trending'],
#  ['ippo', 'yenna', 'panna', 'porom', 'suweet', 'sapida', 'poram'],
#  ['s', 'kids', 'love', 'vijaysethupathi'],
#  ['gommala', 'flopu', 'daapoi', 'elarum', 'asooth', 'poola', 'oombunga'],
#  ['pakka',
#   'thane',
#   'pore',
#   'indha',
#   'kaali',
#   'ude',
#   'aattathethalaivar',
#   'roks'],
#  ['ghibran', 'way', 'to', 'go', 'man'],
#  ['i',
#   'am',
#   'vijay',
#   'anna',
#   'fan',
#   'its',
#   'amazing',
#   'semma',
#   'thala',
#   'sir'],
#  ['last', 'dialogue', 'ok', 'but', 'naadagamaari', 'irukku', 'trailer'],
#  ['k', 'view', 'and', 'k', 'like', 'awesome'],
#  ['wait',
#   'panathuku',
#   'sema',
#   'waita',
#   'vara',
#   'poguthu',
#   'pola',
#   'trailor',
#   'ayooosema',
#   'mass',
#   'creater',
#   'shankarji'],
#  ['viewsya', 'allah', 'ya', 'allah'],
#  ['makkalselvanfans',
#   'sir',
#   'like',
#   'here',
#   'i',
#   'am',
#   'from',
#   'telangana',
#   'hyd'],
#  ['thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'thala',
#   'masssssss'],
#  ['bgm', 'sema', 'thala', 'oada', 'expressions'],
#  ['that', 'swag', 'rajini', 'is', 'rajini'],
#  ['ayyayooo', 'thala', 'goosebumps', 'ethir', 'paakave', 'illa'],
#  ['petta', 'pongal', 'jan', 'ku', 'semma', 'waiting', 'thalaiva'],
#  ['ajith',
#   'sir',
#   'ra',
#   'pidikkathavanga',
#   'dislike',
#   'pannuvanga',
#   'athu',
#   'padam',
#   'nella',
#   'irruthalum',
#   'nella',
#   'illattium'],
#  ['no', 'lip', 'sync', 'for', 'kalyani', 'agree'],
#  ['iyoooooo',
#   'mudilaya',
#   'waiting',
#   'ubeppo',
#   'than',
#   'intha',
#   'padatha',
#   'papanoooothalaivar',
#   'thalaivar',
#   'than',
#   'ya'],
#  ['thalaivar',
#   'wow',
#   'padayappa',
#   'dialogue',
#   'inga',
#   'podungaya',
#   'purinjavan',
#   'like',
#   'ah',
#   'podu',
#   'fdfs'],
#  ['innum', 'hour', 'la', 'm', 'like', 'varanum', 'thala', 'bloods'],
#  ['dai',
#   'thevidiya',
#   'bullaye',
#   'niranjan',
#   'soorappan',
#   'unaku',
#   'theriuma',
#   'peasatha',
#   'da',
#   'badu',
#   'yen',
#   'komavula',
#   'erukiya',
#   'da',
#   'thevidiya',
#   'baiya'],
#  ['vera',
#   'level',
#   'oruthar',
#   'mela',
#   'viswasam',
#   'kata',
#   'innorutara',
#   'yen',
#   'asinga',
#   'paduthireenga'],
#  ['shankar',
#   'sir',
#   'avenger',
#   'trailer',
#   'patha',
#   'pola',
#   'irukku',
#   'hollywood',
#   'rangekku',
#   'irukku',
#   'superoooo',
#   'super',
#   'sir',
#   'varthaye',
#   'illa',
#   'vera',
#   'level',
#   'sir'],
#  ['thalaiva', 'super', 'vazhdukkal', 'sangkar', 'sir', 'o', 'team'],
#  ['padam',
#   'release',
#   'agurakulle',
#   'likes',
#   'm',
#   'views',
#   'k',
#   'comment',
#   'conduvaranu'],
#  ['nalaiku',
#   'thala',
#   'ya',
#   'pakaporommarana',
#   'waitingfor',
#   'thalapathy',
#   'fans'],
#  ['sathiyama',
#   'soldran',
#   'ivarku',
#   'vasayae',
#   'agalaena',
#   'oru',
#   'energy',
#   'at',
#   'this',
#   'age'],
#  ['how', 'to', 'draw', 'kaithi', 'karthi'],
#  ['sirappana',
#   'tharamaana',
#   'sambavangala',
#   'pongal',
#   'ku',
#   'dha',
#   'paaka',
#   'poringavarardhu',
#   'thalaivaru',
#   'petta',
#   'paraakk'],
#  ['hotspot',
#   'on',
#   'pannunga',
#   'da',
#   'trailer',
#   'paaka',
#   'mudila',
#   'net',
#   'slow',
#   'ahh',
#   'iruku'],
#  ['jithu', 'kaha', 'wait', 'pandravanga', 'hit', 'like'],
#  ['m',
#   'views',
#   'varavae',
#   'innum',
#   'oru',
#   'vaaram',
#   'aagum',
#   'pola',
#   'ha',
#   'ha',
#   'vandu',
#   'muruganukku',
#   'vandha',
#   'sodhanai'],
#  ['in', 'srilanka', 'trending', 'thala', 'super'],
#  ['ennappa',
#   'ponagakuku',
#   'release',
#   'panrentu',
#   'january',
#   'release',
#   'date',
#   'solreenga'],
#  ['trailer', 'na', 'ippadi', 'irukkanum', 'enna', 'mass'],
#  ['seri', 'kadaisiya', 'varrathu', 'rajiniyaa', 'illa', 'ms', 'baskar', 'aah'],
#  ['viswasam', 'vs', 'petta', 'viswasam', 'like', 'petta', 'comment'],
#  ['intha',
#   'movie',
#   'sk',
#   'career',
#   'la',
#   'ramba',
#   'important',
#   'ana',
#   'movie',
#   'ah',
#   'irukumnu',
#   'nenaikaravanga',
#   'oru',
#   'like',
#   'podunga'],
#  ['nellai',
#   'chiyaan',
#   'vikram',
#   'veriyargal',
#   'vara',
#   'level',
#   'thalaiva',
#   'chiyaan',
#   'vikram',
#   'i',
#   'am',
#   'writing',
#   'your',
#   'movie'],
#  ['pakka',
#   'thana',
#   'pora',
#   'intha',
#   'kaali',
#   'oda',
#   'aattatha',
#   'thalivar',
#   'vera',
#   'level',
#   'only',
#   'one',
#   'super',
#   'one'],
#  ['padam', 'pathavanga', 'like', 'pannunga', 'sema', 'movie'],
#  ['i',
#   'like',
#   'you',
#   'vikram',
#   'and',
#   'i',
#   'love',
#   'vikram',
#   'semma',
#   'mass',
#   'thala'],
#  ['i', 'think', 'vaseegaran', 'will', 'die', 'in', 'this', 'movie'],
#  ['nenga',
#   'sonna',
#   'varthaiga',
#   'wait',
#   'pandrom',
#   'thala',
#   'ungala',
#   'mari',
#   'amaidhiyaaaaaaaaaaaaaaa'],
#  ['vera', 'level', 'trailler', 'hit', 'like', 'for', 'trailler'],
#  ['vera', 'level', 'trailer', 'marana', 'waiting', 'movie', 'ku'],
#  ['action', 'king', 'arjun', 'fans', 'like', 'here'],
#  ['oo',
#   'thookudurai',
#   'ipo',
#   'lawyer',
#   'ra',
#   'seri',
#   'seri',
#   'director',
#   'siva',
#   'illa',
#   'apo',
#   'padam',
#   'nalla',
#   'dha',
#   'irukum',
#   'trruku',
#   'thakida',
#   'trruku',
#   'thakida'],
#  ['that',
#   'dialogue',
#   'oruthar',
#   'mela',
#   'irukra',
#   'viswasthukaga',
#   'inoruthara',
#   'yen',
#   'asinga',
#   'paduthuringa',
#   'thala',
#   'special',
#   'yuvan'],
#  ['bangam', 'semmaya', 'irukku', 'hit', 'aaga', 'vaazhthukal'],
#  ['thalaiva', 'vaa', 'thalaiva', 'get', 'rajinified', 'semma', 'wow'],
#  ['karthi',
#   'anna',
#   'fans',
#   'like',
#   'i',
#   'am',
#   'fan',
#   'of',
#   'karthi',
#   'anna',
#   'i',
#   'like',
#   'him'],
#  ['when',
#   'comes',
#   'i',
#   'felt',
#   'like',
#   'sivakarthikeyan',
#   'mass',
#   'ka',
#   'bap',
#   'rajani',
#   'sir'],
#  ['ulaga', 'sarithira', 'nayagan', 'dhanush', 'rasikan', 'da'],
#  ['sahoo', 'pada', 'titile', 'slogan', 'ah', 'suturukange'],
#  ['expect', 'pannadhu', 'da', 'kamiya', 'thaan', 'irruku'],
#  ['until', 'goosebumps', 'scenes', 'masss', 'kattuvaaru', 'karthi'],
#  ['ellathukkum',
#   'padam',
#   'edukkuringaleh',
#   'sir',
#   'kudikkira',
#   'appakalala',
#   'avashttha',
#   'padura',
#   'pettha',
#   'ponnunga',
#   'avashttha',
#   'paduratha',
#   'ea',
#   'oru',
#   'padama',
#   'edukka',
#   'mattakkuringa'],
#  ['enaku',
#   'vijay',
#   'a',
#   'putikathu',
#   'anaa',
#   'vijay',
#   'sethupathi',
#   'ya',
#   'thavira',
#   'evanayum',
#   'putikathu',
#   'massss',
#   'vs'],
#  ['gv', 'prakash', 'phhhhh', 'bgm', 'vera', 'level', 'thalaivaaaaaaaaaaa'],
#  ['en',
#   'da',
#   'movie',
#   'name',
#   'sangatamilan',
#   'titlecardlaya',
#   'vijaya',
#   'movies',
#   'hindila',
#   'varuthu',
#   'da',
#   'what',
#   'raaaa'],
#  ['i', 'am', 'chitti', 'reloaded', 'version'],
#  ['enna', 'da', 'onnume', 'puriyala', 'enna', 'da', 'nadakkuthu'],
#  ['thala', 'and', 'yuvan', 'mega', 'mass'],
#  ['vikram', 'he', 'to', 'best', 'hi', 'hogi'],
#  ['varusham',
#   'ula',
#   'iruntha',
#   'thana',
#   'sir',
#   'theriyum',
#   'athuku',
#   'munadi',
#   'ena',
#   'panitu',
#   'irunthanu',
#   'theriyathula'],
#  ['purinchukkanga',
#   'bosss',
#   'oruthar',
#   'mela',
#   'visawasam',
#   'katta',
#   'inooruvarai',
#   'asinkapadutateengathalaye',
#   'sollittar'],
#  ['dhanush',
#   'vetrimaranvera',
#   'inna',
#   'venum',
#   'padam',
#   'blockbusternu',
#   'solrathukuasuran'],
#  ['goosebumps', 'at', 'awesome', 'look', 'my'],
#  ['ayyyoooooo', 'thalaivaaaa', 'final', 'scene', 'semmmmaaaa', 'love', 'you'],
#  ['john', 'wick', 'tamil', 'remake', 'mari', 'iruku'],
#  ['waiting', 'for', 'big', 'screen', 'thalaivaaaaa'],
#  ['pink', 'movie', 'remake', 'amitabh', 'tapsee', 'pannu', 'remake'],
#  ['somehow', 'it', 'look', 'like', 'telugu', 'sri', 'mahalaxmi', 'movie'],
#  ['pubg', 'la', 'loot', 'adikravana', 'sudra', 'mathri', 'irukuj'],
#  ['verithanathuku',
#   'maru',
#   'peyar',
#   'thalaivar',
#   'hit',
#   'like',
#   'thalaivar',
#   'verians'],
#  ['thalaivaaa',
#   'thank',
#   'you',
#   'karthik',
#   'sir',
#   'to',
#   'gv',
#   'us',
#   'old',
#   'rajinikanth'],
#  ['i',
#   'am',
#   'big',
#   'thala',
#   'fan',
#   'thala',
#   'kita',
#   'irrukura',
#   'hardwork',
#   'dedication',
#   'ella',
#   'chiyan',
#   'vikram',
#   'sir',
#   'kitta',
#   'so',
#   'avara',
#   'romba',
#   'pidikum'],
#  ['you', 'bgm', 'vera', 'leval', 'thala', 'masss'],
#  ['ennpa', 'gv', 'nkp', 'bgm', 'manasula', 'vanthutu', 'pokuthu'],
#  ['thala', 'unna', 'ippdi', 'patthu', 'evola', 'nall', 'aachu'],
#  ['superb', 'shankar', 'and', 'super', 'star', 'rocks'],
#  ['pink', 'tapsee', 'panu', 'and', 'big', 'b'],
#  ['kamalkaga', 'ellam', 'illa', 'only', 'chiyan', 'chiyan', 'vikram'],
#  ['ada', 'kilada', 'vayasuku', 'kondu', 'vanthutaanga'],
#  ['vere', 'level', 'ultimate', 'star'],
#  ['dislike',
#   'panavangaluku',
#   'last',
#   'la',
#   'varum',
#   'dialogue',
#   'dan',
#   'correct'],
#  ['congrats', 'vikram', 'sir', 'from', 'suriya', 'fans'],
#  ['enaku', 'enamoo', 'doubt', 'ah', 'dhan', 'eruku'],
#  ['thala', 'thala', 'dhan', 'paa'],
#  ['bigil', 'bigil', 'bigil', 'bigil', 'bigil'],
#  ['super', 'movie', 'and', 'kamala', 'kalasa', 'samma'],
#  ['thala', 'fans', 'enti', 'active', 'ga', 'leru'],
#  ['antha', 'paiyanugu', 'payam', 'illa', 'pollathavan', 'aruran'],
#  ['avara', 'control', 'pannunga', 'pls', 'evan', 'vanthalum', 'mudiyathu'],
#  ['idhu',
#   'madhiri',
#   'innu',
#   'neraya',
#   'neraya',
#   'neraya',
#   'maass',
#   'kaatuvaru',
#   'enga',
#   'thala'],
#  ['awesome',
#   'trailer',
#   'bro',
#   'final',
#   'dialogue',
#   'is',
#   'saaguradhaa',
#   'irundhaalum',
#   'sandai',
#   'pottu',
#   'saganum'],
#  ['aug',
#   'varaikum',
#   'wait',
#   'panna',
#   'mudiyathunu',
#   'ninaikiravanga',
#   'oru',
#   'like',
#   'podunga'],
#  ['okay', 'for', 'kadaaram', 'kondan', 'chiyan', 'mass'],
#  ['vera', 'leval', 'any', 'sk', 'fans', 'here'],
#  ['semma', 'chiyaana', 'kannukku', 'kulurchchiya', 'paaththen', 'chiyaanism'],
#  ['yethana', 'peruku', 'christian', 'bale', 'neyabagam', 'vandadhu'],
#  ['kettukanga',
#   'thala',
#   'fans',
#   'oruthar',
#   'mela',
#   'katra',
#   'visuvasathula',
#   'matha',
#   'vangala',
#   'kevala',
#   'paduthathinga'],
#  ['tribute', 'to', 'support', 'us', 'shankar', 'sir', 'rajani', 'sir'],
#  ['yen',
#   'manathuku',
#   'ethamaga',
#   'erukum',
#   'song',
#   'vaanil',
#   'irul',
#   'soolum',
#   'pothu'],
#  ['ayyo', 'thalaiva', 'kolriye', 'ummmmmmma', 'love', 'you', 'thalaiva'],
#  ['ayiram', 'varatum', 'ulagam', 'sutrum', 'vaaliban', 'mari', 'varathu'],
#  ['antha', 'aalu', 'ethai', 'thottaalum', 'vetrythan', 'super', 'star'],
#  ['thanks',
#   'to',
#   'karthick',
#   'subbaraj',
#   'kalakitingathalapathy',
#   'movie',
#   'la',
#   'thalaivar',
#   'patha',
#   'mathri',
#   'iruku'],
#  ['ennada', 'ithu', 'marana', 'masssss', 'ah', 'iruku'],
#  ['waiting',
#   'for',
#   'petta',
#   'and',
#   'peranbu',
#   'mammookka',
#   'rajini',
#   'thalapathy'],
#  ['bgm', 'marana', 'mass', 'dhanush', 'fans', 'like', 'panunga'],
#  ['inniki', 'trailer', 'pakravanga', 'like', 'pottu', 'ponga'],
#  ['vera', 'level', 'teaser', 'you', 'bgm', 'semma'],
#  ['awesome', 'looks', 'like', 'hollywood', 'trailer'],
#  ['podra', 'vediya', 'deepavali', 'ku', 'oru', 'karumathi', 'irukku'],
#  ['ithaiyum', 'dis', 'like', 'panna', 'epdi', 'da', 'manasu', 'varathu'],
#  ['my', 'kadavul', 'tharisanamlove', 'you', 'thala'],
#  ['ena',
#   'ya',
#   'trailer',
#   'ke',
#   'a',
#   'certificate',
#   'kudukanum',
#   'pola',
#   'iruke'],
#  ['oruthar',
#   'mela',
#   'irukkura',
#   'viswasathila',
#   'aduthavara',
#   'ean',
#   'asinga',
#   'paduthireenga',
#   'sema',
#   'sema',
#   'thala'],
#  ['thala', 'you', 'combo', 'mass'],
#  ['thaa', 'eduthu', 'vainga', 'da', 'adutha', 'national', 'award', 'ah'],
#  ['thalapathy',
#   'fan',
#   'ah',
#   'soldrean',
#   'kandippah',
#   'national',
#   'award',
#   'win',
#   'pannum'],
#  ['vera', 'leval', 'waiting', 'thalaivaaaaa'],
#  ['thank',
#   'you',
#   'karthick',
#   'subhuraj',
#   'sir',
#   'because',
#   'thalaivarvichi',
#   'kallakitingamass',
#   'marana',
#   'mass'],
#  ['did', 'rajini', 'turn', 'into', 'akshay'],
#  ['wowwwwwwwwwwwww', 'danush', 'annaaaaaaa', 'love', 'you', 'so', 'much'],
#  ['intha', 'padam', 'aachum', 'vjs', 'ku', 'hit', 'agatumvalthukal', 'bro'],
#  ['rajini',
#   'sir',
#   'shankar',
#   'and',
#   'akshay',
#   'kumar',
#   'sir',
#   'hats',
#   'off',
#   'vyara',
#   'level'],
#  ['any', 'kusuvasam', 'fans', 'herehit', 'like', 'button'],
#  ['thalaivaaaaaaaaaaaa',
#   'namaku',
#   'thevayaadha',
#   'nama',
#   'dhan',
#   'adichi',
#   'pudunganum',
#   'thalaivaaaaaaaa',
#   'verithanammmmm'],
#  ['bahubali',
#   'records',
#   'out',
#   'of',
#   'signal',
#   'shankar',
#   'daww',
#   'rajini',
#   'daww',
#   'arr',
#   'dawww',
#   'vfx',
#   'daww',
#   'old',
#   'is',
#   'always',
#   'gold'],
#  ['ajith', 'fans', 'last', 'dialogue', 'ungaluku', 'than'],
#  ['thalai', 'kaaga', 'wait', 'pannavanga', 'like', 'podunga'],
#  ['movieku', 'evlo', 'per', 'wait', 'panrega'],
#  ['trending', 'nerkonda', 'paarvai', 'sahoo'],
#  ['wow', 'wow', 'wow', 'is', 'awesome'],
#  ['thala',
#   'mass',
#   'lookpodra',
#   'vediya',
#   'vetra',
#   'cakeaaaaaaaaallpl',
#   'veri',
#   'eruthu',
#   'da',
#   'thalaya',
#   'pathathum'],
#  ['santhosh',
#   'narayan',
#   'music',
#   'pottu',
#   'iruntha',
#   'innum',
#   'nalla',
#   'irunthu',
#   'irukum'],
#  ['ohhh', 'aaa', 'telugu', 'remake', 'of', 'ravi', 'tejas', 'bengal', 'tiger'],
#  ['asuran',
#   'padam',
#   'pathavanga',
#   'like',
#   'podunga',
#   'next',
#   'big',
#   'screen',
#   'bigil'],
#  ['shankar',
#   'sir',
#   'ungaloda',
#   'imagination',
#   'vera',
#   'level',
#   'but',
#   'cg',
#   'ok',
#   'than'],
#  ['all',
#   'the',
#   'best',
#   'chiyan',
#   'waiting',
#   'for',
#   'kadaram',
#   'kondan',
#   'wishes',
#   'from',
#   'kerala',
#   'suriya',
#   'fans'],
#  ['inum',
#   'neraya',
#   'neraya',
#   'neraya',
#   'neraya',
#   'neraya',
#   'likes',
#   'and',
#   'views',
#   'varanum'],
#  ['bigiil', 'mokka', 'padam', 'kaithii', 'awesome'],
#  ['sirapana',
#   'tharamana',
#   'sambavam',
#   'la',
#   'intha',
#   'padathula',
#   'dha',
#   'iruku',
#   'each',
#   'and',
#   'every',
#   'scene',
#   'goosebumps'],
#  ['lena', 'n', 'vikram', 'kidu', 'combination', 'i', 'am', 'waiting'],
#  ['evanda', 'dislike', 'pottan', 'paithiya', 'karan', 'stupid'],
#  ['ithu',
#   'vera',
#   'mathri',
#   'padam',
#   'masala',
#   'padam',
#   'illa',
#   'thala',
#   'love',
#   'thala'],
#  ['more', 'like', 'a', 'games', 'trailer', 'p'],
#  ['kajal', 'fans', 'subscribe'],
#  ['thala', 'block', 'buster', 'movie', 'in', 'viswasam', 'nkp'],
#  ['vetri', 'maran', 'thalaiva', 'neenga', 'eduthale', 'vetri', 'thannnnnnnn'],
#  ['idhu',
#   'hollywood',
#   'madhiri',
#   'irukunu',
#   'solravangalan',
#   'indha',
#   'cmnt',
#   'ta',
#   'like',
#   'pannunga'],
#  ['trailer', 'na', 'athu', 'ethu', 'than'],
#  ['so', 'many', 'many', 'many', 'many', 'many'],
#  ['indha', 'movie', 'la', 'edho', 'oru', 'periya', 'message', 'irukkusuper'],
#  ['ending',
#   'la',
#   'teaser',
#   'bgm',
#   'la',
#   'vara',
#   'ending',
#   'vacha',
#   'inum',
#   'mass',
#   'irkum'],
#  ['wowww',
#   'thalaivaa',
#   'kalakitega',
#   'sure',
#   'pongal',
#   'winner',
#   'dhan',
#   'neenga'],
#  ['yarellam',
#   'padam',
#   'paarthaachu',
#   'arputhamaana',
#   'padamdo',
#   'not',
#   'miss',
#   'it'],
#  ['innum', 'naraya', 'naraya', 'naraya', 'naraya', 'thadava', 'pakkanum'],
#  ['thalaiva', 'aaaaaaa', 'final', 'seen', 'mine', 'god'],
#  ['super', 'style', 'thalaivaa', 'neenga', 'vera', 'level'],
#  ['rajni', 'turn', 'into', 'akki', 'in', 'last'],
#  ['neenga',
#   'vilayaadunathu',
#   'engita',
#   'illa',
#   'eman',
#   'kitta',
#   'chiyaan',
#   'rocks'],
#  ['thalaiva', 'looking', 'good', 'even', 'at', 'semme'],
#  ['unofficial',
#   'sequel',
#   'of',
#   'vada',
#   'chennai',
#   'note',
#   'it',
#   'is',
#   'not',
#   'vada',
#   'chennai',
#   'vetrimaaran',
#   'dawww'],
#  ['semmma', 'super', 'chance', 'a', 'ila'],
#  ['rajini', 'sir', 'fan', 'hit', 'like', 'that'],
#  ['engineering', 'aaganum', 'miss', 'athalaaaam', 'oru', 'kaalam'],
#  ['next', 'aadukalam', 'is', 'loading', 'ha'],
#  ['innaiku',
#   'nightu',
#   'theriyum',
#   'yaaru',
#   'weightuu',
#   'nukalathula',
#   'sandhipomby',
#   'visawasiiii'],
#  ['eppa',
#   'kutti',
#   'moonji',
#   'all',
#   'the',
#   'best',
#   'unakenna',
#   'pa',
#   'big',
#   'screen',
#   'le',
#   'la',
#   'varuva',
#   'naanga',
#   'apdiya'],
#  ['enna', 'ba', 'netflix', 'web', 'series', 'maari', 'feel', 'aaguthu'],
#  ['ipdi', 'neraya', 'neraya', 'neraya', 'padam', 'nadikanum', 'thala', 'nee'],
#  ['super', 'star', 'super', 'film'],
#  ['savaratha',
#   'iruntha',
#   'kuda',
#   'sanda',
#   'pottu',
#   'savanu',
#   'sir',
#   'payanthu',
#   'kalla',
#   'vilunthira',
#   'kudathu',
#   'karthi',
#   'is',
#   'back',
#   'in',
#   'action'],
#  ['cmt', 'enna', 'fans', 'da', 'samy', 'thala', 'vera', 'tha'],
#  ['k', 'views', 'k', 'likes', 'views', 'stuck', 'up'],
#  ['unakennapa',
#   'sivakarthikeyan',
#   'koodalam',
#   'nadula',
#   'naangalam',
#   'apdiya'],
#  ['all',
#   'the',
#   'best',
#   'to',
#   'thalaivar',
#   'rajinikanth',
#   'sir',
#   'from',
#   'malayalam',
#   'superstar',
#   'prithviraj',
#   'sukumaran',
#   'fans'],
#  ['telugu', 'fans', 'need', 'thalaivas', 'peta', 'telugu', 'trailer'],
#  ['kaasa',
#   'micham',
#   'panna',
#   'paatha',
#   'sathiyama',
#   'music',
#   'nalla',
#   'irukkadhu'],
#  ['a', 'wa', 'ng', 'or'],
#  ['feeling',
#   'the',
#   'vintage',
#   'thalaivarannamalai',
#   'arunachal',
#   'basha',
#   'padaiyapa',
#   'elathiyum',
#   'sethu',
#   'vechu',
#   'paakura',
#   'matiri',
#   'irukusema',
#   'anyone',
#   'feels',
#   'the',
#   'same'],
#  ['pakkaa', 'mass', 'rajni', 'and', 'akshay', 'sema', 'mirattal'],
#  ['neraya', 'neraya', 'nerayaaaaaaa', 'peru', 'waiting', 'thala'],
#  ['trailer',
#   'lam',
#   'nalla',
#   'than',
#   'pa',
#   'iruku',
#   'unkita',
#   'finishing',
#   'sari',
#   'illaye',
#   'pa'],
#  ['epo', 'enna', 'panna', 'poromsweat', 'sapda', 'porom'],
#  ['kolakandla', 'irruka', 'pudichavanga', 'like', 'here'],
#  ['last', 'few', 'seconds', 'music', 'video', 'vera', 'levelllll', 'gv', 'da'],
#  ['daily',
#   'um',
#   'at',
#   'least',
#   'one',
#   'time',
#   'achum',
#   'trailer',
#   'eh',
#   'pakuravanga',
#   'like',
#   'podunga'],
#  ['sama',
#   'dailogue',
#   'namaloda',
#   'padipa',
#   'mattum',
#   'yevanalayum',
#   'yeduka',
#   'mudiyathu'],
#  ['gate',
#   'opening',
#   'sceen',
#   'like',
#   'rajinis',
#   'first',
#   'movie',
#   'yarulam',
#   'gavanichinga'],
#  ['va',
#   'thala',
#   'vaaa',
#   'orthar',
#   'mela',
#   'visuvasam',
#   'katturathukaga',
#   'innoruthara',
#   'yan',
#   'acigam',
#   'paduthuriga',
#   'ogga',
#   'nikiraru',
#   'yanga',
#   'thala'],
#  ['mmmm', 'ok', 'super'],
#  ['chinna',
#   'payyan',
#   'mathiri',
#   'stylaa',
#   'irukke',
#   'with',
#   'love',
#   'from',
#   'kerala'],
#  ['adei',
#   'ivar',
#   'pesaura',
#   'ella',
#   'dailogue',
#   'um',
#   'kusuvasam',
#   'ku',
#   'daan',
#   'dedicate',
#   'pola'],
#  ['tee',
#   'jay',
#   'va',
#   'paathingala',
#   'va',
#   'ji',
#   'va',
#   'ji',
#   'unakkudha',
#   'waiting',
#   'ji',
#   'dhanush',
#   'ku',
#   'da',
#   'movie',
#   'ya'],
#  ['last',
#   'dialogue',
#   'thala',
#   'thalapathy',
#   'rendu',
#   'perukkum',
#   'tha',
#   'thala',
#   'pesirukkaru'],
#  ['want', 'to', 'see', 'ajak', 'mama', 'in', 'underwear'],
#  ['thala', 'na', 'mass', 'mathavanga', 'ellam', 'thala', 'munnadi', 'duss'],
#  ['thala', 'always', 'thala', 'dha', 'da'],
#  ['oruthar',
#   'mela',
#   'irruka',
#   'viswasathukka',
#   'mathavangala',
#   'en',
#   'asinga',
#   'paduthiringa',
#   'thala',
#   'thala',
#   'thala'],
#  ['othaaaaa',
#   'maranama',
#   'daaa',
#   'yeppaaaaaaa',
#   'veraaaa',
#   'level',
#   'yaaaa',
#   'nammadiwalikaithii'],
#  ['thala',
#   'and',
#   'thalabathi',
#   'avanga',
#   'fans',
#   'ku',
#   'solla',
#   'asapadradhu',
#   'ithu',
#   'thaan',
#   'piurinjukonga',
#   'da',
#   'deiii'],
#  ['thalaivaaaaa',
#   'vayasilayum',
#   'padam',
#   'nadikkuradhu',
#   'satharanamana',
#   'vishayam',
#   'illa',
#   'super',
#   'star',
#   'rajini',
#   'the',
#   'legend',
#   'india',
#   'cinemavin',
#   'pokkisham'],
#  ['kolai',
#   'gandula',
#   'iruken',
#   'kollama',
#   'vida',
#   'matenwat',
#   'a',
#   'mass',
#   'n',
#   'stylish',
#   'man',
#   'yar'],
#  ['part', 'venum', 'ngravanga', 'like', 'pannunga'],
#  ['mass',
#   'of',
#   'massa',
#   'tamil',
#   'cinima',
#   'to',
#   'hollywood',
#   'level',
#   'vara',
#   'level',
#   'shankar',
#   'rajinikhanth',
#   'tamilandaaaa'],
#  ['evan',
#   'vanthaluminthe',
#   'pongaluku',
#   'naagethandahit',
#   'like',
#   'if',
#   'you',
#   'agree'],
#  ['appa',
#   'oru',
#   'vazhiya',
#   'thrisa',
#   'n',
#   'simran',
#   'kooda',
#   'jodi',
#   'pottaachi'],
#  ['ama', 'vadivela', 'en', 'da', 'asingam', 'paduthuringa'],
#  ['super', 'super', 'super', 'super', 'super', 'super'],
#  ['maranam',
#   'maranam',
#   'maranam',
#   'maranam',
#   'maranam',
#   'maranam',
#   'maranam',
#   'maranam',
#   'maranam'],
#  ['range', 'rajan', 'sir', 'mmm', 'super', 'enga', 'thalakuda', 'wow'],
#  ['thalaiva',
#   'coollip',
#   'ah',
#   'thuppitu',
#   'pesu',
#   'thalaiva',
#   'vasanamae',
#   'puriyala'],
#  ['shankar',
#   'sir',
#   'evanavthu',
#   'katha',
#   'enodathunu',
#   'solli',
#   'varuvan',
#   'be',
#   'careful',
#   'sir'],
#  ['na',
#   'vijay',
#   'fan',
#   'than',
#   'irunthalum',
#   'ajithuku',
#   'likoooooooooooooooooo',
#   'like'],
#  ['thala', 'look', 'yeh', 'vera', 'maaari', 'irukku'],
#  ['bit', 'like', 'avengers', 'age', 'of', 'ultron'],
#  ['dei', 'enra', 'ithu'],
#  ['hollywood', 'movie', 'eh', 'tuff', 'kudikum', 'poliea', 'indha', 'movie'],
#  ['waiting', 'king', 'of', 'bgm', 'you', 'yuvan', 'shankar', 'raja'],
#  ['thala', 'mass', 'yuvan', 'bgm', 'mass'],
#  ['chitti', 'vs', 'chittu', 'kuruvi', 'story'],
#  ['oruthar',
#   'mela',
#   'viswasam',
#   'kaaturatgukku',
#   'innoruthara',
#   'yen',
#   'asinga',
#   'paduthuringa'],
#  ['pink', 'movie', 'remake', 'but', 'nice', 'one'],
#  ['ithuku', 'thaana', 'sivakumar', 'cell', 'phone', 'a', 'thatti', 'vittaru'],
#  ['suyama', 'sinthika', 'therinjavan', 'tha', 'super', 'hero'],
#  ['paravala', 'etho', 'teaser', 'oda', 'trailer', 'pakkala', 'time'],
#  ['graphics',
#   'sari',
#   'illa',
#   'nu',
#   'solrathukune',
#   'oru',
#   'gang',
#   'suthum',
#   'parunga'],
#  ['nerkonda', 'paarvai', 'trailer', 'as', 'd', 'version'],
#  ['millon', 'like', 'kaga', 'wait', 'pandra'],
#  ['ena', 'pa', 'ipdi', 'iruku', 'vera', 'level'],
#  ['thala', 'pesina', 'samaya', 'iruku', 'thala', 'thala', 'thaan'],
#  ['vayasaanaalum', 'style', 'apdiye', 'iruku', 'ya', 'wow', 'sema'],
#  ['thala',
#   'semma',
#   'semma',
#   'congratulations',
#   'from',
#   'kanyakumari',
#   'simbu',
#   'fans'],
#  ['maranammassu',
#   'maranamtoughu',
#   'tharanaumadhuku',
#   'avan',
#   'dhaan',
#   'porandhu',
#   'varumsemma',
#   'thalaivaa'],
#  ['headphone',
#   'la',
#   'yuvan',
#   'bgm',
#   'summa',
#   'therikkuthu',
#   'yuvan',
#   'bgm',
#   'vera',
#   'level'],
#  ['thala', 'mass', 'bgm', 'mass', 'maran', 'mass'],
#  ['my', 'favorite', 'hero', 'thala', 'biggest', 'movie', 'god', 'bless'],
#  ['thala', 'ajith', 'kumar', 'tamil', 'cinema', 'mass'],
#  ['ajithu',
#   'vijay',
#   'vanthalum',
#   'rajini',
#   'ya',
#   'onum',
#   'panamutiyathula',
#   'only',
#   'one',
#   'supar',
#   'one',
#   'rajini'],
#  ['ivuru',
#   'ippathaan',
#   'oru',
#   'nalla',
#   'padathula',
#   'nadikararrunnu',
#   'nenaikareen'],
#  ['tamil', 'cinema', 'va', 'vittu', 'velila', 'vanthu', 'edungada'],
#  ['thalana', 'summa', 'va', 'vera', 'evanukum', 'setagaathu'],
#  ['moka', 'to', 'ivana', 'yevan', 'padam', 'nadaika', 'sonnan'],
#  ['petta', 'is', 'just', 'k', 'likes', 'but', 'viswasam', 'is', 'm', 'likes'],
#  ['we', 'are', 'going', 'to', 'see', 'vera', 'level', 'thala'],
#  ['kaali',
# ...
#  ['enga',
#   'thalaivana',
#   'verukave',
#   'mudiyathu',
#   'sema',
#   'mass',
#   'veral',
#   'level'],
#  ['nee',
#   'va',
#   'thala',
#   'vasanalum',
#   'algum',
#   'styleum',
#   'ungala',
#   'vittu',
#   'pogala'],
#  ['seems',
#   'remake',
#   'of',
#   'point',
#   'blank',
#   'if',
#   'i',
#   'm',
#   'not',
#   'mistaken',
#   'but',
#   'point',
#   'blank',
#   'is',
#   'awesome',
#   'movie'],
#  ['padipehmatu',
#   'yavanalu',
#   'yaduka',
#   'mudiyadhu',
#   'semma',
#   'dialogue',
#   'fdfs',
#   'waiting'],
#  ['yebbah',
#   'dei',
#   'nalla',
#   'padatha',
#   'keduthutingale',
#   'da',
#   'go',
#   'and',
#   'watch',
#   'pink'],
#  ['padippu', 'mattum', 'yaralaiyum', 'eduka', 'mudiyathu', 'semma'],
#  ['now', 'rajni', 'sir', 'fans', 'be', 'like'],
#  ['mass',
#   'mass',
#   'parak',
#   'pongal',
#   'one',
#   'only',
#   'super',
#   'one',
#   'rajinikanth'],
#  ['namakita',
#   'kadu',
#   'iruntha',
#   'eduthupangapanam',
#   'iruntha',
#   'pudingipangapadipu',
#   'matum',
#   'eduthakve',
#   'mudiyathudialogue',
#   'sema'],
#  ['i',
#   'am',
#   'sk',
#   'fan',
#   'but',
#   'vjs',
#   'rombhaaaaaaaaaaaa',
#   'ptikum',
#   'anaaaaaaaaaaaaaaaaa',
#   'acting',
#   'vera',
#   'level'],
#  ['thala',
#   'kola',
#   'maasss',
#   'ingayum',
#   'sila',
#   'echa',
#   'naaiga',
#   'vanthu',
#   'less',
#   'views',
#   'less',
#   'likes',
#   'nu',
#   'kadharitu',
#   'irukanuga',
#   'potta',
#   'pasanga'],
#  ['pink', 'trailer', 'kuda', 'appidiye', 'copy', 'pannitenka'],
#  ['last',
#   'theme',
#   'music',
#   'looks',
#   'like',
#   'nerkonda',
#   'parvai',
#   'vaa',
#   'mothi',
#   'paaru'],
#  ['light', 'working', 'kaka', 'pathavanga', 'like', 'podunga'],
#  ['adei', 'adhukullayuma', 'k', 'views', 'trailer'],
#  ['thalivaaaaaaaaa',
#   'neeee',
#   'semma',
#   'i',
#   'love',
#   'you',
#   'soo',
#   'muchmake',
#   'way',
#   'for',
#   'the',
#   'king'],
#  ['kaithi',
#   'eh',
#   'ippadi',
#   'na',
#   'appea',
#   'thalapati',
#   'dei',
#   'naan',
#   'thala',
#   'fan',
#   'da',
#   'eanake',
#   'veari',
#   'asguthu'],
#  ['mass', 'dialogue', 'ipo', 'atha', 'than', 'panitu', 'irrukanga'],
#  ['padathulaa',
#   'fight',
#   'scene',
#   'iruku',
#   'enga',
#   'illama',
#   'poiyurumonu',
#   'neenaichee'],
#  ['ethula', 'i', 'think', 'thala', 'kami', 'sean', 'la', 'tha', 'varuvara'],
#  ['saaho', 'has', 'highest', 'views', 'than', 'nerkonda', 'paarvai'],
#  ['vera', 'level', 'thala', 'ultimate', 'star'],
#  ['yen',
#   'thalaivan',
#   'ayaz',
#   'irukkana',
#   'superu',
#   'nallathaan',
#   'irukkum',
#   'pola',
#   'pa'],
#  ['my', 'hero', 'karthi', 'sir', 'uyir'],
#  ['we', 'want', 'kannada', 'versions'],
#  ['sec', 'bgm', 'like', 'viswasam'],
#  ['i',
#   'am',
#   'dissapointed',
#   'ongaluku',
#   'epdinu',
#   'theriyala',
#   'but',
#   'ennaku',
#   'satisfy',
#   'agala'],
#  ['sasi', 'kumar', 'mass', 'thalaivaa'],
#  ['only',
#   'one',
#   'ask',
#   'for',
#   'you',
#   'all',
#   'tala',
#   'pola',
#   'varuma',
#   'talada'],
#  ['ippo',
#   'puriyuthu',
#   'en',
#   'title',
#   'ner',
#   'konda',
#   'paarvai',
#   'nu',
#   'vachanganu'],
#  ['this',
#   'movie',
#   'is',
#   'telugu',
#   'movie',
#   'remake',
#   'movie',
#   'name',
#   'sri',
#   'mahalakshmi'],
#  ['trending', 'nothala', 'daw', 'vera', 'evan', 'daaa'],
#  ['waiting', 'but', 'me', 'vijay', 'anna', 'rasigan'],
#  ['oorula',
#   'unnakoru',
#   'meda',
#   'vaanula',
#   'la',
#   'unnakoru',
#   'mancham',
#   'thala',
#   'nee',
#   'parkum',
#   'paarvai',
#   'parava',
#   'paarvayadaa',
#   'ithu',
#   'enga',
#   'thalaiku',
#   'thaan',
#   'porunthum'],
#  ['enee',
#   'maye',
#   'da',
#   'miga',
#   'sirappana',
#   'sambavagella',
#   'kaathirukku',
#   'petta',
#   'parak'],
#  ['mersal',
#   'petta',
#   'sarkar',
#   'viswasam',
#   'ipadi',
#   'ellam',
#   'movie',
#   'record',
#   'kandipa',
#   'break',
#   'pannum'],
#  ['tnks',
#   'fr',
#   'thala',
#   'mass',
#   'mov',
#   'ah',
#   'sel',
#   'panam',
#   'ah',
#   'ipdi',
#   'oru',
#   'nala',
#   'scriptku',
#   'act',
#   'panringa'],
#  ['nethanepa', 'nama', 'valanumna', 'yaravenalum', 'kollalamnu', 'sonna'],
#  ['h', 'vinoth', 'super', 'ji', 'thala', 'masssssssssss'],
#  ['i',
#   'am',
#   'waiting',
#   'dhanush',
#   'thalaivaaaaaaaaaaaa',
#   'first',
#   'day',
#   'first',
#   'show',
#   'i',
#   'am',
#   'go',
#   'i',
#   'love',
#   'you',
#   'dhanush',
#   'anna'],
#  ['vere',
#   'level',
#   'thalaivaa',
#   'karthik',
#   'subbaraj',
#   'sir',
#   'vere',
#   'maari',
#   'irukk',
#   'unga',
#   'characterization'],
#  ['ena', 'pa', 'padam', 'nalla', 'irukum', 'polaye'],
#  ['dislikers', 'please', 'step', 'back', 'k', 'kaithi', 'diwali'],
#  ['enikoru',
#   'doubt',
#   'kadaram',
#   'kondan',
#   'um',
#   'drivanatchathiram',
#   'vm',
#   'rand',
#   'cnma',
#   'aano',
#   'atho',
#   'onnaano'],
#  ['arjun', 'sir', 'like', 'sk', 'comments', 'game', 'start', 'now'],
#  ['vera', 'level', 'yuvan', 'bgm', 'thala', 'mass'],
#  ['sukranle',
#   'thalapathy',
#   'vijay',
#   'vandhamari',
#   'thala',
#   'ajith',
#   'varapley'],
#  ['indian',
#   'biggest',
#   'budget',
#   'film',
#   'keep',
#   'support',
#   'our',
#   'super',
#   'star',
#   'rajini',
#   'sir'],
#  ['thoo', 'kelatqpaiya', 'naaye', 'ka', 'pecha', 'para', 'thoo'],
#  ['twitter', 'ku', 'vanga', 'thala', 'fans'],
#  ['sivakumarah', 'villainah', 'potruntha', 'innum', 'massah', 'irunthirukkum'],
#  ['family',
#   'sentiment',
#   'pondatti',
#   'pullainga',
#   'engayo',
#   'link',
#   'aavuthe',
#   'sun',
#   'pictures',
#   'nalla',
#   'panringa',
#   'thalaivar',
#   'dharisanam'],
#  ['namaku', 'thevaiyanathu', 'awards', 'namba', 'tha', 'adichi', 'vanganum'],
#  ['guys',
#   'porathum',
#   'poringa',
#   'appadiye',
#   'intha',
#   'trailer',
#   'ku',
#   'dislike',
#   'pottutu',
#   'ponaga'],
#  ['ayyyoooo',
#   'thalaivaa',
#   'enna',
#   'solradhune',
#   'therla',
#   'summa',
#   'therikkudhu'],
#  ['dec',
#   'than',
#   'enoda',
#   'birthday',
#   'yaru',
#   'yarula',
#   'hero',
#   'irukingalo',
#   'enaku',
#   'like',
#   'panunga'],
#  ['trailer',
#   'bakwas',
#   'hae',
#   'pr',
#   'movie',
#   'lajawab',
#   'hogi',
#   'akki',
#   'sir',
#   'rajni',
#   'sir'],
#  ['super',
#   'talaivaa',
#   'semma',
#   'aalu',
#   'talaivaa',
#   'waiting',
#   'talaiva',
#   'ponggal',
#   'semma',
#   'trailer'],
#  ['very', 'hard', 'work', 'waiting', 'full', 'movie'],
#  ['epidi',
#   'daa',
#   'veakame',
#   'illama',
#   'unlike',
#   'poduringa',
#   'padam',
#   'blockbuster',
#   'daa'],
#  ['rangaraj', 'panday', 'ku', 'correct', 'aana', 'role'],
#  ['enakku',
#   'mattumtha',
#   'ippudii',
#   'kaatutha',
#   'k',
#   'views',
#   'k',
#   'likes',
#   'how'],
#  ['sirappaana',
#   'tharamaana',
#   'sambavangala',
#   'ineme',
#   'thaan',
#   'pakka',
#   'poreenga',
#   'petta',
#   'paraak'],
#  ['remake',
#   'padamna',
#   'music',
#   'um',
#   'remake',
#   'panra',
#   'vanga',
#   'madhiyila',
#   'thannoda',
#   'own',
#   'music',
#   'pottathu',
#   'sema',
#   'ya',
#   'irukuellam',
#   'you',
#   'mayam'],
#  ['enna',
#   'da',
#   'yapoda',
#   'tarilera',
#   'relase',
#   'pannunga',
#   'viwesa',
#   'kameya',
#   'iruku',
#   'anyway',
#   'semma',
#   'mass',
#   'tariler'],
#  ['my', 'god', 'super', 'anna'],
#  ['ghibran', 'is', 'very', 'unique', 'music', 'composer'],
#  ['makkale',
#   'enga',
#   'channel',
#   'ah',
#   'konjam',
#   'subscribe',
#   'pannunga',
#   'plzz',
#   'friends',
#   'aai',
#   'pasanga'],
#  ['marana', 'mass', 'video', 'song', 'i', 'am', 'weiting'],
#  ['andha',
#   'k',
#   'dislikes',
#   'panna',
#   'potta',
#   'pasangala',
#   'yen',
#   'poola',
#   'vandhu',
#   'oombungada'],
#  ['ajith',
#   'idhe',
#   'mari',
#   'different',
#   'different',
#   'ana',
#   'padam',
#   'panna',
#   'nallarkum'],
#  ['ethulaa',
#   'over',
#   'yaa',
#   'age',
#   'yenakku',
#   'oru',
#   'love',
#   'eilla',
#   'aana',
#   'vayasu',
#   'ullava',
#   'love',
#   'pannuraaga',
#   'mudiyala'],
#  ['asuranhitcomment', 'floplike'],
#  ['petta', 'is', 'going', 'to', 'chase', 'visuvasam'],
#  ['chinna',
#   'payye',
#   'maari',
#   'styla',
#   'irruka',
#   'biggest',
#   'joke',
#   'ever',
#   'made',
#   'to',
#   'a',
#   'years',
#   'old',
#   'man'],
#  ['ajith', 'surya', 'rasigar', 'pooram', 'oompa', 'vantanuka'],
#  ['trisha', 'mam', 'alaga', 'irukaangalove', 'you', 'trisha', 'mam'],
#  ['biggest', 'blockbuster', 'nu', 'solravanga', 'like', 'podalam'],
#  ['thala',
#   'naa',
#   'mass',
#   'thala',
#   'naa',
#   'class',
#   'thala',
#   'naa',
#   'trend',
#   'settar'],
#  ['intha',
#   'trailer',
#   'paatha',
#   'pirahuyarukelam',
#   'thalapathy',
#   'mela',
#   'waiting',
#   'athigama',
#   'iruku'],
#  ['pink', 'movie', 'vs', 'nerkonda', 'paarvai', 'movie'],
#  ['yow',
#   'lahari',
#   'music',
#   'inda',
#   'channel',
#   'karanuku',
#   'epidi',
#   'promotion',
#   'pandranu',
#   'solli',
#   'thangaiya'],
#  ['bigil', 'will', 'eat', 'kaithimark', 'my', 'words'],
#  ['padathukku', 'oru', 'national', 'award', 'parcel'],
#  ['my',
#   'aim',
#   'is',
#   'lawyer',
#   'but',
#   'enala',
#   'aga',
#   'mudiyala',
#   'sila',
#   'karanagala',
#   'but',
#   'en',
#   'thalaya',
#   'antha',
#   'lawyerla',
#   'pakkurapa',
#   'romba',
#   'happyyyaaaa',
#   'iruku'],
#  ['gommala', 'thala', 'da', 'verithanam'],
#  ['dei',
#   'ennada',
#   'conair',
#   'padatha',
#   'kavuthi',
#   'pota',
#   'madiri',
#   'iruku',
#   'unga',
#   'kaithir',
#   'thiruttu',
#   'payale',
#   'lokesuh'],
#  ['maranam',
#   'maasu',
#   'maranam',
#   'tuffu',
#   'tharanum',
#   'athuku',
#   'avan',
#   'thaan',
#   'poranthu',
#   'varanum'],
#  ['yaralaa', 'verithanama', 'wait', 'panittuerukinge', 'm', 'aguruku'],
#  ['pppppaaa',
#   'apdi',
#   'iruku',
#   'semma',
#   'ethana',
#   'time',
#   'tha',
#   'pakarathueagerly',
#   'waiting'],
#  ['semma', 'masso', 'massu', 'love', 'you', 'thala'],
#  ['analum', 'thalai', 'ku', 'siva', 'mela', 'romba', 'viswasam', 'pa'],
#  ['yuvan', 'bgm', 'sema', 'mass', 'vera', 'level', 'goosebumps', 'overloaded'],
#  ['rajini', 'sirdie', 'hard', 'fans', 'from', 'andhra'],
#  ['enada',
#   'ithu',
#   'viswasam',
#   'one',
#   'day',
#   'la',
#   'pana',
#   'views',
#   'and',
#   'likesithu',
#   'moonu',
#   'naal',
#   'agiyum',
#   'thandala'],
#  ['vfx',
#   'innum',
#   'konjam',
#   'nalla',
#   'panirkalam',
#   'shankar',
#   'sir',
#   'cr',
#   'budget',
#   'laye',
#   'tik',
#   'tik',
#   'tik',
#   'world',
#   'class',
#   'vfx'],
#  ['stylish', 'chiyan', 'vikram', 'sir', 'i', 'love', 'you', 'sir'],
#  ['kaalila',
#   'elunthavudaneaa',
#   'straight',
#   'aaaa',
#   'inga',
#   'varavanga',
#   'matum',
#   'likes',
#   'podunga'],
#  ['my', 'age', 'i', 'am', 'rajini', 'fan'],
#  ['pakistani',
#   'movi',
#   'na',
#   'indian',
#   'movi',
#   'ka',
#   'record',
#   'tor',
#   'dia',
#   'salman',
#   'khan',
#   'b',
#   'hairan',
#   'open',
#   'link'],
#  ['rajini',
#   'maderi',
#   'oru',
#   'potta',
#   'paiyanukku',
#   'tamil',
#   'cenimavul',
#   'itam',
#   'kudukkakutadu'],
#  ['superstar', 'vs', 'makkal', 'selvan', 'antha', 'scene', 'epdi', 'irukumo'],
#  ['yoov',
#   'gv',
#   'enaya',
#   'ipd',
#   'bangam',
#   'ah',
#   'bgm',
#   'ah',
#   'potruka',
#   'mass',
#   'uh',
#   'ya'],
#  ['kaipulla', 'vijay', 'twitter', 'la', 'trending', 'agudhu'],
#  ['nee', 'mothurathu', 'enkitta', 'illaeman', 'kittamass', 'mass'],
#  ['gv',
#   'prakash',
#   'music',
#   'vera',
#   'level',
#   'gv',
#   'fans',
#   'hit',
#   'like',
#   'here'],
#  ['world',
#   'number',
#   'one',
#   'craphicsvasul',
#   'vettai',
#   'aarampam',
#   'worldwide',
#   'ithula',
#   'vara',
#   'panam',
#   'konjam',
#   'tamlmakaluku',
#   'help',
#   'panunga',
#   'ok'],
#  ['thala',
#   'nerkonda',
#   'paarvai',
#   'look',
#   'masss',
#   'enga',
#   'thala',
#   'pola',
#   'varumaaaaaa',
#   'nerupu',
#   'da'],
#  ['thala', 'you', 'erundha', 'adhu', 'mass', 'dha'],
#  ['enga',
#   'anna',
#   'varurua',
#   'ella',
#   'uthkittu',
#   'enga',
#   'ana',
#   'vijay',
#   'setepathei'],
#  ['visvasam',
#   'trailer',
#   'trailer',
#   'sppourt',
#   'panavange',
#   'yalaru',
#   'edhuku',
#   'pannuge'],
#  ['vikram',
#   'sir',
#   'nadippuku',
#   'vayasu',
#   'agave',
#   'agathu',
#   'hats',
#   'off',
#   'you'],
#  ['sprb', 'enapa', 'diwali', 'rls', 'october', 'rls', 'aa', 'mari', 'pochu'],
#  ['thala',
#   'rasigayin',
#   'sarbaga',
#   'sangathamizhan',
#   'vetri',
#   'adaya',
#   'vazhuthukal'],
#  ['ajith', 'kumar', 'fan', 'like', 'here'],
#  ['sam',
#   'cs',
#   'enough',
#   'of',
#   'your',
#   'daraa',
#   'darr',
#   'dara',
#   'music',
#   'bgms',
#   'romba',
#   'palasu',
#   'aagirichi'],
#  ['avengersku',
#   'tamilnadula',
#   'aall',
#   'selectionah',
#   'irukara',
#   'super',
#   'hero',
#   'pathalanu',
#   'ivaru',
#   'vera'],
#  ['thalaivar', 'vara', 'laval', 'super', 'trailer', 'o'],
#  ['bgm', 'chumma', 'therikkudhu', 'vikram', 'sir', 'masss'],
#  ['get', 'ready', 'to', 'rajinifieddddddd', 'talaivan', 'daaaaaaa'],
#  ['like', 'poddu', 'trailer', 'pathaa', 'vaingaa', 'like'],
#  ['any', 'rangaraj', 'pandey', 'fans', 'here'],
#  ['times', 'mela', 'pathavanga', 'mattum', 'like', 'it'],
#  ['still', 'messaging', 'ga', 'great', 'yar'],
#  ['just',
#   'k',
#   'like',
#   'reach',
#   'on',
#   'm',
#   'like',
#   'vitraathinga',
#   'like',
#   'ah',
#   'pottu',
#   'therika',
#   'vidunga',
#   'by',
#   'thala',
#   'veriyans'],
#  ['superb', 'thala', 'frm', 'pavan', 'kalyan', 'fans'],
#  ['thalaivaaaaaa', 'magnum', 'ops', 'vera', 'level', 'electrifying', 'mass'],
#  ['ammadiyo',
#   'thala',
#   'da',
#   'nadipu',
#   'vera',
#   'level',
#   'thala',
#   'fan',
#   'endu',
#   'solla',
#   'perumaiya',
#   'ituku',
#   'love',
#   'you',
#   'thala'],
#  ['kaithi',
#   'logesh',
#   'sangatamilan',
#   'vjs',
#   'bigil',
#   'vijay',
#   'all',
#   'are',
#   'in',
#   'vijay'],
#  ['antha',
#   'alavu',
#   'interest',
#   'ah',
#   'illafulla',
#   'girls',
#   'ah',
#   'dha',
#   'katranga'],
#  ['times', 'watch', 'panavan', 'like', 'podu'],
#  ['sk',
#   'fans',
#   'those',
#   'who',
#   'are',
#   'like',
#   'vj',
#   'sethupathi',
#   'podra',
#   'lika',
#   'like',
#   'theriksnum',
#   'sk',
#   'fans'],
#  ['nalla', 'illa', 'na', 'hollywood', 'edhuruparthen'],
#  ['podu', 'vera', 'level', 'love', 'you', 'anna'],
#  ['mass', 'good', 'work', 'keep', 'on', 'rocking', 'superstar'],
#  ['next', 'level', 'to', 'tamil', 'cinema', 'must', 'like'],
#  ['super', 'super', 'ghibran', 'bgm', 'vera', 'level'],
#  ['trailer', 'vera', 'level', 'padam', 'mass', 'aah', 'irukaa', 'pothu'],
#  ['thala', 'na', 'thala', 'thanthala', 'takkaru', 'doi'],
#  ['condipa',
#   'hit',
#   'moviethanu',
#   'solaravanga',
#   'ellarum',
#   'oru',
#   'like',
#   'podunga'],
#  ['oruthar',
#   'mele',
#   'neenga',
#   'viswasam',
#   'kaaturthukaga',
#   'innoruthare',
#   'en',
#   'asingam',
#   'paduthuringe'],
#  ['vera', 'lvl', 'get', 'up', 'semma', 'vikram', 'anna', 'super', 'trailer'],
#  ['marana', 'waiting', 'by', 'thalapathi', 'fan'],
#  ['dhanus', 'looks', 'remain', 'kamal', 'hassan', 'look', 'in', 'virumandi'],
#  ['thala',
#   'ajith',
#   'sirmass',
#   'konjam',
#   'kammiya',
#   'irukuravanga',
#   'like',
#   'pannunga'],
#  ['nallaa', 'thala', 'thala', 'nu', 'irukaru', 'ajith'],
#  ['vere', 'level', 'daa', 'trailerr', 'thala'],
#  ['naan',
#   'thala',
#   'yoda',
#   'thivira',
#   'rasigan',
#   'daa',
#   'naan',
#   'thirunelveli',
#   'karandaa'],
#  ['adichi', 'underwearla', 'oda', 'vittuduven', 'for', 'simon'],
#  ['like',
#   'rekka',
#   'namma',
#   'veetu',
#   'pillai',
#   'kuda',
#   'vidalam',
#   'mass',
#   'ah',
#   'irukum'],
#  ['i',
#   'am',
#   'captain',
#   'fans',
#   'but',
#   'paaa',
#   'sema',
#   'gethu',
#   'ah',
#   'iruku',
#   'ajith',
#   'sir'],
#  ['raijini', 'than', 'massmy', 'age', 'na', 'rajini', 'fqn'],
#  ['intha', 'week', 'kulla', 'k', 'likes', 'varanum'],
#  ['youtube',
#   'hang',
#   'aaych',
#   'views',
#   'kaatamaatingith',
#   'but',
#   'likes',
#   'increase',
#   'aaykitte',
#   'irukk'],
#  ['k', 'like', 'marana', 'mass', 'ah'],
#  ['vijai',
#   'sethubathykkaga',
#   'trailer',
#   'paakkuravanunga',
#   'poi',
#   'seethakathi',
#   'paarurajini',
#   'only',
#   'massmarana',
#   'mass'],
#  ['vj',
#   'nadaka',
#   'vda',
#   'matan',
#   'seenu',
#   'thala',
#   'nadaka',
#   'koodathu',
#   'gethu'],
#  ['you', 'bgm', 'is', 'ozm', 'sema', 'thalaivaa', 'love', 'you', 'you'],
#  ['yella',
#   'pasangalum',
#   'paakkavendiya',
#   'padam',
#   'thala',
#   'sonna',
#   'namba',
#   'pasanga',
#   'keapanga'],
#  ['dhsnush', 'vera', 'leval', 'ethana', 'mura', 'pathalum', 'salipu', 'illa'],
#  ['viswasatha', 'postponed', 'pannuganga', 'da'],
#  ['pakistani',
#   'movi',
#   'na',
#   'indian',
#   'movi',
#   'ka',
#   'record',
#   'tor',
#   'dia',
#   'salman',
#   'khan',
#   'b',
#   'hairan',
#   'open',
#   'link'],
#  ['thalaiva',
#   'trailer',
#   'times',
#   'parthuda',
#   'innumu',
#   'slikkal',
#   'pathutte',
#   'irukkanum',
#   'pola',
#   'irukku',
#   'i',
#   'love',
#   'rajini',
#   'sir'],
#  ['thalaivar',
#   'il',
#   'parthamathiri',
#   'irukkar',
#   'jan',
#   'epa',
#   'varumnu',
#   'irukku',
#   'thalaiva',
#   'we',
#   'are',
#   'all',
#   'wating'],
#  ['super', 'trailar', 'super', 'star', 'rajni', 'rasigan'],
#  ['ena',
#   'da',
#   'idhu',
#   'dunkirk',
#   'bgma',
#   'copy',
#   'adicha',
#   'mari',
#   'iruku',
#   'hanszimmer',
#   'paavam',
#   'summa',
#   'vidadu',
#   'da'],
#  ['last', 'dialogue', 'suit', 'for', 'all', 'fans'],
#  ['i', 'like', 'ayyayo', 'ithu', 'nala', 'eruka', 'dialog'],
#  ...]

# %%
test_bigram , _ = padded_everygram_pipeline(2, test)

# %%
test_bigram = list(test_bigram)

# %%
test_bigram = [list(x) for x in test_bigram]

# %%
test_bigram
# Out:
# [[('<s>',),
#   ('<s>', 'k'),
#   ('k',),
#   ('k', 'dislikes'),
#   ('dislikes',),
#   ('dislikes', 'ethuku'),
#   ('ethuku',),
#   ('ethuku', 'da'),
#   ('da',),
#   ('da', 'intha'),
#   ('intha',),
#   ('intha', 'trailerku'),
#   ('trailerku',),
#   ('trailerku', 'poi'),
#   ('poi',),
#   ('poi', 'apdi'),
#   ('apdi',),
#   ('apdi', 'ungalukku'),
#   ('ungalukku',),
#   ('ungalukku', 'entha'),
#   ('entha',),
#   ('entha', 'trailer'),
#   ('trailer',),
#   ('trailer', 'tha'),
#   ('tha',),
#   ('tha', 'pidikum'),
#   ('pidikum',),
#   ('pidikum', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'lyca'),
#   ('lyca',),
#   ('lyca', 'unna'),
#   ('unna',),
#   ('unna', 'nenacha'),
#   ('nenacha',),
#   ('nenacha', 'pavama'),
#   ('pavama',),
#   ('pavama', 'iruku'),
#   ('iruku',),
#   ('iruku', 'ya'),
#   ('ya',),
#   ('ya', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'it'),
#   ('it',),
#   ('it', 'looks'),
#   ('looks',),
#   ('looks', 'like'),
#   ('like',),
#   ('like', 'hindi'),
#   ('hindi',),
#   ('hindi', 'movie'),
#   ('movie',),
#   ('movie', 'amitab'),
#   ('amitab',),
#   ('amitab', 'bachan'),
#   ('bachan',),
#   ('bachan', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaivarukku'),
#   ('thalaivarukku',),
#   ('thalaivarukku', 'nejamavey'),
#   ('nejamavey',),
#   ('nejamavey', 'vayasaagiduchu'),
#   ('vayasaagiduchu',),
#   ('vayasaagiduchu', 'sivaji'),
#   ('sivaji',),
#   ('sivaji', 'than'),
#   ('than',),
#   ('than', 'thalaivaroda'),
#   ('thalaivaroda',),
#   ('thalaivaroda', 'peak'),
#   ('peak',),
#   ('peak', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'nu'),
#   ('nu',),
#   ('nu', 'sollu'),
#   ('sollu',),
#   ('sollu', 'thala'),
#   ('thala',),
#   ('thala', 'nemirinthu'),
#   ('nemirinthu',),
#   ('nemirinthu', 'nillu'),
#   ('nillu',),
#   ('nillu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'pink'),
#   ('pink',),
#   ('pink', 'original'),
#   ('original',),
#   ('original', 'version'),
#   ('version',),
#   ('version', 'pathavikaluku'),
#   ('pathavikaluku',),
#   ('pathavikaluku', 'this'),
#   ('this',),
#   ('this', 'trailer'),
#   ('trailer',),
#   ('trailer', 'old'),
#   ('old',),
#   ('old', 'maritha'),
#   ('maritha',),
#   ('maritha', 'irukum'),
#   ('irukum',),
#   ('irukum', 'pakathvigalukutha'),
#   ('pakathvigalukutha',),
#   ('pakathvigalukutha', 'all'),
#   ('all',),
#   ('all', 'scenes'),
#   ('scenes',),
#   ('scenes', 'um'),
#   ('um',),
#   ('um', 'new'),
#   ('new',),
#   ('new', 'ah'),
#   ('ah',),
#   ('ah', 'irukum'),
#   ('irukum',),
#   ('irukum', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vera'),
#   ('vera',),
#   ('vera', 'levellllllllllllll'),
#   ('levellllllllllllll',),
#   ('levellllllllllllll', 'all'),
#   ('all',),
#   ('all', 'the'),
#   ('the',),
#   ('the', 'best'),
#   ('best',),
#   ('best', 'shankar'),
#   ('shankar',),
#   ('shankar', 'sir'),
#   ('sir',),
#   ('sir', 'you'),
#   ('you',),
#   ('you', 'are'),
#   ('are',),
#   ('are', 'a'),
#   ('a',),
#   ('a', 'legend'),
#   ('legend',),
#   ('legend', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'h'),
#   ('h',),
#   ('h', 'raja'),
#   ('raja',),
#   ('raja', 'reference'),
#   ('reference',),
#   ('reference', 'kandupudichavangalam'),
#   ('kandupudichavangalam',),
#   ('kandupudichavangalam', 'like'),
#   ('like',),
#   ('like', 'pannunga'),
#   ('pannunga',),
#   ('pannunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'massssss'),
#   ('massssss',),
#   ('massssss', 'thalivaa'),
#   ('thalivaa',),
#   ('thalivaa', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'energy'),
#   ('energy',),
#   ('energy', 'petta'),
#   ('petta',),
#   ('petta', 'parak'),
#   ('parak',),
#   ('parak', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'nadakkadhu'),
#   ('nadakkadhu',),
#   ('nadakkadhu', 'nadakkakoodathu'),
#   ('nadakkakoodathu',),
#   ('nadakkakoodathu', 'nadakka'),
#   ('nadakka',),
#   ('nadakka', 'vidamattaen'),
#   ('vidamattaen',),
#   ('vidamattaen', 'who'),
#   ('who',),
#   ('who', 'expected'),
#   ('expected',),
#   ('expected', 'that'),
#   ('that',),
#   ('that', 'line'),
#   ('line',),
#   ('line', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'nerkonda'),
#   ('nerkonda',),
#   ('nerkonda', 'parvai'),
#   ('parvai',),
#   ('parvai', 'continue'),
#   ('continue',),
#   ('continue', 'days'),
#   ('days',),
#   ('days', 'in'),
#   ('in',),
#   ('in', 'all'),
#   ('all',),
#   ('all', 'teater'),
#   ('teater',),
#   ('teater', 'it'),
#   ('it',),
#   ('it', 'will'),
#   ('will',),
#   ('will', 'be'),
#   ('be',),
#   ('be', 'block'),
#   ('block',),
#   ('block', 'buster'),
#   ('buster',),
#   ('buster', 'movie'),
#   ('movie',),
#   ('movie', 'yeslike'),
#   ('yeslike',),
#   ('yeslike', 'nocomment'),
#   ('nocomment',),
#   ('nocomment', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'r'),
#   ('r',),
#   ('r', 'sijlee'),
#   ('sijlee',),
#   ('sijlee', 'energy'),
#   ('energy',),
#   ('energy', 'solutions'),
#   ('solutions',),
#   ('solutions', 'pvt'),
#   ('pvt',),
#   ('pvt', 'ltdr'),
#   ('ltdr',),
#   ('ltdr', 'sijleecomare'),
#   ('sijleecomare',),
#   ('sijleecomare', 'r'),
#   ('r',),
#   ('r', 'emi'),
#   ('emi',),
#   ('emi', 'availabler'),
#   ('availabler',),
#   ('availabler', 'chennai'),
#   ('chennai',),
#   ('chennai', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'hello'),
#   ('hello',),
#   ('hello', 'youtube'),
#   ('youtube',),
#   ('youtube', 'trent'),
#   ('trent',),
#   ('trent', 'on'),
#   ('on',),
#   ('on', 'button'),
#   ('button',),
#   ('button', 'your'),
#   ('your',),
#   ('your', 'software'),
#   ('software',),
#   ('software', 'death'),
#   ('death',),
#   ('death', 'ah'),
#   ('ah',),
#   ('ah', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'ultimate'),
#   ('ultimate',),
#   ('ultimate', 'star'),
#   ('star',),
#   ('star', 'ajith'),
#   ('ajith',),
#   ('ajith', 'kumar'),
#   ('kumar',),
#   ('kumar', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'unmaiya'),
#   ('unmaiya',),
#   ('unmaiya', 'thala'),
#   ('thala',),
#   ('thala', 'fana'),
#   ('fana',),
#   ('fana', 'irrutha'),
#   ('irrutha',),
#   ('irrutha', 'like'),
#   ('like',),
#   ('like', 'poduga'),
#   ('poduga',),
#   ('poduga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaiva'),
#   ('thalaiva',),
#   ('thalaiva', 'superstar'),
#   ('superstar',),
#   ('superstar', 'rajinikanth'),
#   ('rajinikanth',),
#   ('rajinikanth', 'number'),
#   ('number',),
#   ('number', 'one'),
#   ('one',),
#   ('one', 'mass'),
#   ('mass',),
#   ('mass', 'hero'),
#   ('hero',),
#   ('hero', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'makkal'),
#   ('makkal',),
#   ('makkal', 'selvan'),
#   ('selvan',),
#   ('selvan', 'fans'),
#   ('fans',),
#   ('fans', 'hit'),
#   ('hit',),
#   ('hit', 'like'),
#   ('like',),
#   ('like', 'here'),
#   ('here',),
#   ('here', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'super'),
#   ('super',),
#   ('super', 'star'),
#   ('star',),
#   ('star', 'marana'),
#   ('marana',),
#   ('marana', 'mass'),
#   ('mass',),
#   ('mass', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'am'),
#   ('am',),
#   ('am', 'sasikumar'),
#   ('sasikumar',),
#   ('sasikumar', 'big'),
#   ('big',),
#   ('big', 'fan'),
#   ('fan',),
#   ('fan', 'so'),
#   ('so',),
#   ('so', 'i'),
#   ('i',),
#   ('i', 'like'),
#   ('like',),
#   ('like', 'the'),
#   ('the',),
#   ('the', 'move'),
#   ('move',),
#   ('move', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'superstar'),
#   ('superstar',),
#   ('superstar', 'rajnikant'),
#   ('rajnikant',),
#   ('rajnikant', 'fans'),
#   ('fans',),
#   ('fans', 'hit'),
#   ('hit',),
#   ('hit', 'like'),
#   ('like',),
#   ('like', 'k'),
#   ('k',),
#   ('k', 'likes'),
#   ('likes',),
#   ('likes', 'petta'),
#   ('petta',),
#   ('petta', 'this'),
#   ('this',),
#   ('this', 'pongal'),
#   ('pongal',),
#   ('pongal', 'pakka'),
#   ('pakka',),
#   ('pakka', 'blockbuster'),
#   ('blockbuster',),
#   ('blockbuster', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'siruthai'),
#   ('siruthai',),
#   ('siruthai', 'siva'),
#   ('siva',),
#   ('siva', 'apdiye'),
#   ('apdiye',),
#   ('apdiye', 'director'),
#   ('director',),
#   ('director', 'odadha'),
#   ('odadha',),
#   ('odadha', 'vaangi'),
#   ('vaangi',),
#   ('vaangi', 'madakku'),
#   ('madakku',),
#   ('madakku', 'madakku'),
#   ('madakku',),
#   ('madakku', 'nu'),
#   ('nu',),
#   ('nu', 'kudi'),
#   ('kudi',),
#   ('kudi', 'unnaku'),
#   ('unnaku',),
#   ('unnaku', 'direction'),
#   ('direction',),
#   ('direction', 'varudhaanu'),
#   ('varudhaanu',),
#   ('varudhaanu', 'paapom'),
#   ('paapom',),
#   ('paapom', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', 'pesunaa'),
#   ('pesunaa',),
#   ('pesunaa', 'anilu'),
#   ('anilu',),
#   ('anilu', 'ammaiyan'),
#   ('ammaiyan',),
#   ('ammaiyan', 'vjmaaa'),
#   ('vjmaaa',),
#   ('vjmaaa', 'ku'),
#   ('ku',),
#   ('ku', 'tharama'),
#   ('tharama',),
#   ('tharama', 'sembavam'),
#   ('sembavam',),
#   ('sembavam', 'irrukku'),
#   ('irrukku',),
#   ('irrukku', 'daaaa'),
#   ('daaaa',),
#   ('daaaa', 'anilu'),
#   ('anilu',),
#   ('anilu', 'vick'),
#   ('vick',),
#   ('vick', 'sorry'),
#   ('sorry',),
#   ('sorry', 'kotte'),
#   ('kotte',),
#   ('kotte', 'pathy'),
#   ('pathy',),
#   ('pathy', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'yenapa'),
#   ('yenapa',),
#   ('yenapa', 'hollywood'),
#   ('hollywood',),
#   ('hollywood', 'movie'),
#   ('movie',),
#   ('movie', 'madiri'),
#   ('madiri',),
#   ('madiri', 'trailer'),
#   ('trailer',),
#   ('trailer', 'iruku'),
#   ('iruku',),
#   ('iruku', 'chiyan'),
#   ('chiyan',),
#   ('chiyan', 'rocks'),
#   ('rocks',),
#   ('rocks', 'kalakitaru'),
#   ('kalakitaru',),
#   ('kalakitaru', 'getup'),
#   ('getup',),
#   ('getup', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'bgm'),
#   ('bgm',),
#   ('bgm', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'going'),
#   ('going',),
#   ('going', 'hike'),
#   ('hike',),
#   ('hike', 'ghibran'),
#   ('ghibran',),
#   ('ghibran', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'eppadina'),
#   ('eppadina',),
#   ('eppadina', 'bigil'),
#   ('bigil',),
#   ('bigil', 'trailera'),
#   ('trailera',),
#   ('trailera', 'namma'),
#   ('namma',),
#   ('namma', 'views'),
#   ('views',),
#   ('views', 'reach'),
#   ('reach',),
#   ('reach', 'aga'),
#   ('aga',),
#   ('aga', 'koodadhu'),
#   ('koodadhu',),
#   ('koodadhu', 'adhe'),
#   ('adhe',),
#   ('adhe', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vaa'),
#   ('vaa',),
#   ('vaa', 'thaliva'),
#   ('thaliva',),
#   ('thaliva', 'vaa'),
#   ('vaa',),
#   ('vaa', 'thalaiva'),
#   ('thalaiva',),
#   ('thalaiva', 'marana'),
#   ('marana',),
#   ('marana', 'mass'),
#   ('mass',),
#   ('mass', 'thailaiva'),
#   ('thailaiva',),
#   ('thailaiva', 'fire'),
#   ('fire',),
#   ('fire', 'waiting'),
#   ('waiting',),
#   ('waiting', 'thailva'),
#   ('thailva',),
#   ('thailva', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'that'),
#   ('that',),
#   ('that', 'final'),
#   ('final',),
#   ('final', 'dialoge'),
#   ('dialoge',),
#   ('dialoge', 'oruthar'),
#   ('oruthar',),
#   ('oruthar', 'meala'),
#   ('meala',),
#   ('meala', 'visvasam'),
#   ('visvasam',),
#   ('visvasam', 'katurathukaga'),
#   ('katurathukaga',),
#   ('katurathukaga', 'ennorthara'),
#   ('ennorthara',),
#   ('ennorthara', 'yen'),
#   ('yen',),
#   ('yen', 'asinga'),
#   ('asinga',),
#   ('asinga', 'paduthuringa'),
#   ('paduthuringa',),
#   ('paduthuringa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'bro'),
#   ('bro',),
#   ('bro', 'ellaarum'),
#   ('ellaarum',),
#   ('ellaarum', 'm'),
#   ('m',),
#   ('m', 'likes'),
#   ('likes',),
#   ('likes', 'ethukunga'),
#   ('ethukunga',),
#   ('ethukunga', 'vidaathingai'),
#   ('vidaathingai',),
#   ('vidaathingai', 'would'),
#   ('would',),
#   ('would', 'create'),
#   ('create',),
#   ('create', 'pannungafast'),
#   ('pannungafast',),
#   ('pannungafast', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'madhiri'),
#   ('madhiri',),
#   ('madhiri', 'thuiya'),
#   ('thuiya',),
#   ('thuiya', 'tamil'),
#   ('tamil',),
#   ('tamil', 'pessi'),
#   ('pessi',),
#   ('pessi', 'nadikka'),
#   ('nadikka',),
#   ('nadikka', 'mudiuma'),
#   ('mudiuma',),
#   ('mudiuma', 'thala'),
#   ('thala',),
#   ('thala', 'tamilan'),
#   ('tamilan',),
#   ('tamilan', 'da'),
#   ('da',),
#   ('da', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'yaarellam'),
#   ('yaarellam',),
#   ('yaarellam', 'oct'),
#   ('oct',),
#   ('oct', 'ku'),
#   ('ku',),
#   ('ku', 'verithanama'),
#   ('verithanama',),
#   ('verithanama', 'wait'),
#   ('wait',),
#   ('wait', 'panreega'),
#   ('panreega',),
#   ('panreega', 'hit'),
#   ('hit',),
#   ('hit', 'like'),
#   ('like',),
#   ('like', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalapathy'),
#   ('thalapathy',),
#   ('thalapathy', 'fan'),
#   ('fan',),
#   ('fan', 'like'),
#   ('like',),
#   ('like', 'thala'),
#   ('thala',),
#   ('thala', 'ni'),
#   ('ni',),
#   ('ni', 'vaa'),
#   ('vaa',),
#   ('vaa', 'thala'),
#   ('thala',),
#   ('thala', 'nanga'),
#   ('nanga',),
#   ('nanga', 'erukkom'),
#   ('erukkom',),
#   ('erukkom', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'enna'),
#   ('enna',),
#   ('enna', 'da'),
#   ('da',),
#   ('da', 'trailer'),
#   ('trailer',),
#   ('trailer', 'kannapundai'),
#   ('kannapundai',),
#   ('kannapundai', 'madiri'),
#   ('madiri',),
#   ('madiri', 'iruku'),
#   ('iruku',),
#   ('iruku', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'enathaku'),
#   ('enathaku',),
#   ('enathaku', 'da'),
#   ('da',),
#   ('da', 'dislike'),
#   ('dislike',),
#   ('dislike', 'pannringa'),
#   ('pannringa',),
#   ('pannringa', 'edhoda'),
#   ('edhoda',),
#   ('edhoda', 'oru'),
#   ('oru',),
#   ('oru', 'gethu'),
#   ('gethu',),
#   ('gethu', 'trailer'),
#   ('trailer',),
#   ('trailer', 'irukka'),
#   ('irukka',),
#   ('irukka', 'vaipae'),
#   ('vaipae',),
#   ('vaipae', 'illa'),
#   ('illa',),
#   ('illa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'anil'),
#   ('anil',),
#   ('anil', 'kunjunga'),
#   ('kunjunga',),
#   ('kunjunga', 'romba'),
#   ('romba',),
#   ('romba', 'kadharranga'),
#   ('kadharranga',),
#   ('kadharranga', 'idharku'),
#   ('idharku',),
#   ('idharku', 'ore'),
#   ('ore',),
#   ('ore', 'theervu'),
#   ('theervu',),
#   ('theervu', 'arali'),
#   ('arali',),
#   ('arali', 'vedhaya'),
#   ('vedhaya',),
#   ('vedhaya', 'sappuradhu'),
#   ('sappuradhu',),
#   ('sappuradhu', 'dhan'),
#   ('dhan',),
#   ('dhan', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'agalathey'),
#   ('agalathey',),
#   ('agalathey', 'paatu'),
#   ('paatu',),
#   ('paatu', 'kku'),
#   ('kku',),
#   ('kku', 'aprum'),
#   ('aprum',),
#   ('aprum', 'vanthavanga'),
#   ('vanthavanga',),
#   ('vanthavanga', 'like'),
#   ('like',),
#   ('like', 'aa'),
#   ('aa',),
#   ('aa', 'pottu'),
#   ('pottu',),
#   ('pottu', 'viduunga'),
#   ('viduunga',),
#   ('viduunga', 'nu'),
#   ('nu',),
#   ('nu', 'comment'),
#   ('comment',),
#   ('comment', 'panna'),
#   ('panna',),
#   ('panna', 'vanthavanga'),
#   ('vanthavanga',),
#   ('vanthavanga', 'oru'),
#   ('oru',),
#   ('oru', 'like'),
#   ('like',),
#   ('like', 'a'),
#   ('a',),
#   ('a', 'podunga'),
#   ('podunga',),
#   ('podunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'trailers'),
#   ('trailers',),
#   ('trailers', 'semaaaaaaaa'),
#   ('semaaaaaaaa',),
#   ('semaaaaaaaa', 'i'),
#   ('i',),
#   ('i', 'am'),
#   ('am',),
#   ('am', 'waiting'),
#   ('waiting',),
#   ('waiting', 'release'),
#   ('release',),
#   ('release', 'big'),
#   ('big',),
#   ('big', 'screen'),
#   ('screen',),
#   ('screen', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'love'),
#   ('love',),
#   ('love', 'you'),
#   ('you',),
#   ('you', 'karthik'),
#   ('karthik',),
#   ('karthik', 'real'),
#   ('real',),
#   ('real', 'fan'),
#   ('fan',),
#   ('fan', 'made'),
#   ('made',),
#   ('made', 'film'),
#   ('film',),
#   ('film', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'in'),
#   ('in',),
#   ('in', 'ner'),
#   ('ner',),
#   ('ner', 'konda'),
#   ('konda',),
#   ('konda', 'paarvai'),
#   ('paarvai',),
#   ('paarvai', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'manitha'),
#   ('manitha',),
#   ('manitha', 'kadavul'),
#   ('kadavul',),
#   ('kadavul', 'ajith'),
#   ('ajith',),
#   ('ajith', 'kumar'),
#   ('kumar',),
#   ('kumar', 'kadhal'),
#   ('kadhal',),
#   ('kadhal', 'mannan'),
#   ('mannan',),
#   ('mannan', 'ajithkumar'),
#   ('ajithkumar',),
#   ('ajithkumar', 'ultimate'),
#   ('ultimate',),
#   ('ultimate', 'star'),
#   ('star',),
#   ('star', 'ajithkumar'),
#   ('ajithkumar',),
#   ('ajithkumar', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'daily'),
#   ('daily',),
#   ('daily', 'intha'),
#   ('intha',),
#   ('intha', 'trailer'),
#   ('trailer',),
#   ('trailer', 'ah'),
#   ('ah',),
#   ('ah', 'pakuravanga'),
#   ('pakuravanga',),
#   ('pakuravanga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'super'),
#   ('super',),
#   ('super', 'raa'),
#   ('raa',),
#   ('raa', 'ya'),
#   ('ya',),
#   ('ya', 'eriku'),
#   ('eriku',),
#   ('eriku', 'trailer'),
#   ('trailer',),
#   ('trailer', 'movie'),
#   ('movie',),
#   ('movie', 'uk'),
#   ('uk',),
#   ('uk', 'whiting'),
#   ('whiting',),
#   ('whiting', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'eanga'),
#   ('eanga',),
#   ('eanga', 'chiyan'),
#   ('chiyan',),
#   ('chiyan', 'vikaram'),
#   ('vikaram',),
#   ('vikaram', 'yappo'),
#   ('yappo',),
#   ('yappo', 'maa'),
#   ('maa',),
#   ('maa', 'mass'),
#   ('mass',),
#   ('mass', 'da'),
#   ('da',),
#   ('da', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'trailer'),
#   ('trailer',),
#   ('trailer', 'nalla'),
#   ('nalla',),
#   ('nalla', 'erukku'),
#   ('erukku',),
#   ('erukku', 'pengal'),
#   ('pengal',),
#   ('pengal', 'ku'),
#   ('ku',),
#   ('ku', 'nadakkura'),
#   ('nadakkura',),
#   ('nadakkura', 'kodumaiya'),
#   ('kodumaiya',),
#   ('kodumaiya', 'eduthu'),
#   ('eduthu',),
#   ('eduthu', 'solra'),
#   ('solra',),
#   ('solra', 'kadhai'),
#   ('kadhai',),
#   ('kadhai', 'sema'),
#   ('sema',),
#   ('sema', 'thalapathy'),
#   ('thalapathy',),
#   ('thalapathy', 'fan'),
#   ('fan',),
#   ('fan', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vijay'),
#   ('vijay',),
#   ('vijay', 'sethupathi'),
#   ('sethupathi',),
#   ('sethupathi', 'anna'),
#   ('anna',),
#   ('anna', 'bayangara'),
#   ('bayangara',),
#   ('bayangara', 'mass'),
#   ('mass',),
#   ('mass', 'said'),
#   ('said',),
#   ('said', 'irukaru'),
#   ('irukaru',),
#   ('irukaru', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'final'),
#   ('final',),
#   ('final', 'dialogue'),
#   ('dialogue',),
#   ('dialogue', 'and'),
#   ('and',),
#   ('and', 'previous'),
#   ('previous',),
#   ('previous', 'dialogue'),
#   ('dialogue',),
#   ('dialogue', 'mass'),
#   ('mass',),
#   ('mass', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'happy'),
#   ('happy',),
#   ('happy', 'diwali'),
#   ('diwali',),
#   ('diwali', 'guysss'),
#   ('guysss',),
#   ('guysss', 'if'),
#   ('if',),
#   ('if', 'vijay'),
#   ('vijay',),
#   ('vijay', 'fans'),
#   ('fans',),
#   ('fans', 'here'),
#   ('here',),
#   ('here', 'means'),
#   ('means',),
#   ('means', 'enjoy'),
#   ('enjoy',),
#   ('enjoy', 'you'),
#   ('you',),
#   ('you', 'are'),
#   ('are',),
#   ('are', 'sarkar'),
#   ('sarkar',),
#   ('sarkar', 'day'),
#   ('day',),
#   ('day', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'like'),
#   ('like',),
#   ('like', 'vennum'),
#   ('vennum',),
#   ('vennum', 'ennum'),
#   ('ennum',),
#   ('ennum', 'narayaaa'),
#   ('narayaaa',),
#   ('narayaaa', 'narayaaa'),
#   ('narayaaa',),
#   ('narayaaa', 'narayaaa'),
#   ('narayaaa',),
#   ('narayaaa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'valimai'),
#   ('valimai',),
#   ('valimai', 'aana'),
#   ('aana',),
#   ('aana', 'aamai'),
#   ('aamai',),
#   ('aamai', 'inathin'),
#   ('inathin',),
#   ('inathin', 'thailvan'),
#   ('thailvan',),
#   ('thailvan', 'ajith'),
#   ('ajith',),
#   ('ajith', 'kuthi'),
#   ('kuthi',),
#   ('kuthi', 'punda'),
#   ('punda',),
#   ('punda', 'mavan'),
#   ('mavan',),
#   ('mavan', 'valga'),
#   ('valga',),
#   ('valga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'sk'),
#   ('sk',),
#   ('sk', 'anna'),
#   ('anna',),
#   ('anna', 'nenga'),
#   ('nenga',),
#   ('nenga', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'aduthu'),
#   ('aduthu',),
#   ('aduthu', 'aduthu'),
#   ('aduthu',),
#   ('aduthu', 'munari'),
#   ('munari',),
#   ('munari', 'poitairukinge'),
#   ('poitairukinge',),
#   ('poitairukinge', 'anna'),
#   ('anna',),
#   ('anna', 'always'),
#   ('always',),
#   ('always', 'love'),
#   ('love',),
#   ('love', 'you'),
#   ('you',),
#   ('you', 'anna'),
#   ('anna',),
#   ('anna', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'hit'),
#   ('hit',),
#   ('hit', 'like'),
#   ('like',),
#   ('like', 'ithu'),
#   ('ithu',),
#   ('ithu', 'onnu'),
#   ('onnu',),
#   ('onnu', 'than'),
#   ('than',),
#   ('than', 'inga'),
#   ('inga',),
#   ('inga', 'comments'),
#   ('comments',),
#   ('comments', 'aa'),
#   ('aa',),
#   ('aa', 'irukku'),
#   ('irukku',),
#   ('irukku', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'hours'),
#   ('hours',),
#   ('hours', 'million'),
#   ('million',),
#   ('million', 'views'),
#   ('views',),
#   ('views', 'woww'),
#   ('woww',),
#   ('woww', 'thalaivaaaaipa'),
#   ('thalaivaaaaipa',),
#   ('thalaivaaaaipa', 'vaanga'),
#   ('vaanga',),
#   ('vaanga', 'da'),
#   ('da',),
#   ('da', 'china'),
#   ('china',),
#   ('china', 'pasangala'),
#   ('pasangala',),
#   ('pasangala', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'am'),
#   ('am',),
#   ('am', 'waiting'),
#   ('waiting',),
#   ('waiting', 'for'),
#   ('for',),
#   ('for', 'thala'),
#   ('thala',),
#   ('thala', 'in'),
#   ('in',),
#   ('in', 'nerkonda'),
#   ('nerkonda',),
#   ('nerkonda', 'parvai'),
#   ('parvai',),
#   ('parvai', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'rajini'),
#   ('rajini',),
#   ('rajini', 'kanth'),
#   ('kanth',),
#   ('kanth', 'sir'),
#   ('sir',),
#   ('sir', 'fans'),
#   ('fans',),
#   ('fans', 'like'),
#   ('like',),
#   ('like', 'here'),
#   ('here',),
#   ('here', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'guyzz'),
#   ('guyzz',),
#   ('guyzz', 'night'),
#   ('night',),
#   ('night', 'kulla'),
#   ('kulla',),
#   ('kulla', 'm'),
#   ('m',),
#   ('m', 'views'),
#   ('views',),
#   ('views', 'k'),
#   ('k',),
#   ('k', 'likes'),
#   ('likes',),
#   ('likes', 'podanumspeed'),
#   ('podanumspeed',),
#   ('podanumspeed', 'upp'),
#   ('upp',),
#   ('upp', 'dudes'),
#   ('dudes',),
#   ('dudes', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'hero'),
#   ('hero',),
#   ('hero', 'already'),
#   ('already',),
#   ('already', 'looks'),
#   ('looks',),
#   ('looks', 'like'),
#   ('like',),
#   ('like', 'a'),
#   ('a',),
#   ('a', 'zero'),
#   ('zero',),
#   ('zero', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'rmba'),
#   ('rmba',),
#   ('rmba', 'nerama'),
#   ('nerama',),
#   ('nerama', 'k'),
#   ('k',),
#   ('k', 'la'),
#   ('la',),
#   ('la', 'mattume'),
#   ('mattume',),
#   ('mattume', 'iruku'),
#   ('iruku',),
#   ('iruku', 'thala'),
#   ('thala',),
#   ('thala', 'mass'),
#   ('mass',),
#   ('mass', 'views'),
#   ('views',),
#   ('views', 'pakalanu'),
#   ('pakalanu',),
#   ('pakalanu', 'patha'),
#   ('patha',),
#   ('patha', 'ithu'),
#   ('ithu',),
#   ('ithu', 'vera'),
#   ('vera',),
#   ('vera', 'sathi'),
#   ('sathi',),
#   ('sathi', 'pannuthu'),
#   ('pannuthu',),
#   ('pannuthu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'mathavanga'),
#   ('mathavanga',),
#   ('mathavanga', 'mari'),
#   ('mari',),
#   ('mari', 'bandha'),
#   ('bandha',),
#   ('bandha', 'katti'),
#   ('katti',),
#   ('katti', 'nadikama'),
#   ('nadikama',),
#   ('nadikama', 'karthulla'),
#   ('karthulla',),
#   ('karthulla', 'padam'),
#   ('padam',),
#   ('padam', 'choose'),
#   ('choose',),
#   ('choose', 'panni'),
#   ('panni',),
#   ('panni', 'nadikirau'),
#   ('nadikirau',),
#   ('nadikirau', 'love'),
#   ('love',),
#   ('love', 'you'),
#   ('you',),
#   ('you', 'thala'),
#   ('thala',),
#   ('thala', 'hats'),
#   ('hats',),
#   ('hats', 'off'),
#   ('off',),
#   ('off', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'trending'),
#   ('trending',),
#   ('trending', 'no'),
#   ('no',),
#   ('no', 'in'),
#   ('in',),
#   ('in', 'singapore'),
#   ('singapore',),
#   ('singapore', 'steady'),
#   ('steady',),
#   ('steady', 'la'),
#   ('la',),
#   ('la', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'fathers'),
#   ('fathers',),
#   ('fathers', 'day'),
#   ('day',),
#   ('day', 'special'),
#   ('special',),
#   ('special', 'paarungu'),
#   ('paarungu',),
#   ('paarungu', 'awareness'),
#   ('awareness',),
#   ('awareness', 'share'),
#   ('share',),
#   ('share', 'pannungu'),
#   ('pannungu',),
#   ('pannungu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'indheee'),
#   ('indheee',),
#   ('indheee', 'oru'),
#   ('oru',),
#   ('oru', 'padam'),
#   ('padam',),
#   ('padam', 'poodhum'),
#   ('poodhum',),
#   ('poodhum', 'thalaivaaaa'),
#   ('thalaivaaaa',),
#   ('thalaivaaaa', 'naaan'),
#   ('naaan',),
#   ('naaan', 'ungaleee'),
#   ('ungaleee',),
#   ('ungaleee', 'marupadiyum'),
#   ('marupadiyum',),
#   ('marupadiyum', 'parthutheeee'),
#   ('parthutheeee',),
#   ('parthutheeee', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'why'),
#   ('why',),
#   ('why', 'k'),
#   ('k',),
#   ('k', 'dislikewhat'),
#   ('dislikewhat',),
#   ('dislikewhat', 'they'),
#   ('they',),
#   ('they', 'understandplese'),
#   ('understandplese',),
#   ('understandplese', 'tell'),
#   ('tell',),
#   ('tell', 'me'),
#   ('me',),
#   ('me', 'dislike'),
#   ('dislike',),
#   ('dislike', 'persons'),
#   ('persons',),
#   ('persons', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'waiting'),
#   ('waiting',),
#   ('waiting', 'for'),
#   ('for',),
#   ('for', 'kaappaan'),
#   ('kaappaan',),
#   ('kaappaan', 'suriya'),
#   ('suriya',),
#   ('suriya', 'fans'),
#   ('fans',),
#   ('fans', 'like'),
#   ('like',),
#   ('like', 'here'),
#   ('here',),
#   ('here', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaivar'),
#   ('thalaivar',),
#   ('thalaivar', 'than'),
#   ('than',),
#   ('than', 'super'),
#   ('super',),
#   ('super', 'star'),
#   ('star',),
#   ('star', 'vera'),
#   ('vera',),
#   ('vera', 'evarum'),
#   ('evarum',),
#   ('evarum', 'kidaiyathu'),
#   ('kidaiyathu',),
#   ('kidaiyathu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'asuren'),
#   ('asuren',),
#   ('asuren', 'vettai'),
#   ('vettai',),
#   ('vettai', 'arambam'),
#   ('arambam',),
#   ('arambam', 'am'),
#   ('am',),
#   ('am', 'dhanush'),
#   ('dhanush',),
#   ('dhanush', 'anna'),
#   ('anna',),
#   ('anna', 'veriyan'),
#   ('veriyan',),
#   ('veriyan', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'no'),
#   ('no',),
#   ('no', 'one'),
#   ('one',),
#   ('one', 'two'),
#   ('two',),
#   ('two', 'la'),
#   ('la',),
#   ('la', 'papanga'),
#   ('papanga',),
#   ('papanga', 'vilayattu'),
#   ('vilayattu',),
#   ('vilayattu', 'super'),
#   ('super',),
#   ('super', 'star'),
#   ('star',),
#   ('star', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'trailer'),
#   ('trailer',),
#   ('trailer', 'pathi'),
#   ('pathi',),
#   ('pathi', 'edhana'),
#   ('edhana',),
#   ('edhana', 'sollunga'),
#   ('sollunga',),
#   ('sollunga', 'ya'),
#   ('ya',),
#   ('ya', 'na'),
#   ('na',),
#   ('na', 'poll'),
#   ('poll',),
#   ('poll', 'vachi'),
#   ('vachi',),
#   ('vachi', 'nadathuranunga'),
#   ('nadathuranunga',),
#   ('nadathuranunga', 'indha'),
#   ('indha',),
#   ('indha', 'fan'),
#   ('fan',),
#   ('fan', 'boys'),
#   ('boys',),
#   ('boys', 'like'),
#   ('like',),
#   ('like', 'hu'),
#   ('hu',),
#   ('hu', 'comment'),
#   ('comment',),
#   ('comment', 'haam'),
#   ('haam',),
#   ('haam', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'will'),
#   ('will',),
#   ('will', 'it'),
#   ('it',),
#   ('it', 'get'),
#   ('get',),
#   ('get', 'million'),
#   ('million',),
#   ('million', 'likes'),
#   ('likes',),
#   ('likes', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'ithu'),
#   ('ithu',),
#   ('ithu', 'tamil'),
#   ('tamil',),
#   ('tamil', 'nadu'),
#   ('nadu',),
#   ('nadu', 'ella'),
#   ('ella',),
#   ('ella', 'ithu'),
#   ('ithu',),
#   ('ithu', 'enga'),
#   ('enga',),
#   ('enga', 'thala'),
#   ('thala',),
#   ('thala', 'nadu'),
#   ('nadu',),
#   ('nadu', 'daa'),
#   ('daa',),
#   ('daa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'epd'),
#   ('epd',),
#   ('epd', 'unga'),
#   ('unga',),
#   ('unga', 'combovetridhanush'),
#   ('combovetridhanush',),
#   ('combovetridhanush', 'nala'),
#   ('nala',),
#   ('nala', 'matum'),
#   ('matum',),
#   ('matum', 'ipd'),
#   ('ipd',),
#   ('ipd', 'realistica'),
#   ('realistica',),
#   ('realistica', 'kondu'),
#   ('kondu',),
#   ('kondu', 'vara'),
#   ('vara',),
#   ('vara', 'mudyuthu'),
#   ('mudyuthu',),
#   ('mudyuthu', 'semmmma'),
#   ('semmmma',),
#   ('semmmma', 'pa'),
#   ('pa',),
#   ('pa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'wowww'),
#   ('wowww',),
#   ('wowww', 'amaizing'),
#   ('amaizing',),
#   ('amaizing', 'bgm'),
#   ('bgm',),
#   ('bgm', 'nammakita'),
#   ('nammakita',),
#   ('nammakita', 'kaaadu'),
#   ('kaaadu',),
#   ('kaaadu', 'iruntha'),
#   ('iruntha',),
#   ('iruntha', 'eduthupanga'),
#   ('eduthupanga',),
#   ('eduthupanga', 'kasu'),
#   ('kasu',),
#   ('kasu', 'iruntha'),
#   ('iruntha',),
#   ('iruntha', 'pudingikuruvanga'),
#   ('pudingikuruvanga',),
#   ('pudingikuruvanga', 'padipa'),
#   ('padipa',),
#   ('padipa', 'mattum'),
#   ('mattum',),
#   ('mattum', 'eduthukave'),
#   ('eduthukave',),
#   ('eduthukave', 'mudiyathu'),
#   ('mudiyathu',),
#   ('mudiyathu', 'chithambaram'),
#   ('chithambaram',),
#   ('chithambaram', 'superb'),
#   ('superb',),
#   ('superb', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'adichu'),
#   ('adichu',),
#   ('adichu', 'underwear'),
#   ('underwear',),
#   ('underwear', 'oda'),
#   ('oda',),
#   ('oda', 'voda'),
#   ('voda',),
#   ('voda', 'vitturuven'),
#   ('vitturuven',),
#   ('vitturuven', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'pakathana'),
#   ('pakathana',),
#   ('pakathana', 'pora'),
#   ('pora',),
#   ('pora', 'pongalugu'),
#   ('pongalugu',),
#   ('pongalugu', 'inntha'),
#   ('inntha',),
#   ('inntha', 'kalliyoda'),
#   ('kalliyoda',),
#   ('kalliyoda', 'attatha'),
#   ('attatha',),
#   ('attatha', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'indha'),
#   ('indha',),
#   ('indha', 'diwali'),
#   ('diwali',),
#   ('diwali', 'kaidhi'),
#   ('kaidhi',),
#   ('kaidhi', 'ku'),
#   ('ku',),
#   ('ku', 'bigil'),
#   ('bigil',),
#   ('bigil', 'visil'),
#   ('visil',),
#   ('visil', 'podu'),
#   ('podu',),
#   ('podu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'adutha'),
#   ('adutha',),
#   ('adutha', 'vaaram'),
#   ('vaaram',),
#   ('vaaram', 'thaan'),
#   ('thaan',),
#   ('thaan', 'indha'),
#   ('indha',),
#   ('indha', 'maanam'),
#   ('maanam',),
#   ('maanam', 'ketta'),
#   ('ketta',),
#   ('ketta', 'padathuku'),
#   ('padathuku',),
#   ('padathuku', 'm'),
#   ('m',),
#   ('m', 'views'),
#   ('views',),
#   ('views', 'varumnu'),
#   ('varumnu',),
#   ('varumnu', 'nenaikiravanga'),
#   ('nenaikiravanga',),
#   ('nenaikiravanga', 'like'),
#   ('like',),
#   ('like', 'podunga'),
#   ('podunga',),
#   ('podunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'ithu'),
#   ('ithu',),
#   ('ithu', 'vae'),
#   ('vae',),
#   ('vae', 'ippadi'),
#   ('ippadi',),
#   ('ippadi', 'naapa'),
#   ('naapa',),
#   ('naapa', 'thalapathy'),
#   ('thalapathy',),
#   ('thalapathy', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'koja'),
#   ('koja',),
#   ('koja', 'different'),
#   ('different',),
#   ('different', 'aana'),
#   ('aana',),
#   ('aana', 'movie'),
#   ('movie',),
#   ('movie', 'interesting'),
#   ('interesting',),
#   ('interesting', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'oruthar'),
#   ('oruthar',),
#   ('oruthar', 'meala'),
#   ('meala',),
#   ('meala', 'viswasam'),
#   ('viswasam',),
#   ('viswasam', 'katura'),
#   ('katura',),
#   ('katura', 'naala'),
#   ('naala',),
#   ('naala', 'inu'),
#   ('inu',),
#   ('inu', 'oruthara'),
#   ('oruthara',),
#   ('oruthara', 'yen'),
#   ('yen',),
#   ('yen', 'asinga'),
#   ('asinga',),
#   ('asinga', 'paduthuringa'),
#   ('paduthuringa',),
#   ('paduthuringa', 'thala'),
#   ('thala',),
#   ('thala', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'kola'),
#   ('kola',),
#   ('kola', 'verithanam'),
#   ('verithanam',),
#   ('verithanam', 'trailer'),
#   ('trailer',),
#   ('trailer', 'award'),
#   ('award',),
#   ('award', 'kandipa'),
#   ('kandipa',),
#   ('kandipa', 'kedaikkun'),
#   ('kedaikkun',),
#   ('kedaikkun', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'rajini'),
#   ('rajini',),
#   ('rajini', 'sankar'),
#   ('sankar',),
#   ('sankar', 'ar'),
#   ('ar',),
#   ('ar', 'rahman'),
#   ('rahman',),
#   ('rahman', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'intha'),
#   ('intha',),
#   ('intha', 'combo'),
#   ('combo',),
#   ('combo', 'kkaaga'),
#   ('kkaaga',),
#   ('kkaaga', 'tharalaama'),
#   ('tharalaama',),
#   ('tharalaama', 'paakalam'),
#   ('paakalam',),
#   ('paakalam', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'kola'),
#   ('kola',),
#   ('kola', 'gaandula'),
#   ('gaandula',),
#   ('gaandula', 'iruken'),
#   ('iruken',),
#   ('iruken', 'mavane'),
#   ('mavane',),
#   ('mavane', 'kollama'),
#   ('kollama',),
#   ('kollama', 'vidamaten'),
#   ('vidamaten',),
#   ('vidamaten', 'antha'),
#   ('antha',),
#   ('antha', 'k'),
#   ('k',),
#   ('k', 'dislike'),
#   ('dislike',),
#   ('dislike', 'panninavangala'),
#   ('panninavangala',),
#   ('panninavangala', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'wtf'),
#   ('wtf',),
#   ('wtf', 'manu'),
#   ('manu',),
#   ('manu', 'is'),
#   ('is',),
#   ('is', 'doing'),
#   ('doing',),
#   ('doing', 'in'),
#   ('in',),
#   ('in', 'between'),
#   ('between',),
#   ('between', 'gandhi'),
#   ('gandhi',),
#   ('gandhi', 'and'),
#   ('and',),
#   ('and', 'ambedkar'),
#   ('ambedkar',),
#   ('ambedkar', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'kaasu'),
#   ('kaasu',),
#   ('kaasu', 'kodhuthu'),
#   ('kodhuthu',),
#   ('kodhuthu', 'vikku'),
#   ('vikku',),
#   ('vikku', 'mudiya'),
#   ('mudiya',),
#   ('mudiya', 'vangalam'),
#   ('vangalam',),
#   ('vangalam', 'ana'),
#   ('ana',),
#   ('ana', 'kaasu'),
#   ('kaasu',),
#   ('kaasu', 'kodhuthu'),
#   ('kodhuthu',),
#   ('kodhuthu', 'tholapathy'),
#   ('tholapathy',),
#   ('tholapathy', 'enra'),
#   ('enra',),
#   ('enra', 'title'),
#   ('title',),
#   ('title', 'vangalaama'),
#   ('vangalaama',),
#   ('vangalaama', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'viswasathuku'),
#   ('viswasathuku',),
#   ('viswasathuku', 'sirappana'),
#   ('sirappana',),
#   ('sirappana', 'tharamana'),
#   ('tharamana',),
#   ('tharamana', 'sambavangalai'),
#   ('sambavangalai',),
#   ('sambavangalai', 'ini'),
#   ('ini',),
#   ('ini', 'thaan'),
#   ('thaan',),
#   ('thaan', 'paarka'),
#   ('paarka',),
#   ('paarka', 'poreenga'),
#   ('poreenga',),
#   ('poreenga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'indha'),
#   ('indha',),
#   ('indha', 'padam'),
#   ('padam',),
#   ('padam', 'kandippa'),
#   ('kandippa',),
#   ('kandippa', 'mokkaya'),
#   ('mokkaya',),
#   ('mokkaya', 'irukum'),
#   ('irukum',),
#   ('irukum', 'nu'),
#   ('nu',),
#   ('nu', 'nenaikaravanga'),
#   ('nenaikaravanga',),
#   ('nenaikaravanga', 'like'),
#   ('like',),
#   ('like', 'podunga'),
#   ('podunga',),
#   ('podunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'this'),
#   ('this',),
#   ('this', 'time'),
#   ('time',),
#   ('time', 'thalaivar'),
#   ('thalaivar',),
#   ('thalaivar', 'trailer'),
#   ('trailer',),
#   ('trailer', 'ah'),
#   ('ah',),
#   ('ah', 'ku'),
#   ('ku',),
#   ('ku', 'mela'),
#   ('mela',),
#   ('mela', 'parthavanga'),
#   ('parthavanga',),
#   ('parthavanga', 'like'),
#   ('like',),
#   ('like', 'pannunga'),
#   ('pannunga',),
#   ('pannunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'min'),
#   ('min',),
#   ('min', 'a'),
#   ('a',),
#   ('a', 'k'),
#   ('k',),
#   ('k', 'views'),
#   ('views',),
#   ('views', 'omg'),
#   ('omg',),
#   ('omg', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaivaaaa'),
#   ('thalaivaaaa',),
#   ('thalaivaaaa', 'you'),
#   ('you',),
#   ('you', 'are'),
#   ('are',),
#   ('are', 'one'),
#   ('one',),
#   ('one', 'and'),
#   ('and',),
#   ('and', 'only'),
#   ('only',),
#   ('only', 'super'),
#   ('super',),
#   ('super', 'star'),
#   ('star',),
#   ('star', 'pettaaaaa'),
#   ('pettaaaaa',),
#   ('pettaaaaa', 'marana'),
#   ('marana',),
#   ('marana', 'maaaaasss'),
#   ('maaaaasss',),
#   ('maaaaasss', 'i'),
#   ('i',),
#   ('i', 'will'),
#   ('will',),
#   ('will', 'be'),
#   ('be',),
#   ('be', 'in'),
#   ('in',),
#   ('in', 'fdfs'),
#   ('fdfs',),
#   ('fdfs', 'at'),
#   ('at',),
#   ('at', 'trichy'),
#   ('trichy',),
#   ('trichy', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vikram'),
#   ('vikram',),
#   ('vikram', 'look'),
#   ('look',),
#   ('look', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'making'),
#   ('making',),
#   ('making', 'la'),
#   ('la',),
#   ('la', 'pakumbotheya'),
#   ('pakumbotheya',),
#   ('pakumbotheya', 'veriya'),
#   ('veriya',),
#   ('veriya', 'irruku'),
#   ('irruku',),
#   ('irruku', 'kasa'),
#   ('kasa',),
#   ('kasa', 'thaniya'),
#   ('thaniya',),
#   ('thaniya', 'vari'),
#   ('vari',),
#   ('vari', 'erachi'),
#   ('erachi',),
#   ('erachi', 'irrukanga'),
#   ('irrukanga',),
#   ('irrukanga', 'polatrailer'),
#   ('polatrailer',),
#   ('polatrailer', 'semma'),
#   ('semma',),
#   ('semma', 'mass'),
#   ('mass',),
#   ('mass', 'dha'),
#   ('dha',),
#   ('dha', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'therikka'),
#   ('therikka',),
#   ('therikka', 'vda'),
#   ('vda',),
#   ('vda', 'vantaanga'),
#   ('vantaanga',),
#   ('vantaanga', 'thalaivar'),
#   ('thalaivar',),
#   ('thalaivar', 'and'),
#   ('and',),
#   ('and', 'team'),
#   ('team',),
#   ('team', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'ajith'),
#   ('ajith',),
#   ('ajith', 'kumar'),
#   ('kumar',),
#   ('kumar', 'yuvan'),
#   ('yuvan',),
#   ('yuvan', 'shankar'),
#   ('shankar',),
#   ('shankar', 'raja'),
#   ('raja',),
#   ('raja', 'h'),
#   ('h',),
#   ('h', 'vinond'),
#   ('vinond',),
#   ('vinond', 'uff'),
#   ('uff',),
#   ('uff', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'chiyan'),
#   ('chiyan',),
#   ('chiyan', 'fans'),
#   ('fans',),
#   ('fans', 'lam'),
#   ('lam',),
#   ('lam', 'like'),
#   ('like',),
#   ('like', 'button'),
#   ('button',),
#   ('button', 'ah'),
#   ('ah',),
#   ('ah', 'adichi'),
#   ('adichi',),
#   ('adichi', 'thookunga'),
#   ('thookunga',),
#   ('thookunga', 'paaklaamm'),
#   ('paaklaamm',),
#   ('paaklaamm', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'bgm'),
#   ('bgm',),
#   ('bgm', 'nice'),
#   ('nice',),
#   ('nice', 'but'),
#   ('but',),
#   ('but', 'onum'),
#   ('onum',),
#   ('onum', 'solra'),
#   ('solra',),
#   ('solra', 'maari'),
#   ('maari',),
#   ('maari', 'illa'),
#   ('illa',),
#   ('illa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'dr'),
#   ('dr',),
#   ('dr', 'br'),
#   ('br',),
#   ('br', 'ambedkar'),
#   ('ambedkar',),
#   ('ambedkar', 'dialogue'),
#   ('dialogue',),
#   ('dialogue', 'jai'),
#   ('jai',),
#   ('jai', 'bheem'),
#   ('bheem',),
#   ('bheem', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'kgf'),
#   ('kgf',),
#   ('kgf', 'chapter'),
#   ('chapter',),
#   ('chapter', 'like'),
#   ('like',),
#   ('like', 'kaithi'),
#   ('kaithi',),
#   ('kaithi', 'like'),
#   ('like',),
#   ('like', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'on'),
#   ('on',),
#   ('on', 'trending'),
#   ('trending',),
#   ('trending', 'omg'),
#   ('omg',),
#   ('omg', 'woww'),
#   ('woww',),
#   ('woww', 'love'),
#   ('love',),
#   ('love', 'rajinikanth'),
#   ('rajinikanth',),
#   ('rajinikanth', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'nangalum'),
#   ('nangalum',),
#   ('nangalum', 'kola'),
#   ('kola',),
#   ('kola', 'kanda'),
#   ('kanda',),
#   ('kanda', 'la'),
#   ('la',),
#   ('la', 'than'),
#   ('than',),
#   ('than', 'irukom'),
#   ('irukom',),
#   ('irukom', 'oda'),
#   ('oda',),
#   ('oda', 'vidroma'),
#   ('vidroma',),
#   ('vidroma', 'illayanu'),
#   ('illayanu',),
#   ('illayanu', 'parru'),
#   ('parru',),
#   ('parru', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'g'),
#   ('g',),
#   ('g', 'v'),
#   ('v',),
#   ('v', 'p'),
#   ('p',),
#   ('p', 'kumar'),
#   ('kumar',),
#   ('kumar', 'music'),
#   ('music',),
#   ('music', 'vera'),
#   ('vera',),
#   ('vera', 'leval'),
#   ('leval',),
#   ('leval', 'bgm'),
#   ('bgm',),
#   ('bgm', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'chiyan'),
#   ('chiyan',),
#   ('chiyan', 'ninga'),
#   ('ninga',),
#   ('ninga', 'fast'),
#   ('fast',),
#   ('fast', 'furiors'),
#   ('furiors',),
#   ('furiors', 'laye'),
#   ('laye',),
#   ('laye', 'nadikalam'),
#   ('nadikalam',),
#   ('nadikalam', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'million'),
#   ('million',),
#   ('million', 'innum'),
#   ('innum',),
#   ('innum', 'days'),
#   ('days',),
#   ('days', 'kulla'),
#   ('kulla',),
#   ('kulla', 'varanum'),
#   ('varanum',),
#   ('varanum', 'friends'),
#   ('friends',),
#   ('friends', 'keep'),
#   ('keep',),
#   ('keep', 'watching'),
#   ('watching',),
#   ('watching', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'mirattal'),
#   ('mirattal',),
#   ('mirattal', 'ah'),
#   ('ah',),
#   ('ah', 'irukku'),
#   ('irukku',),
#   ('irukku', 'boss'),
#   ('boss',),
#   ('boss', 'siva'),
#   ('siva',),
#   ('siva', 'anne'),
#   ('anne',),
#   ('anne', 'sema'),
#   ('sema',),
#   ('sema', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'dai'),
#   ('dai',),
#   ('dai', 'kodi'),
#   ('kodi',),
#   ('kodi', 'thevaiya'),
#   ('thevaiya',),
#   ('thevaiya', 'intha'),
#   ('intha',),
#   ('intha', 'movieku'),
#   ('movieku',),
#   ('movieku', 'varumaiyil'),
#   ('varumaiyil',),
#   ('varumaiyil', 'vazum'),
#   ('vazum',),
#   ('vazum', 'eazakku'),
#   ('eazakku',),
#   ('eazakku', 'seru'),
#   ('seru',),
#   ('seru', 'pottala'),
#   ('pottala',),
#   ('pottala', 'natu'),
#   ('natu',),
#   ('natu', 'munnerum'),
#   ('munnerum',),
#   ('munnerum', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'dai'),
#   ('dai',),
#   ('dai', 'pandey'),
#   ('pandey',),
#   ('pandey', 'thala'),
#   ('thala',),
#   ('thala', 'ya'),
#   ('ya',),
#   ('ya', 'vey'),
#   ('vey',),
#   ('vey', 'yethirthu'),
#   ('yethirthu',),
#   ('yethirthu', 'pesuriya'),
#   ('pesuriya',),
#   ('pesuriya', 'goyala'),
#   ('goyala',),
#   ('goyala', 'theater'),
#   ('theater',),
#   ('theater', 'pakkam'),
#   ('pakkam',),
#   ('pakkam', 'varuvala'),
#   ('varuvala',),
#   ('varuvala', 'va'),
#   ('va',),
#   ('va', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vjs'),
#   ('vjs',),
#   ('vjs', 'anna'),
#   ('anna',),
#   ('anna', 'voice'),
#   ('voice',),
#   ('voice', 'ke'),
#   ('ke',),
#   ('ke', 'naanelam'),
#   ('naanelam',),
#   ('naanelam', 'adimainu'),
#   ('adimainu',),
#   ('adimainu', 'solravanga'),
#   ('solravanga',),
#   ('solravanga', 'oru'),
#   ('oru',),
#   ('oru', 'like'),
#   ('like',),
#   ('like', 'podunga'),
#   ('podunga',),
#   ('podunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'ethana'),
#   ('ethana',),
#   ('ethana', 'padam'),
#   ('padam',),
#   ('padam', 'vanthanu'),
#   ('vanthanu',),
#   ('vanthanu', 'salt'),
#   ('salt',),
#   ('salt', 'and'),
#   ('and',),
#   ('and', 'pepper'),
#   ('pepper',),
#   ('pepper', 'mattum'),
#   ('mattum',),
#   ('mattum', 'thanth'),
#   ('thanth',),
#   ('thanth', 'l'),
#   ('l',),
#   ('l', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'namakku'),
#   ('namakku',),
#   ('namakku', 'thevayandhu'),
#   ('thevayandhu',),
#   ('thevayandhu', 'namaa'),
#   ('namaa',),
#   ('namaa', 'dha'),
#   ('dha',),
#   ('dha', 'adichu'),
#   ('adichu',),
#   ('adichu', 'vanganum'),
#   ('vanganum',),
#   ('vanganum', 'semma'),
#   ('semma',),
#   ('semma', 'punch'),
#   ('punch',),
#   ('punch', 'd'),
#   ('d',),
#   ('d', 'killing'),
#   ('killing',),
#   ('killing', 'trailor'),
#   ('trailor',),
#   ('trailor', 'dudes'),
#   ('dudes',),
#   ('dudes', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'diehard'),
#   ('diehard',),
#   ('diehard', 'fan'),
#   ('fan',),
#   ('fan', 'of'),
#   ('of',),
#   ('of', 'chiyaan'),
#   ('chiyaan',),
#   ('chiyaan', 'vikram'),
#   ('vikram',),
#   ('vikram', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'trailera'),
#   ('trailera',),
#   ('trailera', 'fulla'),
#   ('fulla',),
#   ('fulla', 'paakave'),
#   ('paakave',),
#   ('paakave', 'porumai'),
#   ('porumai',),
#   ('porumai', 'illaye'),
#   ('illaye',),
#   ('illaye', 'padam'),
#   ('padam',),
#   ('padam', 'epdi'),
#   ('epdi',),
#   ('epdi', 'irkumo'),
#   ('irkumo',),
#   ('irkumo', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'nerkonda'),
#   ('nerkonda',),
#   ('nerkonda', 'parvai'),
#   ('parvai',),
#   ('parvai', 'blue'),
#   ('blue',),
#   ('blue', 'sattai'),
#   ('sattai',),
#   ('sattai', 'maran'),
#   ('maran',),
#   ('maran', 'review'),
#   ('review',),
#   ('review', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'next'),
#   ('next',),
#   ('next', 'bigil'),
#   ('bigil',),
#   ('bigil', 'movie'),
#   ('movie',),
#   ('movie', 'ku'),
#   ('ku',),
#   ('ku', 'waiting'),
#   ('waiting',),
#   ('waiting', 'pantravanga'),
#   ('pantravanga',),
#   ('pantravanga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'trailer'),
#   ('trailer',),
#   ('trailer', 'bangam'),
#   ('bangam',),
#   ('bangam', 'talented'),
#   ('talented',),
#   ('talented', 'film'),
#   ('film',),
#   ('film', 'maker'),
#   ('maker',),
#   ('maker', 'lokesh'),
#   ('lokesh',),
#   ('lokesh', 'ganagaraj'),
#   ('ganagaraj',),
#   ('ganagaraj', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'theatre'),
#   ('theatre',),
#   ('theatre', 'padam'),
#   ('padam',),
#   ('padam', 'pakkanum'),
#   ('pakkanum',),
#   ('pakkanum', 'solli'),
#   ('solli',),
#   ('solli', 'veriyilla'),
#   ('veriyilla',),
#   ('veriyilla', 'erikkenevanavadu'),
#   ('erikkenevanavadu',),
#   ('erikkenevanavadu', 'piracy'),
#   ('piracy',),
#   ('piracy', 'solli'),
#   ('solli',),
#   ('solli', 'net'),
#   ('net',),
#   ('net', 'la'),
#   ('la',),
#   ('la', 'padaththa'),
#   ('padaththa',),
#   ('padaththa', 'vittathalavaroda'),
#   ('vittathalavaroda',),
#   ('vittathalavaroda', 'kolaveriyan'),
#   ('kolaveriyan',),
#   ('kolaveriyan', 'mavane'),
#   ('mavane',),
#   ('mavane', 'koluththama'),
#   ('koluththama',),
#   ('koluththama', 'vidamatten'),
#   ('vidamatten',),
#   ('vidamatten', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'malayalam'),
#   ('malayalam',),
#   ('malayalam', 'movie'),
#   ('movie',),
#   ('movie', 'chindhamani'),
#   ('chindhamani',),
#   ('chindhamani', 'kolakes'),
#   ('kolakes',),
#   ('kolakes', 'copy'),
#   ('copy',),
#   ('copy', 'ajit'),
#   ('ajit',),
#   ('ajit', 'vest'),
#   ('vest',),
#   ('vest', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'padama'),
#   ('padama',),
#   ('padama', 'ithu'),
#   ('ithu',),
#   ('ithu', 'koothi'),
#   ('koothi',),
#   ('koothi', 'maari'),
#   ('maari',),
#   ('maari', 'iruku'),
#   ('iruku',),
#   ('iruku', 'trailer'),
#   ('trailer',),
#   ('trailer', 'padam'),
#   ('padam',),
#   ('padam', 'punda'),
#   ('punda',),
#   ('punda', 'mathiri'),
#   ('mathiri',),
#   ('mathiri', 'irukum'),
#   ('irukum',),
#   ('irukum', 'pola'),
#   ('pola',),
#   ('pola', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'back'),
#   ('back',),
#   ('back', 'to'),
#   ('to',),
#   ('to', 'youth'),
#   ('youth',),
#   ('youth', 'rajini'),
#   ('rajini',),
#   ('rajini', 'thalaiva'),
#   ('thalaiva',),
#   ('thalaiva', 'marana'),
#   ('marana',),
#   ('marana', 'mass'),
#   ('mass',),
#   ('mass', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'i'),
#   ('i',),
#   ('i', 'can'),
#   ('can',),
#   ('can', 'not'),
#   ('not',),
#   ('not', 'believe'),
#   ('believe',),
#   ('believe', 'he'),
#   ('he',),
#   ('he', 'is'),
#   ('is',),
#   ('is', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'appu'),
#   ('appu',),
#   ('appu', 'ithu'),
#   ('ithu',),
#   ('ithu', 'enna'),
#   ('enna',),
#   ('enna', 'telegu'),
#   ('telegu',),
#   ('telegu', 'padam'),
#   ('padam',),
#   ('padam', 'matri'),
#   ('matri',),
#   ('matri', 'iruku'),
#   ('iruku',),
#   ('iruku', 'tamil'),
#   ('tamil',),
#   ('tamil', 'padam'),
#   ('padam',),
#   ('padam', 'yedugeda'),
#   ('yedugeda',),
#   ('yedugeda', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', 'thalathala'),
#   ('thalathala',),
#   ('thalathala', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vijay'),
#   ('vijay',),
#   ('vijay', 'fans'),
#   ('fans',),
#   ('fans', 'dislike'),
#   ('dislike',),
#   ('dislike', 'pottu'),
#   ('pottu',),
#   ('pottu', 'oomba'),
#   ('oomba',),
#   ('oomba', 'vandhutanga'),
#   ('vandhutanga',),
#   ('vandhutanga', 'thayoli'),
#   ('thayoli',),
#   ('thayoli', 'poitu'),
#   ('poitu',),
#   ('poitu', 'unga'),
#   ('unga',),
#   ('unga', 'amma'),
#   ('amma',),
#   ('amma', 'shidhiya'),
#   ('shidhiya',),
#   ('shidhiya', 'oombungada'),
#   ('oombungada',),
#   ('oombungada', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'blockbuster'),
#   ('blockbuster',),
#   ('blockbuster', 'but'),
#   ('but',),
#   ('but', 'not'),
#   ('not',),
#   ('not', 'as'),
#   ('as',),
#   ('as', 'like'),
#   ('like',),
#   ('like', 'bahubali'),
#   ('bahubali',),
#   ('bahubali', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'ithula'),
#   ('ithula',),
#   ('ithula', 'dislike'),
#   ('dislike',),
#   ('dislike', 'panna'),
#   ('panna',),
#   ('panna', 'ennada'),
#   ('ennada',),
#   ('ennada', 'irukku'),
#   ('irukku',),
#   ('irukku', 'enda'),
#   ('enda',),
#   ('enda', 'ithana'),
#   ('ithana',),
#   ('ithana', 'dislikes'),
#   ('dislikes',),
#   ('dislikes', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaivar'),
#   ('thalaivar',),
#   ('thalaivar', 'masss'),
#   ('masss',),
#   ('masss', 'ah'),
#   ('ah',),
#   ('ah', 'irukarupa'),
#   ('irukarupa',),
#   ('irukarupa', 'nu'),
#   ('nu',),
#   ('nu', 'sonnavangala'),
#   ('sonnavangala',),
#   ('sonnavangala', 'hit'),
#   ('hit',),
#   ('hit', 'likes'),
#   ('likes',),
#   ('likes', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'times'),
#   ('times',),
#   ('times', 'pathavanga'),
#   ('pathavanga',),
#   ('pathavanga', 'like'),
#   ('like',),
#   ('like', 'podunga'),
#   ('podunga',),
#   ('podunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'tharisanam'),
#   ('tharisanam',),
#   ('tharisanam', 'marana'),
#   ('marana',),
#   ('marana', 'waiting'),
#   ('waiting',),
#   ('waiting', 'in'),
#   ('in',),
#   ('in', 'big'),
#   ('big',),
#   ('big', 'screen'),
#   ('screen',),
#   ('screen', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'pakarathuku'),
#   ('pakarathuku',),
#   ('pakarathuku', 'chinna'),
#   ('chinna',),
#   ('chinna', 'paiyan'),
#   ('paiyan',),
#   ('paiyan', 'maathiriya'),
#   ('maathiriya',),
#   ('maathiriya', 'poi'),
#   ('poi',),
#   ('poi', 'sonnalum'),
#   ('sonnalum',),
#   ('sonnalum', 'oru'),
#   ('oru',),
#   ('oru', 'nayam'),
#   ('nayam',),
#   ('nayam', 'venamada'),
#   ('venamada',),
#   ('venamada', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'die'),
#   ('die',),
#   ('die', 'hard'),
#   ('hard',),
#   ('hard', 'fans'),
#   ('fans',),
#   ('fans', 'of'),
#   ('of',),
#   ('of', 'ajithkumar'),
#   ('ajithkumar',),
#   ('ajithkumar', 'hit'),
#   ('hit',),
#   ('hit', 'like'),
#   ('like',),
#   ('like', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'sethupathi'),
#   ('sethupathi',),
# ...
#   ('ah',),
#   ('ah', 'pottu'),
#   ('pottu',),
#   ('pottu', 'therika'),
#   ('therika',),
#   ('therika', 'vidunga'),
#   ('vidunga',),
#   ('vidunga', 'by'),
#   ('by',),
#   ('by', 'thala'),
#   ('thala',),
#   ('thala', 'veriyans'),
#   ('veriyans',),
#   ('veriyans', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'superb'),
#   ('superb',),
#   ('superb', 'thala'),
#   ('thala',),
#   ('thala', 'frm'),
#   ('frm',),
#   ('frm', 'pavan'),
#   ('pavan',),
#   ('pavan', 'kalyan'),
#   ('kalyan',),
#   ('kalyan', 'fans'),
#   ('fans',),
#   ('fans', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaivaaaaaa'),
#   ('thalaivaaaaaa',),
#   ('thalaivaaaaaa', 'magnum'),
#   ('magnum',),
#   ('magnum', 'ops'),
#   ('ops',),
#   ('ops', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'electrifying'),
#   ('electrifying',),
#   ('electrifying', 'mass'),
#   ('mass',),
#   ('mass', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'ammadiyo'),
#   ('ammadiyo',),
#   ('ammadiyo', 'thala'),
#   ('thala',),
#   ('thala', 'da'),
#   ('da',),
#   ('da', 'nadipu'),
#   ('nadipu',),
#   ('nadipu', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'thala'),
#   ('thala',),
#   ('thala', 'fan'),
#   ('fan',),
#   ('fan', 'endu'),
#   ('endu',),
#   ('endu', 'solla'),
#   ('solla',),
#   ('solla', 'perumaiya'),
#   ('perumaiya',),
#   ('perumaiya', 'ituku'),
#   ('ituku',),
#   ('ituku', 'love'),
#   ('love',),
#   ('love', 'you'),
#   ('you',),
#   ('you', 'thala'),
#   ('thala',),
#   ('thala', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'kaithi'),
#   ('kaithi',),
#   ('kaithi', 'logesh'),
#   ('logesh',),
#   ('logesh', 'sangatamilan'),
#   ('sangatamilan',),
#   ('sangatamilan', 'vjs'),
#   ('vjs',),
#   ('vjs', 'bigil'),
#   ('bigil',),
#   ('bigil', 'vijay'),
#   ('vijay',),
#   ('vijay', 'all'),
#   ('all',),
#   ('all', 'are'),
#   ('are',),
#   ('are', 'in'),
#   ('in',),
#   ('in', 'vijay'),
#   ('vijay',),
#   ('vijay', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'antha'),
#   ('antha',),
#   ('antha', 'alavu'),
#   ('alavu',),
#   ('alavu', 'interest'),
#   ('interest',),
#   ('interest', 'ah'),
#   ('ah',),
#   ('ah', 'illafulla'),
#   ('illafulla',),
#   ('illafulla', 'girls'),
#   ('girls',),
#   ('girls', 'ah'),
#   ('ah',),
#   ('ah', 'dha'),
#   ('dha',),
#   ('dha', 'katranga'),
#   ('katranga',),
#   ('katranga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'times'),
#   ('times',),
#   ('times', 'watch'),
#   ('watch',),
#   ('watch', 'panavan'),
#   ('panavan',),
#   ('panavan', 'like'),
#   ('like',),
#   ('like', 'podu'),
#   ('podu',),
#   ('podu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'sk'),
#   ('sk',),
#   ('sk', 'fans'),
#   ('fans',),
#   ('fans', 'those'),
#   ('those',),
#   ('those', 'who'),
#   ('who',),
#   ('who', 'are'),
#   ('are',),
#   ('are', 'like'),
#   ('like',),
#   ('like', 'vj'),
#   ('vj',),
#   ('vj', 'sethupathi'),
#   ('sethupathi',),
#   ('sethupathi', 'podra'),
#   ('podra',),
#   ('podra', 'lika'),
#   ('lika',),
#   ('lika', 'like'),
#   ('like',),
#   ('like', 'theriksnum'),
#   ('theriksnum',),
#   ('theriksnum', 'sk'),
#   ('sk',),
#   ('sk', 'fans'),
#   ('fans',),
#   ('fans', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'nalla'),
#   ('nalla',),
#   ('nalla', 'illa'),
#   ('illa',),
#   ('illa', 'na'),
#   ('na',),
#   ('na', 'hollywood'),
#   ('hollywood',),
#   ('hollywood', 'edhuruparthen'),
#   ('edhuruparthen',),
#   ('edhuruparthen', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'podu'),
#   ('podu',),
#   ('podu', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'love'),
#   ('love',),
#   ('love', 'you'),
#   ('you',),
#   ('you', 'anna'),
#   ('anna',),
#   ('anna', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'mass'),
#   ('mass',),
#   ('mass', 'good'),
#   ('good',),
#   ('good', 'work'),
#   ('work',),
#   ('work', 'keep'),
#   ('keep',),
#   ('keep', 'on'),
#   ('on',),
#   ('on', 'rocking'),
#   ('rocking',),
#   ('rocking', 'superstar'),
#   ('superstar',),
#   ('superstar', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'next'),
#   ('next',),
#   ('next', 'level'),
#   ('level',),
#   ('level', 'to'),
#   ('to',),
#   ('to', 'tamil'),
#   ('tamil',),
#   ('tamil', 'cinema'),
#   ('cinema',),
#   ('cinema', 'must'),
#   ('must',),
#   ('must', 'like'),
#   ('like',),
#   ('like', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'super'),
#   ('super',),
#   ('super', 'super'),
#   ('super',),
#   ('super', 'ghibran'),
#   ('ghibran',),
#   ('ghibran', 'bgm'),
#   ('bgm',),
#   ('bgm', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'trailer'),
#   ('trailer',),
#   ('trailer', 'vera'),
#   ('vera',),
#   ('vera', 'level'),
#   ('level',),
#   ('level', 'padam'),
#   ('padam',),
#   ('padam', 'mass'),
#   ('mass',),
#   ('mass', 'aah'),
#   ('aah',),
#   ('aah', 'irukaa'),
#   ('irukaa',),
#   ('irukaa', 'pothu'),
#   ('pothu',),
#   ('pothu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'na'),
#   ('na',),
#   ('na', 'thala'),
#   ('thala',),
#   ('thala', 'thanthala'),
#   ('thanthala',),
#   ('thanthala', 'takkaru'),
#   ('takkaru',),
#   ('takkaru', 'doi'),
#   ('doi',),
#   ('doi', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'condipa'),
#   ('condipa',),
#   ('condipa', 'hit'),
#   ('hit',),
#   ('hit', 'moviethanu'),
#   ('moviethanu',),
#   ('moviethanu', 'solaravanga'),
#   ('solaravanga',),
#   ('solaravanga', 'ellarum'),
#   ('ellarum',),
#   ('ellarum', 'oru'),
#   ('oru',),
#   ('oru', 'like'),
#   ('like',),
#   ('like', 'podunga'),
#   ('podunga',),
#   ('podunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'oruthar'),
#   ('oruthar',),
#   ('oruthar', 'mele'),
#   ('mele',),
#   ('mele', 'neenga'),
#   ('neenga',),
#   ('neenga', 'viswasam'),
#   ('viswasam',),
#   ('viswasam', 'kaaturthukaga'),
#   ('kaaturthukaga',),
#   ('kaaturthukaga', 'innoruthare'),
#   ('innoruthare',),
#   ('innoruthare', 'en'),
#   ('en',),
#   ('en', 'asingam'),
#   ('asingam',),
#   ('asingam', 'paduthuringe'),
#   ('paduthuringe',),
#   ('paduthuringe', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vera'),
#   ('vera',),
#   ('vera', 'lvl'),
#   ('lvl',),
#   ('lvl', 'get'),
#   ('get',),
#   ('get', 'up'),
#   ('up',),
#   ('up', 'semma'),
#   ('semma',),
#   ('semma', 'vikram'),
#   ('vikram',),
#   ('vikram', 'anna'),
#   ('anna',),
#   ('anna', 'super'),
#   ('super',),
#   ('super', 'trailer'),
#   ('trailer',),
#   ('trailer', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'marana'),
#   ('marana',),
#   ('marana', 'waiting'),
#   ('waiting',),
#   ('waiting', 'by'),
#   ('by',),
#   ('by', 'thalapathi'),
#   ('thalapathi',),
#   ('thalapathi', 'fan'),
#   ('fan',),
#   ('fan', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'dhanus'),
#   ('dhanus',),
#   ('dhanus', 'looks'),
#   ('looks',),
#   ('looks', 'remain'),
#   ('remain',),
#   ('remain', 'kamal'),
#   ('kamal',),
#   ('kamal', 'hassan'),
#   ('hassan',),
#   ('hassan', 'look'),
#   ('look',),
#   ('look', 'in'),
#   ('in',),
#   ('in', 'virumandi'),
#   ('virumandi',),
#   ('virumandi', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thala'),
#   ('thala',),
#   ('thala', 'ajith'),
#   ('ajith',),
#   ('ajith', 'sirmass'),
#   ('sirmass',),
#   ('sirmass', 'konjam'),
#   ('konjam',),
#   ('konjam', 'kammiya'),
#   ('kammiya',),
#   ('kammiya', 'irukuravanga'),
#   ('irukuravanga',),
#   ('irukuravanga', 'like'),
#   ('like',),
#   ('like', 'pannunga'),
#   ('pannunga',),
#   ('pannunga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'nallaa'),
#   ('nallaa',),
#   ('nallaa', 'thala'),
#   ('thala',),
#   ('thala', 'thala'),
#   ('thala',),
#   ('thala', 'nu'),
#   ('nu',),
#   ('nu', 'irukaru'),
#   ('irukaru',),
#   ('irukaru', 'ajith'),
#   ('ajith',),
#   ('ajith', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vere'),
#   ('vere',),
#   ('vere', 'level'),
#   ('level',),
#   ('level', 'daa'),
#   ('daa',),
#   ('daa', 'trailerr'),
#   ('trailerr',),
#   ('trailerr', 'thala'),
#   ('thala',),
#   ('thala', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'naan'),
#   ('naan',),
#   ('naan', 'thala'),
#   ('thala',),
#   ('thala', 'yoda'),
#   ('yoda',),
#   ('yoda', 'thivira'),
#   ('thivira',),
#   ('thivira', 'rasigan'),
#   ('rasigan',),
#   ('rasigan', 'daa'),
#   ('daa',),
#   ('daa', 'naan'),
#   ('naan',),
#   ('naan', 'thirunelveli'),
#   ('thirunelveli',),
#   ('thirunelveli', 'karandaa'),
#   ('karandaa',),
#   ('karandaa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'adichi'),
#   ('adichi',),
#   ('adichi', 'underwearla'),
#   ('underwearla',),
#   ('underwearla', 'oda'),
#   ('oda',),
#   ('oda', 'vittuduven'),
#   ('vittuduven',),
#   ('vittuduven', 'for'),
#   ('for',),
#   ('for', 'simon'),
#   ('simon',),
#   ('simon', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'like'),
#   ('like',),
#   ('like', 'rekka'),
#   ('rekka',),
#   ('rekka', 'namma'),
#   ('namma',),
#   ('namma', 'veetu'),
#   ('veetu',),
#   ('veetu', 'pillai'),
#   ('pillai',),
#   ('pillai', 'kuda'),
#   ('kuda',),
#   ('kuda', 'vidalam'),
#   ('vidalam',),
#   ('vidalam', 'mass'),
#   ('mass',),
#   ('mass', 'ah'),
#   ('ah',),
#   ('ah', 'irukum'),
#   ('irukum',),
#   ('irukum', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'i'),
#   ('i',),
#   ('i', 'am'),
#   ('am',),
#   ('am', 'captain'),
#   ('captain',),
#   ('captain', 'fans'),
#   ('fans',),
#   ('fans', 'but'),
#   ('but',),
#   ('but', 'paaa'),
#   ('paaa',),
#   ('paaa', 'sema'),
#   ('sema',),
#   ('sema', 'gethu'),
#   ('gethu',),
#   ('gethu', 'ah'),
#   ('ah',),
#   ('ah', 'iruku'),
#   ('iruku',),
#   ('iruku', 'ajith'),
#   ('ajith',),
#   ('ajith', 'sir'),
#   ('sir',),
#   ('sir', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'raijini'),
#   ('raijini',),
#   ('raijini', 'than'),
#   ('than',),
#   ('than', 'massmy'),
#   ('massmy',),
#   ('massmy', 'age'),
#   ('age',),
#   ('age', 'na'),
#   ('na',),
#   ('na', 'rajini'),
#   ('rajini',),
#   ('rajini', 'fqn'),
#   ('fqn',),
#   ('fqn', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'intha'),
#   ('intha',),
#   ('intha', 'week'),
#   ('week',),
#   ('week', 'kulla'),
#   ('kulla',),
#   ('kulla', 'k'),
#   ('k',),
#   ('k', 'likes'),
#   ('likes',),
#   ('likes', 'varanum'),
#   ('varanum',),
#   ('varanum', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'youtube'),
#   ('youtube',),
#   ('youtube', 'hang'),
#   ('hang',),
#   ('hang', 'aaych'),
#   ('aaych',),
#   ('aaych', 'views'),
#   ('views',),
#   ('views', 'kaatamaatingith'),
#   ('kaatamaatingith',),
#   ('kaatamaatingith', 'but'),
#   ('but',),
#   ('but', 'likes'),
#   ('likes',),
#   ('likes', 'increase'),
#   ('increase',),
#   ('increase', 'aaykitte'),
#   ('aaykitte',),
#   ('aaykitte', 'irukk'),
#   ('irukk',),
#   ('irukk', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'k'),
#   ('k',),
#   ('k', 'like'),
#   ('like',),
#   ('like', 'marana'),
#   ('marana',),
#   ('marana', 'mass'),
#   ('mass',),
#   ('mass', 'ah'),
#   ('ah',),
#   ('ah', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vijai'),
#   ('vijai',),
#   ('vijai', 'sethubathykkaga'),
#   ('sethubathykkaga',),
#   ('sethubathykkaga', 'trailer'),
#   ('trailer',),
#   ('trailer', 'paakkuravanunga'),
#   ('paakkuravanunga',),
#   ('paakkuravanunga', 'poi'),
#   ('poi',),
#   ('poi', 'seethakathi'),
#   ('seethakathi',),
#   ('seethakathi', 'paarurajini'),
#   ('paarurajini',),
#   ('paarurajini', 'only'),
#   ('only',),
#   ('only', 'massmarana'),
#   ('massmarana',),
#   ('massmarana', 'mass'),
#   ('mass',),
#   ('mass', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'vj'),
#   ('vj',),
#   ('vj', 'nadaka'),
#   ('nadaka',),
#   ('nadaka', 'vda'),
#   ('vda',),
#   ('vda', 'matan'),
#   ('matan',),
#   ('matan', 'seenu'),
#   ('seenu',),
#   ('seenu', 'thala'),
#   ('thala',),
#   ('thala', 'nadaka'),
#   ('nadaka',),
#   ('nadaka', 'koodathu'),
#   ('koodathu',),
#   ('koodathu', 'gethu'),
#   ('gethu',),
#   ('gethu', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'you'),
#   ('you',),
#   ('you', 'bgm'),
#   ('bgm',),
#   ('bgm', 'is'),
#   ('is',),
#   ('is', 'ozm'),
#   ('ozm',),
#   ('ozm', 'sema'),
#   ('sema',),
#   ('sema', 'thalaivaa'),
#   ('thalaivaa',),
#   ('thalaivaa', 'love'),
#   ('love',),
#   ('love', 'you'),
#   ('you',),
#   ('you', 'you'),
#   ('you',),
#   ('you', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'yella'),
#   ('yella',),
#   ('yella', 'pasangalum'),
#   ('pasangalum',),
#   ('pasangalum', 'paakkavendiya'),
#   ('paakkavendiya',),
#   ('paakkavendiya', 'padam'),
#   ('padam',),
#   ('padam', 'thala'),
#   ('thala',),
#   ('thala', 'sonna'),
#   ('sonna',),
#   ('sonna', 'namba'),
#   ('namba',),
#   ('namba', 'pasanga'),
#   ('pasanga',),
#   ('pasanga', 'keapanga'),
#   ('keapanga',),
#   ('keapanga', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'dhsnush'),
#   ('dhsnush',),
#   ('dhsnush', 'vera'),
#   ('vera',),
#   ('vera', 'leval'),
#   ('leval',),
#   ('leval', 'ethana'),
#   ('ethana',),
#   ('ethana', 'mura'),
#   ('mura',),
#   ('mura', 'pathalum'),
#   ('pathalum',),
#   ('pathalum', 'salipu'),
#   ('salipu',),
#   ('salipu', 'illa'),
#   ('illa',),
#   ('illa', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'viswasatha'),
#   ('viswasatha',),
#   ('viswasatha', 'postponed'),
#   ('postponed',),
#   ('postponed', 'pannuganga'),
#   ('pannuganga',),
#   ('pannuganga', 'da'),
#   ('da',),
#   ('da', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'pakistani'),
#   ('pakistani',),
#   ('pakistani', 'movi'),
#   ('movi',),
#   ('movi', 'na'),
#   ('na',),
#   ('na', 'indian'),
#   ('indian',),
#   ('indian', 'movi'),
#   ('movi',),
#   ('movi', 'ka'),
#   ('ka',),
#   ('ka', 'record'),
#   ('record',),
#   ('record', 'tor'),
#   ('tor',),
#   ('tor', 'dia'),
#   ('dia',),
#   ('dia', 'salman'),
#   ('salman',),
#   ('salman', 'khan'),
#   ('khan',),
#   ('khan', 'b'),
#   ('b',),
#   ('b', 'hairan'),
#   ('hairan',),
#   ('hairan', 'open'),
#   ('open',),
#   ('open', 'link'),
#   ('link',),
#   ('link', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaiva'),
#   ('thalaiva',),
#   ('thalaiva', 'trailer'),
#   ('trailer',),
#   ('trailer', 'times'),
#   ('times',),
#   ('times', 'parthuda'),
#   ('parthuda',),
#   ('parthuda', 'innumu'),
#   ('innumu',),
#   ('innumu', 'slikkal'),
#   ('slikkal',),
#   ('slikkal', 'pathutte'),
#   ('pathutte',),
#   ('pathutte', 'irukkanum'),
#   ('irukkanum',),
#   ('irukkanum', 'pola'),
#   ('pola',),
#   ('pola', 'irukku'),
#   ('irukku',),
#   ('irukku', 'i'),
#   ('i',),
#   ('i', 'love'),
#   ('love',),
#   ('love', 'rajini'),
#   ('rajini',),
#   ('rajini', 'sir'),
#   ('sir',),
#   ('sir', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaivar'),
#   ('thalaivar',),
#   ('thalaivar', 'il'),
#   ('il',),
#   ('il', 'parthamathiri'),
#   ('parthamathiri',),
#   ('parthamathiri', 'irukkar'),
#   ('irukkar',),
#   ('irukkar', 'jan'),
#   ('jan',),
#   ('jan', 'epa'),
#   ('epa',),
#   ('epa', 'varumnu'),
#   ('varumnu',),
#   ('varumnu', 'irukku'),
#   ('irukku',),
#   ('irukku', 'thalaiva'),
#   ('thalaiva',),
#   ('thalaiva', 'we'),
#   ('we',),
#   ('we', 'are'),
#   ('are',),
#   ('are', 'all'),
#   ('all',),
#   ('all', 'wating'),
#   ('wating',),
#   ('wating', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'super'),
#   ('super',),
#   ('super', 'trailar'),
#   ('trailar',),
#   ('trailar', 'super'),
#   ('super',),
#   ('super', 'star'),
#   ('star',),
#   ('star', 'rajni'),
#   ('rajni',),
#   ('rajni', 'rasigan'),
#   ('rasigan',),
#   ('rasigan', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'ena'),
#   ('ena',),
#   ('ena', 'da'),
#   ('da',),
#   ('da', 'idhu'),
#   ('idhu',),
#   ('idhu', 'dunkirk'),
#   ('dunkirk',),
#   ('dunkirk', 'bgma'),
#   ('bgma',),
#   ('bgma', 'copy'),
#   ('copy',),
#   ('copy', 'adicha'),
#   ('adicha',),
#   ('adicha', 'mari'),
#   ('mari',),
#   ('mari', 'iruku'),
#   ('iruku',),
#   ('iruku', 'hanszimmer'),
#   ('hanszimmer',),
#   ('hanszimmer', 'paavam'),
#   ('paavam',),
#   ('paavam', 'summa'),
#   ('summa',),
#   ('summa', 'vidadu'),
#   ('vidadu',),
#   ('vidadu', 'da'),
#   ('da',),
#   ('da', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'last'),
#   ('last',),
#   ('last', 'dialogue'),
#   ('dialogue',),
#   ('dialogue', 'suit'),
#   ('suit',),
#   ('suit', 'for'),
#   ('for',),
#   ('for', 'all'),
#   ('all',),
#   ('all', 'fans'),
#   ('fans',),
#   ('fans', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'i'),
#   ('i',),
#   ('i', 'like'),
#   ('like',),
#   ('like', 'ayyayo'),
#   ('ayyayo',),
#   ('ayyayo', 'ithu'),
#   ('ithu',),
#   ('ithu', 'nala'),
#   ('nala',),
#   ('nala', 'eruka'),
#   ('eruka',),
#   ('eruka', 'dialog'),
#   ('dialog',),
#   ('dialog', '</s>'),
#   ('</s>',)],
#  [('<s>',),
#   ('<s>', 'thalaveriyan'),
#   ('thalaveriyan',),
#   ('thalaveriyan', 'solren'),
#   ('solren',),
#   ('solren', 'semma'),
#   ('semma',),
#   ('semma', 'mass'),
#   ('mass',),
#   ('mass', 'viswasam'),
#   ('viswasam',),
#   ('viswasam', 'elithi'),
#   ('elithi',),
#   ('elithi', 'vachukonga'),
#   ('vachukonga',),
#   ('vachukonga', 'viswasam'),
#   ('viswasam',),
#   ('viswasam', 'trailor'),
#   ('trailor',),
#   ('trailor', 'ithoda'),
#   ('ithoda',),
#   ('ithoda', 'mass'),
#   ('mass',),
#   ('mass', 'ah'),
#   ('ah',),
#   ('ah', 'irukum'),
#   ('irukum',),
#   ('irukum', '</s>'),
#   ('</s>',)],
#  ...]

# %%
lm.entropy(test_bigram)
# Out:
# inf

# %%
lm.entropy("thala")
# Out:
# 10.450401859948752

# %%
lm.perplexity("trailer")
# Out:
# 1791.25794684349

# %%
lm.logscore("thala", ["mass"])
# Out:
# -4.366178869316403

# %%
lm.logscore("trailer", ["mass"])
# Out:
# -5.08746284125034
